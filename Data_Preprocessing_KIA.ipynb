# %%
import pandas as pd # 데이터 핸들링 
import numpy as np 
import matplotlib.pyplot as plt # 데이터 시각화 
# %matplotlib inline
import seaborn as sns # 데이터 시각화(고급분석)
import warnings
warnings.filterwarnings("ignore")

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
df = pd.read_csv('data/기아-Copy1.csv')
df
# Out:
#        Unnamed: 0 brand  name                 info type      km  year  \
# 0           11813    기아    K5              2.0 럭셔리  가솔린  110575  2011
# 1           11815    기아   모하비        가솔린 4WD KV460  가솔린  213823  2011
# 2           11817    기아    K5                  럭셔리  가솔린  106819  2014
# 3           11818    기아    K7         3.3 GDI 노블레스  가솔린  110857  2016
# 4           11819    기아  스포티지      디젤 1.7 2WD 노블레스   디젤  129624  2018
# ...           ...   ...   ...                  ...  ...     ...   ...
# 11282       43894    기아  프라이드  4DR 1.6 CVVT SLX     가솔린   70000  2009
# 11283       43895    기아  프라이드  4DR 1.6 CVVT SLX     가솔린   21768  2007
# 11284       43896    기아  프라이드  4DR 1.6 CVVT SLX     가솔린   21768  2007
# 11285       43897    기아  프라이드    4DR 1.5 VGT LX      디젤  133837  2009
# 11286       43898    기아  프라이드   4DR 1.5 VGT SLX      디젤  230000  2009
#
#       accident color location  price   wd
# 0          무사고   검정색       인천    650  2WD
# ...

# %%
# 쓸모없는 컬럼 제거
df.drop(['Unnamed: 0'],axis=1, inplace = True)
df
# Out:
#       brand  name                 info type      km  year accident color  \
# 0        기아    K5              2.0 럭셔리  가솔린  110575  2011      무사고   검정색
# 1        기아   모하비        가솔린 4WD KV460  가솔린  213823  2011      무사고   검정색
# 2        기아    K5                  럭셔리  가솔린  106819  2014      무사고   검정색
# 3        기아    K7         3.3 GDI 노블레스  가솔린  110857  2016      무사고   검정색
# 4        기아  스포티지      디젤 1.7 2WD 노블레스   디젤  129624  2018      무사고   검정색
# ...     ...   ...                  ...  ...     ...   ...      ...   ...
# 11282    기아  프라이드  4DR 1.6 CVVT SLX     가솔린   70000  2009      무사고    기타
# 11283    기아  프라이드  4DR 1.6 CVVT SLX     가솔린   21768  2007      무사고    회색
# 11284    기아  프라이드  4DR 1.6 CVVT SLX     가솔린   21768  2007      무사고    회색
# 11285    기아  프라이드    4DR 1.5 VGT LX      디젤  133837  2009      무사고    회색
# 11286    기아  프라이드   4DR 1.5 VGT SLX      디젤  230000  2009      무사고    흰색
#
#       location  price   wd
# 0           인천    650  2WD
# 1           대구   1550  4WD
# ...

# %%
df
# Out:
#       brand  name                 info type      km  year accident color  \
# 0        기아    K5              2.0 럭셔리  가솔린  110575  2011      무사고   검정색
# 1        기아   모하비        가솔린 4WD KV460  가솔린  213823  2011      무사고   검정색
# 2        기아    K5                  럭셔리  가솔린  106819  2014      무사고   검정색
# 3        기아    K7         3.3 GDI 노블레스  가솔린  110857  2016      무사고   검정색
# 4        기아  스포티지      디젤 1.7 2WD 노블레스   디젤  129624  2018      무사고   검정색
# ...     ...   ...                  ...  ...     ...   ...      ...   ...
# 11282    기아  프라이드  4DR 1.6 CVVT SLX     가솔린   70000  2009      무사고    기타
# 11283    기아  프라이드  4DR 1.6 CVVT SLX     가솔린   21768  2007      무사고    회색
# 11284    기아  프라이드  4DR 1.6 CVVT SLX     가솔린   21768  2007      무사고    회색
# 11285    기아  프라이드    4DR 1.5 VGT LX      디젤  133837  2009      무사고    회색
# 11286    기아  프라이드   4DR 1.5 VGT SLX      디젤  230000  2009      무사고    흰색
#
#       location  price   wd
# 0           인천    650  2WD
# 1           대구   1550  4WD
# ...

# %%
df['name'].value_counts().sort_values(ascending = False)
# Out:
# K7                      1707
# K5                      1507
# 카니발                     1303
# 모닝                      1003
# 레이                       967
# 쏘렌토                      823
# 스포티지                     721
# K3                       581
# K9                       488
# 모하비                      393
# 스팅어                      296
# 셀토스                      291
# K8                       227
# 스토닉                      210
# 니로                       198
# 쏘울                       108
# 프라이드                     107
# 카렌스                       73
# 오피러스                      73
# 마스터                       68
# 쏘렌토R                      55
# 포르테                       48
# 로체                        27
# 봉고III 트럭 CRDi 카고           5
# 쎄라토                        3
# 봉고3                        2
# 카렌스2                       1
# 더 뉴 봉고III 트럭 CRDi 카고       1
# 옵티마                        1
# Name: name, dtype: int64

# %%
K5 = df[df['name'] == 'K5']

# %%
K5
# Out:
#       brand name                    info type      km  year accident color  \
# 0        기아   K5                 2.0 럭셔리  가솔린  110575  2011      무사고   검정색
# 2        기아   K5                     럭셔리  가솔린  106819  2014      무사고   검정색
# 5        기아   K5                     2.0  가솔린   29151  2019      무사고   검정색
# 29       기아   K5                  1.6 터보  가솔린    8766  2021      무사고   검정색
# 30       기아   K5               2.0 프레스티지  가솔린  101196  2012      무사고   검정색
# ...     ...  ...                     ...  ...     ...   ...      ...   ...
# 10197    기아   K5     3세대 2.0 가솔린 노블레스     가솔린   16436  2020      무사고    흰색
# 10198    기아   K5   3세대 1.6 가솔린 터보 시그니처    가솔린   13296  2021      무사고    흰색
# 10199    기아   K5     3세대 2.0 가솔린 노블레스     가솔린   16436  2020      무사고    흰색
# 10200    기아   K5  3세대 1.6 가솔린 터보 프레스티지    가솔린    3343  2021      무사고    흰색
# 10201    기아   K5     3세대 2.0 가솔린 노블레스     가솔린     242  2021      무사고    흰색
#
#       location  price   wd
# 0           인천    650  2WD
# ...

# %%
# 인덱스 초기화
K5.reset_index(inplace = True)
K5
# Out:
#       index brand name                    info type      km  year accident  \
# 0         0    기아   K5                 2.0 럭셔리  가솔린  110575  2011      무사고
# 1         2    기아   K5                     럭셔리  가솔린  106819  2014      무사고
# 2         5    기아   K5                     2.0  가솔린   29151  2019      무사고
# 3        29    기아   K5                  1.6 터보  가솔린    8766  2021      무사고
# 4        30    기아   K5               2.0 프레스티지  가솔린  101196  2012      무사고
# ...     ...   ...  ...                     ...  ...     ...   ...      ...
# 1502  10197    기아   K5     3세대 2.0 가솔린 노블레스     가솔린   16436  2020      무사고
# 1503  10198    기아   K5   3세대 1.6 가솔린 터보 시그니처    가솔린   13296  2021      무사고
# 1504  10199    기아   K5     3세대 2.0 가솔린 노블레스     가솔린   16436  2020      무사고
# 1505  10200    기아   K5  3세대 1.6 가솔린 터보 프레스티지    가솔린    3343  2021      무사고
# 1506  10201    기아   K5     3세대 2.0 가솔린 노블레스     가솔린     242  2021      무사고
#
#      color location  price   wd
# 0      검정색       인천    650  2WD
# ...

# %%
# 기존 인덱스 삭제
K5.drop(['index'], axis = 1,inplace = True)

# %%
K5
# Out:
#      brand name                    info type      km  year accident color  \
# 0       기아   K5                 2.0 럭셔리  가솔린  110575  2011      무사고   검정색
# 1       기아   K5                     럭셔리  가솔린  106819  2014      무사고   검정색
# 2       기아   K5                     2.0  가솔린   29151  2019      무사고   검정색
# 3       기아   K5                  1.6 터보  가솔린    8766  2021      무사고   검정색
# 4       기아   K5               2.0 프레스티지  가솔린  101196  2012      무사고   검정색
# ...    ...  ...                     ...  ...     ...   ...      ...   ...
# 1502    기아   K5     3세대 2.0 가솔린 노블레스     가솔린   16436  2020      무사고    흰색
# 1503    기아   K5   3세대 1.6 가솔린 터보 시그니처    가솔린   13296  2021      무사고    흰색
# 1504    기아   K5     3세대 2.0 가솔린 노블레스     가솔린   16436  2020      무사고    흰색
# 1505    기아   K5  3세대 1.6 가솔린 터보 프레스티지    가솔린    3343  2021      무사고    흰색
# 1506    기아   K5     3세대 2.0 가솔린 노블레스     가솔린     242  2021      무사고    흰색
#
#      location  price   wd
# 0          인천    650  2WD
# ...

# %%
# name 행의 문자열 제거
K5['info'] = K5.apply(lambda x: x['info'].replace('가솔린',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('디젤',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('4WD',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('2WD',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('AWD',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('3세대',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('2세대',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('하이브리드',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('세부등급 없음',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].strip(), axis = 1)
K5
# Out:
#      brand name           info type      km  year accident color location  \
# 0       기아   K5        2.0 럭셔리  가솔린  110575  2011      무사고   검정색       인천
# 1       기아   K5            럭셔리  가솔린  106819  2014      무사고   검정색       인천
# 2       기아   K5            2.0  가솔린   29151  2019      무사고   검정색       충북
# 3       기아   K5         1.6 터보  가솔린    8766  2021      무사고   검정색       경기
# 4       기아   K5      2.0 프레스티지  가솔린  101196  2012      무사고   검정색       대구
# ...    ...  ...            ...  ...     ...   ...      ...   ...      ...
# 1502    기아   K5      2.0  노블레스  가솔린   16436  2020      무사고    흰색       경기
# 1503    기아   K5   1.6  터보 시그니처  가솔린   13296  2021      무사고    흰색       경기
# 1504    기아   K5      2.0  노블레스  가솔린   16436  2020      무사고    흰색       경기
# 1505    기아   K5  1.6  터보 프레스티지  가솔린    3343  2021      무사고    흰색       경기
# 1506    기아   K5      2.0  노블레스  가솔린     242  2021      무사고    흰색       경기
#
#       price   wd
# 0       650  2WD
# 1       940  2WD
# 2      1890  2WD
# ...

# %%
for i in range(0, len(K5)):
    if K5['info'].str.contains('SX')[i] :
        print(K5['info'][i])
    else :
        pass
# Out:
# LPI SX
# 2.0 SX
# 1.7  SX
# 2.0 SX
# 2.0 터보 SX
# 2.0 SX
# 1.7  SX
# 2.0 SX
# 1.6 터보 SX
# 2.0 SX
# 2.0 터보 SX
# 2.0 SX
# 1.7  SX
# 2.0 SX
# 1.7  SX
# 2.0 SX
# 2.0 SX
# LPI SX
# 1.7  SX
# 2.0 SX
# 2.0 SX
# 2.0 SX
# 2.0 SX
# LPI SX
# LPI SX
# 2.0 SX
# 2.0 SX
# 1.7  SX
# LPI SX
# LPI SX
# 1.6 터보 SX
# 1.7  SX
# 1.7  SX
# 2.0 SX
# LPI SX
# 1.7  SX
# 2.0 SX
# LPI SX
# 2.0 SX
# LPI SX
# 1.6 터보 SX
# 2.0 SX
# 2.0 SX
# 1.7  SX
# 1.7  SX
# 2.0 SX
# 1.7  SX
# 1.7  SX
# 1.6 터보 SX
# LPI SX
# LPI SX
# LPI SX
# 2.0 SX
# 2.0 SX
# 1.7  SX
# 2.0 SX
# 2.0 SX
# 1.7  SX
# LPI SX
# 2.0 SX
# LPI SX
# 2.0 SX
# LPI SX
# 2.0 SX
# 1.7  SX
# 2.0 SX
# 1.7  SX
# 1.7  SX
# 2.0 터보 SX
# 1.7  SX
# LPI SX
# 1.7  SX
# 2.0 SX
# 1.7  SX
# 1.7  SX
# 1.7  SX
# LPI SX
# 1.7  SX
# 2.0 SX
# 1.7  SX
# 2.0 SX
# 2.0 SX
# 1.7  SX
# 2.0 SX
# 2.0 SX
# 2.0 터보 SX
# 2.0 SX
# LPI SX
# 2.0 SX노블레스 스페셜
# 2.0 SX시그니처
# 1.6 터보 SX노블레스
# 2.0 터보 SX노블레스 스페셜
# 2.0 SX럭셔리
# 2.0 SX스타일 에디션
# 1.6 터보 SX노블레스 스페셜
# 1.6 터보 SX노블레스
# 1.7  SX노블레스 스페셜
# ...

# %%
for i in range(0, len(K5)):
    if K5['info'].str.contains('MX')[i] :
        print(K5['info'][i])
    else :
        pass
# Out:
# 2.0 MX
# LPI MX
# 2.0 MX
# LPI MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# 1.7  MX
# LPI MX
# LPI MX
# LPI MX
# 2.0 MX
# LPI MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# LPI MX
# 1.7  MX
# LPI MX
# 2.0 MX
# 2.0 MX
# LPI MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# 1.7  MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# 1.7  MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# LPI MX
# 2.0 MX
# LPI MX
# 2.0 MX
# LPI MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# LPI MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# LPI MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# LPI MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# LPI MX
# LPI MX
# LPI MX
# LPI MX
# 2.0 MX
# LPI MX
# LPI MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# LPI MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# LPI MX
# 2.0 MX
# LPI MX
# 2.0 MX
# 2.0 MX
# 1.7  MX
# 2.0 MX
# LPI MX
# LPI MX
# 2.0 MX
# 1.7  MX
# LPI MX
# 1.7  MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# LPI MX
# 2.0 MX
# LPI MX
# 2.0 MX
# 2.0 MX
# LPI MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# 2.0 MX
# ...

# %%
for i in range(0,len(K5)):
    if K5['info'].str.contains('트랜디')[i]:
        print(K5['info'][i])
# Out:
# 럭셔리트랜디
# 럭셔리트랜디
# 럭셔리트랜디

# %%
for i in range(0,len(K5)):
    if K5['info'].str.contains('에디션')[i]:
        print(K5['info'][i])
# Out:
# 2.0 SX스타일 에디션
# 2.0 MX스타일 에디션
# 2.0 SX스타일 에디션
# 2.0 SX스타일 에디션
# 2.0 MX스타일 에디션
# 2.0 SX스페셜 에디션

# %%
for i in range(0,len(K5)):
    if K5['info'].str.contains('스타일')[i]:
        print(K5['info'][i])
# Out:
# 2.0 SX스타일 에디션
# 2.0 MX스타일 에디션
# 2.0 SX스타일 에디션
# 2.0 SX스타일 에디션
# 2.0 MX스타일 에디션

# %%
K5[K5['info']=='2.0 SX스타일 에디션']
# Out:
#      brand name           info type     km  year accident color location  \
# 942     기아   K5  2.0 SX스타일 에디션  가솔린  52384  2018      무사고    흰색       인천
# 1002    기아   K5  2.0 SX스타일 에디션  가솔린  51303  2018     단순교환    흰색       인천
# 1043    기아   K5  2.0 SX스타일 에디션  가솔린  19943  2018      무사고    회색       충북
#
#       price   wd
# 942    1520  2WD
# 1002   1590  2WD
# 1043   1750  2WD

# %%
K5['info'].unique()
# Out:
# array(['2.0 럭셔리', '럭셔리', '2.0', '1.6 터보', '2.0 프레스티지', '500h 프레스티지',
#        '2.0 MX', 'LPI 노블레스', '노블레스', 'LPI 프레스티지', '2.0 디럭스', 'LPI SX',
#        'LPI MX', 'LPI 디럭스', 'LPI 럭셔리', '2.0 터보 GDI 노블레스',
#        'LPI 프레스티지(장애인용)', '시그니처', '2.0 SX', '2.0 노블레스', '1.7', 'LPI 스마트',
#        '디럭스', '1.7  MX', '2.0 LPI 렌터카용', '1.7  SX', '2.0 LPI',
#        '2.0 터보 SX', 'W 스페셜', '프레스티지', '2.0 터보 GDI 프레스티지', '2.4 GDI 노블레스',
#        '1.6 터보 SX', '터보 GDI 프레스티지', '2.0 스마트', '500h 럭셔리',
#        '2.0 LPI(렌터카용)', '2.4 수출형(옵티마)', '2.0 트렌디', '터보 GDI 노블레스',
#        '2.4 GDI 프레스티지', '500h 노블레스', '2.0 MX노블레스', '2.0 SX노블레스 스페셜',
#        '터보 1.6시그니처', '2.0 SX시그니처', '1.6 터보 SX노블레스', '2.0 터보 SX노블레스 스페셜',
#        '2.0 SX럭셔리', '1.6 터보노블레스', '2.0노블레스', '1.7  MX럭셔리', '2.0 LPI럭셔리',
#        '1.7 프레스티지', '2.0 SX스타일 에디션', '1.6 터보노블레스 스페셜', '2.0프레스티지',
#        '1.6 터보 SX노블레스 스페셜', '1.7  MX노블레스', '1.7  MX프레스티지',
#        '2.0 MX노블레스 스페셜', '2.0인텔리전트', 'LPI MX노블레스', '2.0 MX시그니처',
# ...

# %%
# info열의 프리미엄 스포츠 여부를 upgrade 열에 추가
K5['upgrade'] = ""

for i in range(0, len(K5)):
    
    if K5['info'].str.contains('스탠다드')[i]:
        K5['upgrade'][i] = '스탠다드'

    elif K5['info'].str.contains('스마트 스페셜')[i]:
        K5['upgrade'][i] = '스마트 스페셜'
        
    elif K5['info'].str.contains('스마트')[i]:
        K5['upgrade'][i] = '스마트'
    
        
    elif K5['info'].str.contains('디럭스')[i]:
        K5['upgrade'][i] = '디럭스'
        
    elif K5['info'].str.contains('럭셔리 스페셜')[i]:
        K5['upgrade'][i] = '럭셔리 스페셜'
    
    elif K5['info'].str.contains('럭셔리트렌디')[i]:
        K5['upgrade'][i] = '럭셔리 트렌디'
        
    elif K5['info'].str.contains('럭셔리트랜디')[i]:
        K5['upgrade'][i] = '럭셔리 트렌디'
    
    elif K5['info'].str.contains('럭셔리')[i]:
        K5['upgrade'][i] = '럭셔리'
    
    elif K5['info'].str.contains('스타일 에디션')[i]:
        K5['upgrade'][i] = '스타일 에디션'
        
    elif K5['info'].str.contains('트렌디')[i]:
        K5['upgrade'][i] = '트렌디'
        
    elif K5['info'].str.contains('트랜디')[i]:
        K5['upgrade'][i] = '트렌디'
        
    elif K5['info'].str.contains('W 스페셜')[i]:
        K5['upgrade'][i] = 'W 스페셜'
        
    elif K5['info'].str.contains('프레스티지')[i]:
        K5['upgrade'][i] = '프레스티지'
        
    elif K5['info'].str.contains('스페셜 에디션')[i]:
        K5['upgrade'][i] = '스페셜 에디션'
    
    elif K5['info'].str.contains('노블레스 스페셜')[i]:
        K5['upgrade'][i] = '노블레스 스페셜'
        
    elif K5['info'].str.contains('노블레스')[i]:
        K5['upgrade'][i] = '노블레스'
        
    elif K5['info'].str.contains('시그니쳐')[i]:
        K5['upgrade'][i] = '시그니쳐'
        
    elif K5['info'].str.contains('시그니처')[i]:
        K5['upgrade'][i] = '시그니쳐'
        
    elif K5['info'].str.contains('인텔리전트')[i]:
        K5['upgrade'][i] = '시그니쳐'
        
    elif K5['info'].str.contains('GT LINE')[i]:
        K5['upgrade'][i] = 'GT LINE'
        
    elif K5['info'].str.contains('GT')[i]:
        K5['upgrade'][i] = 'GT'
        
    else :
        K5['upgrade'][i] = '스탠다드'
K5
# Out:
#      brand name           info type      km  year accident color location  \
# 0       기아   K5        2.0 럭셔리  가솔린  110575  2011      무사고   검정색       인천
# 1       기아   K5            럭셔리  가솔린  106819  2014      무사고   검정색       인천
# 2       기아   K5            2.0  가솔린   29151  2019      무사고   검정색       충북
# 3       기아   K5         1.6 터보  가솔린    8766  2021      무사고   검정색       경기
# 4       기아   K5      2.0 프레스티지  가솔린  101196  2012      무사고   검정색       대구
# ...    ...  ...            ...  ...     ...   ...      ...   ...      ...
# 1502    기아   K5      2.0  노블레스  가솔린   16436  2020      무사고    흰색       경기
# 1503    기아   K5   1.6  터보 시그니처  가솔린   13296  2021      무사고    흰색       경기
# 1504    기아   K5      2.0  노블레스  가솔린   16436  2020      무사고    흰색       경기
# 1505    기아   K5  1.6  터보 프레스티지  가솔린    3343  2021      무사고    흰색       경기
# 1506    기아   K5      2.0  노블레스  가솔린     242  2021      무사고    흰색       경기
#
#       price   wd upgrade
# 0       650  2WD     럭셔리
# 1       940  2WD     럭셔리
# ...

# %%
K5[K5['upgrade'] == 'NaN']
# Out:
# Empty DataFrame
# Columns: [brand, name, info, type, km, year, accident, color, location, price, wd, upgrade]
# Index: []

# %%
# info 행의 문자열 제거
K5['info'] = K5.apply(lambda x: x['info'].replace('스탠다드',''), axis = 1) 
K5['info'] = K5.apply(lambda x: x['info'].replace('스마트',''), axis = 1) 
K5['info'] = K5.apply(lambda x: x['info'].replace('디럭스',''), axis = 1) 
K5['info'] = K5.apply(lambda x: x['info'].replace('스타일',''), axis = 1)   
K5['info'] = K5.apply(lambda x: x['info'].replace('럭셔리',''), axis = 1)       
K5['info'] = K5.apply(lambda x: x['info'].replace('트랜디',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('W 스페셜',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('에디션',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('스페셜',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('인텔리전트',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('GT LINE',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('GT',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('프레스티지',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('트렌디',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('노블레스',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('시그니쳐',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('시그니처',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('렌터카용',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('수출형옵티마',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('기본형',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace('(',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].replace(')',''), axis = 1)
K5['info'] = K5.apply(lambda x: x['info'].strip(), axis = 1)
K5
# Out:
#      brand name     info type      km  year accident color location  price  \
# 0       기아   K5      2.0  가솔린  110575  2011      무사고   검정색       인천    650
# 1       기아   K5           가솔린  106819  2014      무사고   검정색       인천    940
# 2       기아   K5      2.0  가솔린   29151  2019      무사고   검정색       충북   1890
# 3       기아   K5   1.6 터보  가솔린    8766  2021      무사고   검정색       경기   3190
# 4       기아   K5      2.0  가솔린  101196  2012      무사고   검정색       대구    820
# ...    ...  ...      ...  ...     ...   ...      ...   ...      ...    ...
# 1502    기아   K5      2.0  가솔린   16436  2020      무사고    흰색       경기   2820
# 1503    기아   K5  1.6  터보  가솔린   13296  2021      무사고    흰색       경기   3330
# 1504    기아   K5      2.0  가솔린   16436  2020      무사고    흰색       경기   2820
# 1505    기아   K5  1.6  터보  가솔린    3343  2021      무사고    흰색       경기   2830
# 1506    기아   K5      2.0  가솔린     242  2021      무사고    흰색       경기   2899
#
#        wd upgrade
# 0     2WD     럭셔리
# 1     2WD     럭셔리
# ...

# %%
# info 행의 프리미엄, 스포츠 문자열 제거
K5['type'].unique()
# Out:
# array(['가솔린', '가솔린+전기', 'LPG(일반인 구입)', '디젤', 'LPG', '하이브리드'], dtype=object)

# %%
K5['type'] = K5.apply(lambda x: x['type'].replace('(일반인 구입)',''), axis = 1)
K5['type'] = K5.apply(lambda x: x['type'].replace('가솔린+전기','하이브리드'), axis = 1)
K5['type'] = K5.apply(lambda x: x['type'].strip(), axis = 1)
K5['type'].unique()
# Out:
# array(['가솔린', '하이브리드', 'LPG', '디젤'], dtype=object)

# %%
K7 = df[df['name'] == 'K7']
K7
# Out:
#       brand name                       info         type      km  year  \
# 3        기아   K7               3.3 GDI 노블레스          가솔린  110857  2016
# 10       기아   K7              3.0 GDI 프레스티지          가솔린   50938  2015
# 16       기아   K7          3.0 LPI 럭셔리 (렌터카)  LPG(일반인 구입)   61709  2017
# 18       기아   K7                2.2 디젤 노블레스           디젤   58018  2020
# 24       기아   K7                LPI 3.0 럭셔리  LPG(일반인 구입)  180891  2014
# ...     ...  ...                        ...          ...     ...   ...
# 10348    기아   K7       프리미어 2.5 GDi 노블레스             가솔린   16865  2019
# 10349    기아   K7       프리미어 2.2 디젤 프레스티지              디젤   19836  2019
# 10350    기아   K7  프리미어 하이브리드 2.4 HEV 노블레스          하이브리드   17810  2020
# 10351    기아   K7  프리미어 하이브리드 2.4 HEV 노블레스          하이브리드   17810  2020
# 10352    기아   K7  프리미어 하이브리드 2.4 HEV 노블레스          하이브리드   17810  2020
#
#       accident color location  price   wd
# 3          무사고   검정색       경기   1780  2WD
# ...

# %%
# name 행의 문자열 제거
K7['info'] = K7.apply(lambda x: x['info'].replace('가솔린',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('디젤',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('하이브리드',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('세부등급 없음',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].strip(), axis = 1)
K7
# Out:
#       brand name                info         type      km  year accident  \
# 3        기아   K7        3.3 GDI 노블레스          가솔린  110857  2016      무사고
# 10       기아   K7       3.0 GDI 프레스티지          가솔린   50938  2015      무사고
# 16       기아   K7   3.0 LPI 럭셔리 (렌터카)  LPG(일반인 구입)   61709  2017      무사고
# 18       기아   K7           2.2  노블레스           디젤   58018  2020      무사고
# 24       기아   K7         LPI 3.0 럭셔리  LPG(일반인 구입)  180891  2014      무사고
# ...     ...  ...                 ...          ...     ...   ...      ...
# 10348    기아   K7   프리미어 2.5 GDi 노블레스          가솔린   16865  2019      무사고
# 10349    기아   K7     프리미어 2.2  프레스티지           디젤   19836  2019      무사고
# 10350    기아   K7  프리미어  2.4 HEV 노블레스        하이브리드   17810  2020      무사고
# 10351    기아   K7  프리미어  2.4 HEV 노블레스        하이브리드   17810  2020      무사고
# 10352    기아   K7  프리미어  2.4 HEV 노블레스        하이브리드   17810  2020      무사고
#
#       color location  price   wd
# 3       검정색       경기   1780  2WD
# ...

# %%
K7.reset_index(inplace = True)
K7.drop(['index'], axis = 1,inplace = True)
K7
# Out:
#      brand name                info         type      km  year accident color  \
# 0       기아   K7        3.3 GDI 노블레스          가솔린  110857  2016      무사고   검정색
# 1       기아   K7       3.0 GDI 프레스티지          가솔린   50938  2015      무사고   검정색
# 2       기아   K7   3.0 LPI 럭셔리 (렌터카)  LPG(일반인 구입)   61709  2017      무사고   검정색
# 3       기아   K7           2.2  노블레스           디젤   58018  2020      무사고   검정색
# 4       기아   K7         LPI 3.0 럭셔리  LPG(일반인 구입)  180891  2014      무사고   검정색
# ...    ...  ...                 ...          ...     ...   ...      ...   ...
# 1702    기아   K7   프리미어 2.5 GDi 노블레스          가솔린   16865  2019      무사고    흰색
# 1703    기아   K7     프리미어 2.2  프레스티지           디젤   19836  2019      무사고    흰색
# 1704    기아   K7  프리미어  2.4 HEV 노블레스        하이브리드   17810  2020      무사고    흰색
# 1705    기아   K7  프리미어  2.4 HEV 노블레스        하이브리드   17810  2020      무사고    흰색
# 1706    기아   K7  프리미어  2.4 HEV 노블레스        하이브리드   17810  2020      무사고    흰색
#
#      location  price   wd
# ...

# %%
K7['info'].unique()
# Out:
# array(['3.3 GDI 노블레스', '3.0 GDI 프레스티지', '3.0 LPI 럭셔리 (렌터카)', '2.2  노블레스',
#        'LPI 3.0 럭셔리', '2.4 GDI 리미티드', '2.4 GDI 프레스티지', '2.5 GDI 노블레스',
#        '2.2  리미티드', '노블레스', '3.0 LPI 트렌디(렌터카)', 'LPI 3.0 프레스티지',
#        '3.0 GDI 노블레스', '3.0 LPI 럭셔리', '프레스티지', '2.2  프레스티지', '시그니처',
#        '2.5 GDI X 에디션', '3.3 GDI 리미티드 플러스', '3.0 GDI 리미티드',
#        '3.0 GDI 시그니처', '2.4 GDI 프레스티지 스페셜', '700h 프레스티지', 'VG270 럭셔리',
#        '2.4 GDI 노블레스', '3.0 GDI 프레스티지 스페셜', '3.0 LPI 프레스티지 (렌터카)',
#        'LPI 3.0 디럭스', '노블레스 스페셜', '2.4 GDI 디럭스', '2.4 GDI 럭셔리',
#        '3.0 LPI 프레스티지', '2.4 GDI 리미티드 에디션', '3.0 LPI 프레스티지(렌터카)',
#        '3.0 GDI 럭셔리', '3.0 LPI 디럭스 (렌터카)', 'VG240 디럭스', '3.0 LPI 택시형',
#        '3.0 LPI 노블레스(장애인용)', '3.3 GDI 리미티드 에디션', 'VG350 노블레스',
#        '2.4 월드컵 에디션', '2.4 GDI 스페셜', '3.0 LPI 노블레스', 'VG270 디럭스',
#        '2.2  리미티드 에디션', 'VG270 프레스티지', '2.5 GDI 프레스티지',
#        '3.0 LPI 프레스티지(장애인용)', '700h 럭셔리', 'LPI VG270 럭셔리',
# ...

# %%
for i in range(0,len(K7)):
    if K7['info'].str.contains('X 에디션')[i]:
        print(K7['info'][i])
# Out:
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5 GDI X 에디션
# 2.5X 에디션
# 2.5X 에디션
# 2.5X 에디션
# 2.5X 에디션
# 2.5X 에디션
# 2.5X 에디션
# 2.5X 에디션
# 2.5X 에디션
# 2.5X 에디션
# 2.5X 에디션
# 프리미어 2.5 GDi X 에디션
# 프리미어 2.5 GDi X 에디션
# 프리미어 2.5 GDi X 에디션
# 프리미어 2.5 GDi X 에디션
# 프리미어 2.5 GDi X 에디션
# 프리미어 2.5 GDi X 에디션
# 프리미어 2.5 GDi X 에디션
# 프리미어 2.5 GDi X 에디션
# 프리미어 2.5 GDi X 에디션
# 프리미어 2.5 GDi X 에디션
# 프리미어 2.5 GDi X 에디션
# 프리미어 2.5 GDi X 에디션
# 프리미어 2.5 GDi X 에디션
# 프리미어 2.5 GDi X 에디션
# 프리미어 2.5 GDi X 에디션
# ...

# %%
# info열의 프리미엄 스포츠 여부를 upgrade 열에 추가
K7['upgrade'] = ""

for i in range(0, len(K7)):
    
    if K7['info'].str.contains('스탠다드')[i]:
        K7['upgrade'][i] = '스탠다드'

    elif K7['info'].str.contains('디럭스스페셜')[i]:
        K7['upgrade'][i] = '스마트 스페셜'
        
    elif K7['info'].str.contains('디럭스')[i]:
        K7['upgrade'][i] = '디럭스'
    
    elif K7['info'].str.contains('트렌디')[i]:
        K7['upgrade'][i] = '트렌디'
        
    elif K7['info'].str.contains('럭셔리 스페셜')[i]:
        K7['upgrade'][i] = '럭셔리 스페셜' 

    elif K7['info'].str.contains('럭셔리 프리미엄')[i]:
        K7['upgrade'][i] = '럭셔리 스페셜' 
    
    elif K7['info'].str.contains('럭셔리')[i]:
        K7['upgrade'][i] = '럭셔리'
    
    elif K7['info'].str.contains('프레스티지 스페셜')[i]:
        K7['upgrade'][i] = '프레스티지 스페셜'
        
    elif K7['info'].str.contains('프레스티지 프리미엄')[i]:
        K7['upgrade'][i] = '프레스티지 스페셜'
        
    elif K7['info'].str.contains('프레스티지')[i]:
        K7['upgrade'][i] = '프레스티지'
        
    elif K7['info'].str.contains('리미티드')[i]:
        K7['upgrade'][i] = '리미티드'
        
    elif K7['info'].str.contains('리미티드 에디션')[i]:
        K7['upgrade'][i] = '리미티드'
    
    elif K7['info'].str.contains('노블레스 스페셜')[i]:
        K7['upgrade'][i] = '노블레스 스페셜'
        
    elif K7['info'].str.contains('노블레스 프리미엄')[i]:
        K7['upgrade'][i] = '노블레스 스페셜'
        
    elif K7['info'].str.contains('노블레스')[i]:
        K7['upgrade'][i] = '노블레스'
        
    elif K7['info'].str.contains('월드컵')[i]:
        K7['upgrade'][i] = '월드컵 에디션'
        
    elif K7['info'].str.contains('X 에디션')[i]:
        K7['upgrade'][i] = 'X 에디션'
        
    elif K7['info'].str.contains('시그니쳐')[i]:
        K7['upgrade'][i] = '시그니쳐'
        
    elif K7['info'].str.contains('시그니처')[i]:
        K7['upgrade'][i] = '시그니쳐'
        
    elif K7['info'].str.contains('2.4 GDI 스페셜')[i]:
        K7['upgrade'][i] = '프레스티디 스페셜'
               
    else :
        K7['upgrade'][i] = '스탠다드'
K7
# Out:
#      brand name                info         type      km  year accident color  \
# 0       기아   K7        3.3 GDI 노블레스          가솔린  110857  2016      무사고   검정색
# 1       기아   K7       3.0 GDI 프레스티지          가솔린   50938  2015      무사고   검정색
# 2       기아   K7   3.0 LPI 럭셔리 (렌터카)  LPG(일반인 구입)   61709  2017      무사고   검정색
# 3       기아   K7           2.2  노블레스           디젤   58018  2020      무사고   검정색
# 4       기아   K7         LPI 3.0 럭셔리  LPG(일반인 구입)  180891  2014      무사고   검정색
# ...    ...  ...                 ...          ...     ...   ...      ...   ...
# 1702    기아   K7   프리미어 2.5 GDi 노블레스          가솔린   16865  2019      무사고    흰색
# 1703    기아   K7     프리미어 2.2  프레스티지           디젤   19836  2019      무사고    흰색
# 1704    기아   K7  프리미어  2.4 HEV 노블레스        하이브리드   17810  2020      무사고    흰색
# 1705    기아   K7  프리미어  2.4 HEV 노블레스        하이브리드   17810  2020      무사고    흰색
# 1706    기아   K7  프리미어  2.4 HEV 노블레스        하이브리드   17810  2020      무사고    흰색
#
# ...

# %%
K7[K7['upgrade'] == 'NaN']
# Out:
# Empty DataFrame
# Columns: [brand, name, info, type, km, year, accident, color, location, price, wd, upgrade]
# Index: []

# %%
# info 행의 문자열 제거
K7['info'] = K7.apply(lambda x: x['info'].replace('스탠다드',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('디럭스스페셜',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('디럭스',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('트렌디',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('럭셔리 스페셜',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('럭셔리 프리미엄',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('럭셔리',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('프레스티지 스페셜',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('프레스티지 프리미엄',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('프레스티지',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('리미티드',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('리미티드 에디션',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('노블레스 스페셜',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('노블레스 프리미엄',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('노블레스',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('월드컵',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('X 에디션',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('월드컵',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('시그니쳐',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('시그니처',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('스페셜',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('프리미어',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('(렌터카)',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('렌터카',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('수출형',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('기본형',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('일반인',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('(일반인)',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('(장애인용)',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('()',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('플러스',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('에디션',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].replace('택시형',''), axis = 1)
K7['info'] = K7.apply(lambda x: x['info'].strip(), axis = 1)
K7
# Out:
#      brand name     info         type      km  year accident color location  \
# 0       기아   K7  3.3 GDI          가솔린  110857  2016      무사고   검정색       경기
# 1       기아   K7  3.0 GDI          가솔린   50938  2015      무사고   검정색       서울
# 2       기아   K7  3.0 LPI  LPG(일반인 구입)   61709  2017      무사고   검정색       광주
# 3       기아   K7      2.2           디젤   58018  2020      무사고   검정색       광주
# 4       기아   K7  LPI 3.0  LPG(일반인 구입)  180891  2014      무사고   검정색       대전
# ...    ...  ...      ...          ...     ...   ...      ...   ...      ...
# 1702    기아   K7  2.5 GDi          가솔린   16865  2019      무사고    흰색       경남
# 1703    기아   K7      2.2           디젤   19836  2019      무사고    흰색       인천
# 1704    기아   K7  2.4 HEV        하이브리드   17810  2020      무사고    흰색       대구
# 1705    기아   K7  2.4 HEV        하이브리드   17810  2020      무사고    흰색       대구
# 1706    기아   K7  2.4 HEV        하이브리드   17810  2020      무사고    흰색       대구
#
#       price   wd upgrade
# 0      1780  2WD    노블레스
# ...

# %%
K7['info'].unique()
# Out:
# array(['3.3 GDI', '3.0 GDI', '3.0 LPI', '2.2', 'LPI 3.0', '2.4 GDI',
#        '2.5 GDI', '', '700h', 'VG270', 'VG240', 'VG350', '2.4',
#        'LPI VG270', '3.5', '2.5', '3.0', 'LPG 3.0', '3.0 LPi', '2.4 HEV',
#        '2.5 GDi', '3.0 GDi'], dtype=object)

# %%
df['name'].unique()
# Out:
# array(['K5', '모하비', 'K7', '스포티지', '카니발', '쏘렌토', '레이', 'K9', '포르테', '모닝',
#        'K8', '카렌스', '스팅어', 'K3', '마스터', '오피러스', '프라이드', '로체', '스토닉', '쏘울',
#        '셀토스', '니로', '쎄라토', '옵티마', '봉고III 트럭 CRDi 카고',
#        '더 뉴 봉고III 트럭 CRDi 카고', '봉고3', '쏘렌토R', '카렌스2'], dtype=object)

# %%
mohave = df[df['name'] == '모하비']
mohave
# Out:
#       brand name                info type      km  year accident color  \
# 1        기아  모하비       가솔린 4WD KV460  가솔린  213823  2011      무사고   검정색
# 12       기아  모하비          디젤 3.0 4WD   디젤   43813  2018      무사고   검정색
# 14       기아  모하비           4WD KV300   디젤   51482  2014      무사고   검정색
# 31       기아  모하비          디젤 3.0 4WD   디젤   57621  2018      무사고   검정색
# 37       기아  모하비          디젤 3.0 4WD   디젤   46818  2018      무사고   검정색
# ...     ...  ...                 ...  ...     ...   ...      ...   ...
# 10774    기아  모하비  마스터 4WD 디젤 마스터즈      디젤   17011  2019      무사고    흰색
# 10775    기아  모하비  마스터 4WD 디젤 마스터즈      디젤   46372  2019      무사고    흰색
# 10776    기아  모하비  마스터 4WD 디젤 마스터즈      디젤   17011  2019      무사고    흰색
# 10777    기아  모하비  마스터 4WD 디젤 마스터즈      디젤   17011  2019      무사고    흰색
# 10778    기아  모하비  마스터 4WD 디젤 마스터즈      디젤   17011  2019      무사고    흰색
#
#       location  price   wd
# 1           대구   1550  4WD
# 12          경기   3580  4WD
# 14          서울   2350  4WD
# ...

# %%
mohave.reset_index(inplace = True)
mohave.drop(['index'], axis = 1,inplace = True)
mohave
# Out:
#     brand name                info type      km  year accident color location  \
# 0      기아  모하비       가솔린 4WD KV460  가솔린  213823  2011      무사고   검정색       대구
# 1      기아  모하비          디젤 3.0 4WD   디젤   43813  2018      무사고   검정색       경기
# 2      기아  모하비           4WD KV300   디젤   51482  2014      무사고   검정색       서울
# 3      기아  모하비          디젤 3.0 4WD   디젤   57621  2018      무사고   검정색       대구
# 4      기아  모하비          디젤 3.0 4WD   디젤   46818  2018      무사고   검정색       서울
# ..    ...  ...                 ...  ...     ...   ...      ...   ...      ...
# 388    기아  모하비  마스터 4WD 디젤 마스터즈      디젤   17011  2019      무사고    흰색       경기
# 389    기아  모하비  마스터 4WD 디젤 마스터즈      디젤   46372  2019      무사고    흰색       경기
# 390    기아  모하비  마스터 4WD 디젤 마스터즈      디젤   17011  2019      무사고    흰색       경기
# 391    기아  모하비  마스터 4WD 디젤 마스터즈      디젤   17011  2019      무사고    흰색       경기
# 392    기아  모하비  마스터 4WD 디젤 마스터즈      디젤   17011  2019      무사고    흰색       경기
#
#      price   wd
# ...

# %%
# name 행의 문자열 제거
mohave['info'] = mohave.apply(lambda x: x['info'].replace('가솔린',''), axis = 1)
mohave['info'] = mohave.apply(lambda x: x['info'].replace('디젤',''), axis = 1)
mohave['info'] = mohave.apply(lambda x: x['info'].replace('하이브리드',''), axis = 1)
mohave['info'] = mohave.apply(lambda x: x['info'].replace('세부등급 없음',''), axis = 1)
mohave['info'] = mohave.apply(lambda x: x['info'].replace('4WD',''), axis = 1)
mohave['info'] = mohave.apply(lambda x: x['info'].replace('2WD',''), axis = 1)
mohave['info'] = mohave.apply(lambda x: x['info'].strip(), axis = 1)
mohave
# Out:
#     brand name        info type      km  year accident color location  price  \
# 0      기아  모하비       KV460  가솔린  213823  2011      무사고   검정색       대구   1550
# 1      기아  모하비         3.0   디젤   43813  2018      무사고   검정색       경기   3580
# 2      기아  모하비       KV300   디젤   51482  2014      무사고   검정색       서울   2350
# 3      기아  모하비         3.0   디젤   57621  2018      무사고   검정색       대구   3350
# 4      기아  모하비         3.0   디젤   46818  2018      무사고   검정색       서울   3349
# ..    ...  ...         ...  ...     ...   ...      ...   ...      ...    ...
# 388    기아  모하비  마스터   마스터즈   디젤   17011  2019      무사고    흰색       경기   4777
# 389    기아  모하비  마스터   마스터즈   디젤   46372  2019      무사고    흰색       경기   4700
# 390    기아  모하비  마스터   마스터즈   디젤   17011  2019      무사고    흰색       경기   4777
# 391    기아  모하비  마스터   마스터즈   디젤   17011  2019      무사고    흰색       경기   4777
# 392    기아  모하비  마스터   마스터즈   디젤   17011  2019      무사고    흰색       경기   4777
#
#       wd
# 0    4WD
# 1    4WD
# 2    4WD
# ...

# %%
mohave['info'].unique()
# Out:
# array(['KV460', '3.0', 'KV300', 'QV300', 'JV300', '3.0 프레지던트', '3.0 VIP',
#        '3.0 노블레스', '마스터   마스터즈', '마스터   플래티넘'], dtype=object)

# %%
# info열의 프리미엄 스포츠 여부를 upgrade 열에 추가
mohave['upgrade'] = ""

for i in range(0, len(mohave)):
    
    if mohave['info'].str.contains('노블레스')[i]:
        mohave['upgrade'][i] = '노블레스'

    elif mohave['info'].str.contains('프레지던트')[i]:
        mohave['upgrade'][i] = '프레지던트'
        
    elif mohave['info'].str.contains('VIP')[i]:
        mohave['upgrade'][i] = 'VIP'
    
    elif mohave['info'].str.contains('마스터즈')[i]:
        mohave['upgrade'][i] = '마스터즈'
        
    elif mohave['info'].str.contains('플래티넘')[i]:
        mohave['upgrade'][i] = '플래티넘' 
        
    elif mohave['info'].str.contains('KV460')[i]:
        mohave['upgrade'][i] = '기본형' 
        
    elif mohave['info'].str.contains('KV300')[i]:
        mohave['upgrade'][i] = '기본형' 
        
    elif mohave['info'].str.contains('QV300')[i]:
        mohave['upgrade'][i] = '기본형' 

    elif mohave['info'].str.contains('JV300')[i]:
        mohave['upgrade'][i] = '기본형' 
        
    else :
        mohave['upgrade'][i] = '기본형'
mohave
# Out:
#     brand name        info type      km  year accident color location  price  \
# 0      기아  모하비       KV460  가솔린  213823  2011      무사고   검정색       대구   1550
# 1      기아  모하비         3.0   디젤   43813  2018      무사고   검정색       경기   3580
# 2      기아  모하비       KV300   디젤   51482  2014      무사고   검정색       서울   2350
# 3      기아  모하비         3.0   디젤   57621  2018      무사고   검정색       대구   3350
# 4      기아  모하비         3.0   디젤   46818  2018      무사고   검정색       서울   3349
# ..    ...  ...         ...  ...     ...   ...      ...   ...      ...    ...
# 388    기아  모하비  마스터   마스터즈   디젤   17011  2019      무사고    흰색       경기   4777
# 389    기아  모하비  마스터   마스터즈   디젤   46372  2019      무사고    흰색       경기   4700
# 390    기아  모하비  마스터   마스터즈   디젤   17011  2019      무사고    흰색       경기   4777
# 391    기아  모하비  마스터   마스터즈   디젤   17011  2019      무사고    흰색       경기   4777
# 392    기아  모하비  마스터   마스터즈   디젤   17011  2019      무사고    흰색       경기   4777
#
#       wd upgrade
# 0    4WD     기본형
# ...

# %%
mohave[mohave['upgrade'] == 'NaN']
# Out:
# Empty DataFrame
# Columns: [brand, name, info, type, km, year, accident, color, location, price, wd, upgrade]
# Index: []

# %%
# info 행의 문자열 제거
mohave['info'] = mohave.apply(lambda x: x['info'].replace('노블레스',''), axis = 1)
mohave['info'] = mohave.apply(lambda x: x['info'].replace('프레지던트',''), axis = 1)
mohave['info'] = mohave.apply(lambda x: x['info'].replace('VIP',''), axis = 1)
mohave['info'] = mohave.apply(lambda x: x['info'].replace('마스터즈',''), axis = 1)
mohave['info'] = mohave.apply(lambda x: x['info'].replace('플래티넘',''), axis = 1)
mohave['info'] = mohave.apply(lambda x: x['info'].strip(), axis = 1)
mohave
# Out:
#     brand name   info type      km  year accident color location  price   wd  \
# 0      기아  모하비  KV460  가솔린  213823  2011      무사고   검정색       대구   1550  4WD
# 1      기아  모하비    3.0   디젤   43813  2018      무사고   검정색       경기   3580  4WD
# 2      기아  모하비  KV300   디젤   51482  2014      무사고   검정색       서울   2350  4WD
# 3      기아  모하비    3.0   디젤   57621  2018      무사고   검정색       대구   3350  4WD
# 4      기아  모하비    3.0   디젤   46818  2018      무사고   검정색       서울   3349  4WD
# ..    ...  ...    ...  ...     ...   ...      ...   ...      ...    ...  ...
# 388    기아  모하비    마스터   디젤   17011  2019      무사고    흰색       경기   4777  4WD
# 389    기아  모하비    마스터   디젤   46372  2019      무사고    흰색       경기   4700  4WD
# 390    기아  모하비    마스터   디젤   17011  2019      무사고    흰색       경기   4777  4WD
# 391    기아  모하비    마스터   디젤   17011  2019      무사고    흰색       경기   4777  4WD
# 392    기아  모하비    마스터   디젤   17011  2019      무사고    흰색       경기   4777  4WD
#
#     upgrade
# 0       기본형
# 1       기본형
# ...

# %%
df['name'].unique()
# Out:
# array(['K5', '모하비', 'K7', '스포티지', '카니발', '쏘렌토', '레이', 'K9', '포르테', '모닝',
#        'K8', '카렌스', '스팅어', 'K3', '마스터', '오피러스', '프라이드', '로체', '스토닉', '쏘울',
#        '셀토스', '니로', '쎄라토', '옵티마', '봉고III 트럭 CRDi 카고',
#        '더 뉴 봉고III 트럭 CRDi 카고', '봉고3', '쏘렌토R', '카렌스2'], dtype=object)

# %%
sport = df[df['name'] == '스포티지']
sport
# Out:
#       brand  name                   info type      km  year accident color  \
# 4        기아  스포티지        디젤 1.7 2WD 노블레스   디젤  129624  2018      무사고   검정색
# 69       기아  스포티지            가솔린 2.0 2WD  가솔린    5467  2022      무사고   검정색
# 83       기아  스포티지         디젤 2.0 2WD 트렌디   디젤   84774  2018      무사고   검정색
# 98       기아  스포티지         디젤 2.0 4WD 트렌디   디젤   48389  2018      무사고   검정색
# 117      기아  스포티지         디젤 1.7 2WD 트렌디   디젤   67626  2017      무사고   검정색
# ...     ...   ...                    ...  ...     ...   ...      ...   ...
# 11209    기아  스포티지   볼드 2.0 디젤 2WD 인텔리전트    디젤   45410  2018      무사고    흰색
# 11210    기아  스포티지   볼드 2.0 디젤 2WD 인텔리전트    디젤   45410  2018      무사고    흰색
# 11211    기아  스포티지    볼드 2.0 디젤 2WD 노블레스    디젤   15000  2018      무사고    흰색
# 11212    기아  스포티지    R 2WD 디젤 TLX 최고급형     디젤   86688  2011      무사고    흰색
# 11213    기아  스포티지     R 2WD 디젤 TLX 고급형     디젤  125148  2011      무사고    흰색
#
#       location  price   wd
# 4           경기   2100  2WD
# ...

# %%
sport.reset_index(inplace = True)
sport.drop(['index'], axis = 1,inplace = True)
sport
# Out:
#     brand  name                   info type      km  year accident color  \
# 0      기아  스포티지        디젤 1.7 2WD 노블레스   디젤  129624  2018      무사고   검정색
# 1      기아  스포티지            가솔린 2.0 2WD  가솔린    5467  2022      무사고   검정색
# 2      기아  스포티지         디젤 2.0 2WD 트렌디   디젤   84774  2018      무사고   검정색
# 3      기아  스포티지         디젤 2.0 4WD 트렌디   디젤   48389  2018      무사고   검정색
# 4      기아  스포티지         디젤 1.7 2WD 트렌디   디젤   67626  2017      무사고   검정색
# ..    ...   ...                    ...  ...     ...   ...      ...   ...
# 716    기아  스포티지   볼드 2.0 디젤 2WD 인텔리전트    디젤   45410  2018      무사고    흰색
# 717    기아  스포티지   볼드 2.0 디젤 2WD 인텔리전트    디젤   45410  2018      무사고    흰색
# 718    기아  스포티지    볼드 2.0 디젤 2WD 노블레스    디젤   15000  2018      무사고    흰색
# 719    기아  스포티지    R 2WD 디젤 TLX 최고급형     디젤   86688  2011      무사고    흰색
# 720    기아  스포티지     R 2WD 디젤 TLX 고급형     디젤  125148  2011      무사고    흰색
#
#     location  price   wd
# 0         경기   2100  2WD
# 1         대구   2689  2WD
# ...

# %%
sport['info'].unique()
# Out:
# array(['디젤 1.7 2WD 노블레스', '가솔린 2.0 2WD', '디젤 2.0 2WD 트렌디',
#        '디젤 2.0 4WD 트렌디', '디젤 1.7 2WD 트렌디', '디젤 1.6 2WD', '디젤 2.0 2WD',
#        '디젤 2.0 2WD 노블레스', '디젤 2WD TLX', '디젤 4WD 노블레스', '디젤 2WD 프레스티지',
#        '디젤 2WD 노블레스', '디젤 2WD 트렌디', '디젤 2WD 리미티드', '디젤 2.0 2WD 스타일 에디션',
#        '디젤 4WD 트렌디', '디젤 2.0 2WD 프레스티지', '디젤 4WD 리미티드', '디젤 4WD 프레스티지',
#        '가솔린 2.0 2WD 노블레스', '디젤 4WD LX', '디젤 2.0 4WD 노블레스',
#        '디젤 2.0 4WD 프레스티지', '가솔린 터보 GDI 2WD TLX', '디젤 2WD 럭셔리',
#        '디젤(VGT) 2WD TLX', '디젤 4WD TLX', '가솔린 2WD TLX', '디젤(VGT) 2WD 리미티드',
#        '디젤 2WD 에이스', '디젤 2.0 4WD', '디젤 2WD LX', '가솔린 터보 GDI 4WD 리미티드',
#        '가솔린 2WD 터보 GDI 트렌디', '가솔린 2WD 리미티드', '가솔린 1.6 터보 4WD',
#        '가솔린 2WD LX', '가솔린 2WD 프렌드', '디젤 4WD 에이스', '디젤(VGT) 2WD LX',
#        '가솔린 2WD 터보 GDI 에이스', '디젤 2.0 2WD 노블레스플러스', '디젤 1.6 2WD프레스티지',
#        '디젤 2WD TLX최고급형', '가솔린 2.0 2WD시그니쳐 그래비티', '가솔린 2.0 2WD프레스티지',
#        '디젤 2.0 2WD 노블레스세부등급 없음', '디젤 1.7 2WD 노블레스세부등급 없음',
# ...

# %%
for i in range(0,len(sport)):
    if sport['info'].str.contains('시그')[i]:
        print(sport['info'][i])
# Out:
# 가솔린 2.0 2WD시그니쳐 그래비티
# 디젤 2.0 2WD시그니쳐 그래비티
# 가솔린 2.0 2WD시그니쳐
# 디젤 2.0 2WD시그니쳐
# 디젤 2.0 2WD시그니쳐
# 가솔린 2.0 2WD시그니쳐
# 디젤 1.6 2WD시그니쳐
#  볼드 2.0 디젤 2WD 시그니처
#  볼드 2.0 가솔린 2WD 시그니처
#  볼드 2.0 가솔린 2WD 시그니처
#  볼드 2.0 가솔린 2WD 시그니처
#  볼드 2.0 디젤 2WD 시그니처
#  볼드 2.0 가솔린 2WD 시그니처
#  볼드 2.0 가솔린 2WD 시그니처
#  볼드 2.0 가솔린 2WD 시그니처
#  볼드 2.0 디젤 2WD 시그니처
#  볼드 2.0 가솔린 2WD 시그니처
#  볼드 2.0 가솔린 2WD 시그니처

# %%
# info열의 프리미엄 스포츠 여부를 upgrade 열에 추가
sport['upgrade'] = ""

for i in range(0, len(sport)):
    
    if sport['info'].str.contains('스탠다드')[i]:
        sport['upgrade'][i] = '스탠다드'
        
    elif sport['info'].str.contains('스텐다드')[i]:
        sport['upgrade'][i] = '스탠다드'

    elif sport['info'].str.contains('LX')[i]:
        sport['upgrade'][i] = '스탠다드'
        
    elif sport['info'].str.contains('럭셔리')[i]:
        sport['upgrade'][i] = '럭셔리'
    
    elif sport['info'].str.contains('TLX 고급형')[i]:
        sport['upgrade'][i] = '럭셔리'
        
    elif sport['info'].str.contains('TLX 최고급형')[i]:
        sport['upgrade'][i] = '트렌디' 
        
    elif sport['info'].str.contains('트렌디')[i]:
        sport['upgrade'][i] = '트렌디'
        
    elif sport['info'].str.contains('TLX')[i]:
        sport['upgrade'][i] = '럭셔리 트렌디' 
        
    elif sport['info'].str.contains('W 스페셜')[i]:
        sport['upgrade'][i] = 'W 스페셜' 
        
    elif sport['info'].str.contains('스타일 에디션')[i]:
        sport['upgrade'][i] = '스타일 에디션' 
        
    elif sport['info'].str.contains('에이스')[i]:
        sport['upgrade'][i] = '스타일 에디션' 
        
    elif sport['info'].str.contains('노블레스스페셜')[i]:
        sport['upgrade'][i] = '노블레스 스페셜' 
        
    elif sport['info'].str.contains('노블레스 스페셜')[i]:
        sport['upgrade'][i] = '노블레스 스페셜' 
        
    elif sport['info'].str.contains('노블레스 그래비티')[i]:
        sport['upgrade'][i] = '노블레스 스페셜' 
        
    elif sport['info'].str.contains('노블레스')[i]:
        sport['upgrade'][i] = '노블레스'

    elif sport['info'].str.contains('시그니처 스페셜')[i]:
        sport['upgrade'][i] = '시그니처 스페셜' 
        
    elif sport['info'].str.contains('시그니처 그래비티')[i]:
        sport['upgrade'][i] = '시그니처 스페셜' 
        
    elif sport['info'].str.contains('시그니처')[i]:
        sport['upgrade'][i] = '시그니처' 
        
    elif sport['info'].str.contains('시그니쳐')[i]:
        sport['upgrade'][i] = '시그니처' 
        
    elif sport['info'].str.contains('인텔리전트')[i]:
        sport['upgrade'][i] = '시그니처'
        
    elif sport['info'].str.contains('리미티드')[i]:
        sport['upgrade'][i] = '리미티드'
        
    elif sport['info'].str.contains('LIMITED')[i]:
        sport['upgrade'][i] = '리미티드'
        
    elif sport['info'].str.contains('프레스티지')[i]:
        sport['upgrade'][i] = '프레스티지' 
        
    elif sport['info'].str.contains('TLX 세이프티')[i]:
        sport['upgrade'][i] = '프레스티지' 
        
    else :
        sport['upgrade'][i] = '스탠다드'
sport
# Out:
#     brand  name                   info type      km  year accident color  \
# 0      기아  스포티지        디젤 1.7 2WD 노블레스   디젤  129624  2018      무사고   검정색
# 1      기아  스포티지            가솔린 2.0 2WD  가솔린    5467  2022      무사고   검정색
# 2      기아  스포티지         디젤 2.0 2WD 트렌디   디젤   84774  2018      무사고   검정색
# 3      기아  스포티지         디젤 2.0 4WD 트렌디   디젤   48389  2018      무사고   검정색
# 4      기아  스포티지         디젤 1.7 2WD 트렌디   디젤   67626  2017      무사고   검정색
# ..    ...   ...                    ...  ...     ...   ...      ...   ...
# 716    기아  스포티지   볼드 2.0 디젤 2WD 인텔리전트    디젤   45410  2018      무사고    흰색
# 717    기아  스포티지   볼드 2.0 디젤 2WD 인텔리전트    디젤   45410  2018      무사고    흰색
# 718    기아  스포티지    볼드 2.0 디젤 2WD 노블레스    디젤   15000  2018      무사고    흰색
# 719    기아  스포티지    R 2WD 디젤 TLX 최고급형     디젤   86688  2011      무사고    흰색
# 720    기아  스포티지     R 2WD 디젤 TLX 고급형     디젤  125148  2011      무사고    흰색
#
#     location  price   wd upgrade
# 0         경기   2100  2WD    노블레스
# ...

# %%
sport[sport['upgrade'] == 'NaN']
# Out:
# Empty DataFrame
# Columns: [brand, name, info, type, km, year, accident, color, location, price, wd, upgrade]
# Index: []

# %%
# name 행의 문자열 제거
sport['info'] = sport.apply(lambda x: x['info'].replace('가솔린',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('디젤',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('하이브리드',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('세부등급 없음',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('2WD',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('4WD',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].strip(), axis = 1)

# %%
# info 행의 문자열 제거
sport['info'] = sport.apply(lambda x: x['info'].replace('스텐다드',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('LX',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('럭셔리',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('TLX',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('고급형',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('최',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('트렌디',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('W 스페셜',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('스타일 에디션',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('에이스',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('노블레스',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('스페셜',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('그래비티',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('시그니처',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('시그니쳐',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('인텔리전트',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('리미티드',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('LIMITED',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('프레스티지',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].replace('세이프티',''), axis = 1)
sport['info'] = sport.apply(lambda x: x['info'].strip(), axis = 1)
sport
# Out:
#     brand  name    info type      km  year accident color location  price  \
# 0      기아  스포티지     1.7   디젤  129624  2018      무사고   검정색       경기   2100
# 1      기아  스포티지     2.0  가솔린    5467  2022      무사고   검정색       대구   2689
# 2      기아  스포티지     2.0   디젤   84774  2018      무사고   검정색       경기   1450
# 3      기아  스포티지     2.0   디젤   48389  2018      무사고   검정색       광주   1725
# 4      기아  스포티지     1.7   디젤   67626  2017      무사고   검정색       인천   1540
# ..    ...   ...     ...  ...     ...   ...      ...   ...      ...    ...
# 716    기아  스포티지  볼드 2.0   디젤   45410  2018      무사고    흰색       경기   2650
# 717    기아  스포티지  볼드 2.0   디젤   45410  2018      무사고    흰색       경기   2650
# 718    기아  스포티지  볼드 2.0   디젤   15000  2018      무사고    흰색       광주   2450
# 719    기아  스포티지   R   T   디젤   86688  2011      무사고    흰색       경기   1120
# 720    기아  스포티지   R   T   디젤  125148  2011      무사고    흰색       대전    790
#
#       wd upgrade
# 0    2WD    노블레스
# 1    2WD    스탠다드
# 2    2WD     트렌디
# ...

# %%
df['name'].unique()
# Out:
# array(['K5', '모하비', 'K7', '스포티지', '카니발', '쏘렌토', '레이', 'K9', '포르테', '모닝',
#        'K8', '카렌스', '스팅어', 'K3', '마스터', '오피러스', '프라이드', '로체', '스토닉', '쏘울',
#        '셀토스', '니로', '쎄라토', '옵티마', '봉고III 트럭 CRDi 카고',
#        '더 뉴 봉고III 트럭 CRDi 카고', '봉고3', '쏘렌토R', '카렌스2'], dtype=object)

# %%
df['name'] = df.apply(lambda x: x['name'].replace('카렌스2','카렌스'), axis = 1)
df['name'].unique()
# Out:
# array(['K5', '모하비', 'K7', '스포티지', '카니발', '쏘렌토', '레이', 'K9', '포르테', '모닝',
#        'K8', '카렌스', '스팅어', 'K3', '마스터', '오피러스', '프라이드', '로체', '스토닉', '쏘울',
#        '셀토스', '니로', '쎄라토', '옵티마', '봉고III 트럭 CRDi 카고',
#        '더 뉴 봉고III 트럭 CRDi 카고', '봉고3', '쏘렌토R'], dtype=object)

# %%
carnival = df[df['name'] == '카니발']
carnival
# Out:
#      brand name              info type      km  year accident color location  \
# 6       기아  카니발       가솔린 7인승 리무진  가솔린   34516  2019      무사고   검정색       대구
# 7       기아  카니발      9인승 노블레스 스페셜   디젤   72175  2018      무사고   검정색       인천
# 8       기아  카니발       그랜드 카니발 GLX   디젤  104368  2013      무사고   검정색       경기
# 13      기아  카니발         9인승 프레스티지   디젤   39004  2019      무사고   검정색       서울
# 19      기아  카니발         9인승 하이리무진   디젤  106003  2017      무사고   검정색       서울
# ...    ...  ...               ...  ...     ...   ...      ...   ...      ...
# 9859    기아  카니발        11인승 프레스티지   디젤   70370  2019       사고    흰색       인천
# 9861    기아  카니발         9인승 프레스티지   디젤   27745  2019      무사고    흰색       인천
# 9863    기아  카니발  가솔린 7인승 리무진프레지던트  가솔린   42527  2019      무사고   검정색       인천
# 9866    기아  카니발  그랜드 카니발 GLXR 스페셜   디젤  142838  2010      무사고    기타       인천
# 9900    기아  카니발           9인승 럭셔리   디젤   69881  2019      무사고    기타       인천
#
#       price   wd
# 6      3430  2WD
# ...

# %%
carnival.reset_index(inplace = True)
carnival.drop(['index'], axis = 1,inplace = True)
carnival
# Out:
#      brand name              info type      km  year accident color location  \
# 0       기아  카니발       가솔린 7인승 리무진  가솔린   34516  2019      무사고   검정색       대구
# 1       기아  카니발      9인승 노블레스 스페셜   디젤   72175  2018      무사고   검정색       인천
# 2       기아  카니발       그랜드 카니발 GLX   디젤  104368  2013      무사고   검정색       경기
# 3       기아  카니발         9인승 프레스티지   디젤   39004  2019      무사고   검정색       서울
# 4       기아  카니발         9인승 하이리무진   디젤  106003  2017      무사고   검정색       서울
# ...    ...  ...               ...  ...     ...   ...      ...   ...      ...
# 1298    기아  카니발        11인승 프레스티지   디젤   70370  2019       사고    흰색       인천
# 1299    기아  카니발         9인승 프레스티지   디젤   27745  2019      무사고    흰색       인천
# 1300    기아  카니발  가솔린 7인승 리무진프레지던트  가솔린   42527  2019      무사고   검정색       인천
# 1301    기아  카니발  그랜드 카니발 GLXR 스페셜   디젤  142838  2010      무사고    기타       인천
# 1302    기아  카니발           9인승 럭셔리   디젤   69881  2019      무사고    기타       인천
#
#       price   wd
# 0      3430  2WD
# ...

# %%
carnival['info'].unique()
# Out:
# array(['가솔린 7인승 리무진', '9인승 노블레스 스페셜', '그랜드 카니발 GLX', '9인승 프레스티지',
#        '9인승 하이리무진', '9인승 시그니처', '9인승 럭셔리', '가솔린 9인승 하이리무진',
#        '가솔린 7인승 하이리무진', '7인승 리무진', '9인승 노블레스', '가솔린 9인승 하이리무진(특장업체)',
#        '11인승 디럭스', 'GLX', '그랜드 카니발 GX', 'GLX 하이리무진 11인승', '11인승 프레스티지',
#        '가솔린 9인승 노블레스 스페셜', '7인승 하이리무진', '11인승 럭셔리', '9인승 디젤(CRDI) 리미티드',
#        '그랜드 카니발 하이리무진 GLX', '11인승 하이리무진', '가솔린 9인승 노블레스', 'LIMITED',
#        '뉴카니발 리무진 GLX', '그랜드 카니발 President', 'LPI GLX', 'GLX 리무진 9인승',
#        '가솔린 7인승 하이리무진(특장업체)', '뉴카니발 리무진 President', '9인승 디젤(VGT) GX',
#        'GX', '7인승 시그니처', '그랜드 카니발 가솔린 GLX', '그랜드 카니발 가솔린 President',
#        '11인승 노블레스', '7인승 하이리무진(특장업체)', '9인승 디젤(VGT) 리무진', '이지무브 8인승',
#        '뉴카니발 GX', '하이리무진 L290 7인승', '9인승 디젤(VGT) GLX', '가솔린 7인승 시그니처',
#        '뉴카니발 GLX', '가솔린 9인승 프레스티지', 'LPI GX', '9인승 하이리무진(특장업체)',
#        '9인승 디젤(CRDI) GLX', '가솔린 7인승 노블레스', '9인승 디젤 파크', '9인승 디젤(CRDI) GX',
#        '7인승 노블레스', '어린이 보호차', '11인승 어린이 보호차', '그랜드 카니발 LPI GX',
# ...

# %%
# name 행의 문자열 제거
carnival['info'] = carnival.apply(lambda x: x['info'].replace('세부등급 없음',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].strip(), axis = 1)
carnival
# Out:
#      brand name              info type      km  year accident color location  \
# 0       기아  카니발       가솔린 7인승 리무진  가솔린   34516  2019      무사고   검정색       대구
# 1       기아  카니발      9인승 노블레스 스페셜   디젤   72175  2018      무사고   검정색       인천
# 2       기아  카니발       그랜드 카니발 GLX   디젤  104368  2013      무사고   검정색       경기
# 3       기아  카니발         9인승 프레스티지   디젤   39004  2019      무사고   검정색       서울
# 4       기아  카니발         9인승 하이리무진   디젤  106003  2017      무사고   검정색       서울
# ...    ...  ...               ...  ...     ...   ...      ...   ...      ...
# 1298    기아  카니발        11인승 프레스티지   디젤   70370  2019       사고    흰색       인천
# 1299    기아  카니발         9인승 프레스티지   디젤   27745  2019      무사고    흰색       인천
# 1300    기아  카니발  가솔린 7인승 리무진프레지던트  가솔린   42527  2019      무사고   검정색       인천
# 1301    기아  카니발  그랜드 카니발 GLXR 스페셜   디젤  142838  2010      무사고    기타       인천
# 1302    기아  카니발           9인승 럭셔리   디젤   69881  2019      무사고    기타       인천
#
#       price   wd
# 0      3430  2WD
# ...

# %%
# info열의 프리미엄 스포츠 여부를 upgrade 열에 추가
carnival['upgrade'] = ""

for i in range(0, len(carnival)):
    
    if carnival['info'].str.contains('럭셔리')[i]:
        carnival['upgrade'][i] = '럭셔리'

    elif carnival['info'].str.contains('디럭스')[i]:
        carnival['upgrade'][i] = '디럭스'
        
    elif carnival['info'].str.contains('노블레스 스페셜')[i]:
        carnival['upgrade'][i] = '노블레스 스페셜'
    
    elif carnival['info'].str.contains('프레스티지')[i]:
        carnival['upgrade'][i] = '프레스티지'
        
    elif carnival['info'].str.contains('시그니처')[i]:
        carnival['upgrade'][i] = '시그니처' 
        
    elif carnival['info'].str.contains('VIP')[i]:
        carnival['upgrade'][i] = 'VIP'
        
    elif carnival['info'].str.contains('프레지던트')[i]:
        carnival['upgrade'][i] = '프레지던트' 
        
    elif carnival['info'].str.contains('President')[i]:
        carnival['upgrade'][i] = '프레지던트' 
        
    elif carnival['info'].str.contains('노블레스')[i]:
        carnival['upgrade'][i] = '노블레스' 
        
    elif carnival['info'].str.contains('GX')[i]:
        carnival['upgrade'][i] = 'GX' 
        
    elif carnival['info'].str.contains('GLX')[i]:
        carnival['upgrade'][i] = 'GLX' 
        
    elif carnival['info'].str.contains('리미티드')[i]:
        carnival['upgrade'][i] = '리미티드' 
        
    elif carnival['info'].str.contains('LIMITED')[i]:
        carnival['upgrade'][i] = '리미티드' 
        
    elif carnival['info'].str.contains('어린이')[i]:
        carnival['upgrade'][i] = '프레스티지'
        
    elif carnival['info'].str.contains('가솔린 9인승 하이리무진')[i]:
        carnival['upgrade'][i] = '시그니처' 
        
    elif carnival['info'].str.contains('가솔린 11인승 하이리무진')[i]:
        carnival['upgrade'][i] = '시그니처' 
        
    elif carnival['info'].str.contains('이지무브')[i]:
        carnival['upgrade'][i] = 'GLX' 
        
    elif carnival['info'].str.contains('9인승 하이리무진')[i] and carnival['type'][i] == '디젤' :
        carnival['upgrade'][i] = '시그니처' 
        
    elif carnival['info'].str.contains('7인승 하이리무진')[i] and carnival['type'][i] == '디젤' :
        carnival['upgrade'][i] = '시그니처'
        
    elif carnival['info'].str.contains('9인승 하이리무진')[i] and carnival['type'][i] == '가솔린' :
        carnival['upgrade'][i] = '시그니처' 
        
    elif carnival['info'].str.contains('11인승 하이리무진')[i] and carnival['type'][i] == '가솔린' :
        carnival['upgrade'][i] = '시그니처'
        
    elif carnival['info'].str.contains('트립')[i]:
        carnival['upgrade'][i] = '트립'
        
    elif carnival['info'].str.contains('랜드')[i]:
        carnival['upgrade'][i] = '랜드'
        
    elif carnival['info'].str.contains('파크')[i]:
        carnival['upgrade'][i] = '파크'
        
    else :
        carnival['upgrade'][i] = '디럭스'
carnival
# Out:
#      brand name              info type      km  year accident color location  \
# 0       기아  카니발       가솔린 7인승 리무진  가솔린   34516  2019      무사고   검정색       대구
# 1       기아  카니발      9인승 노블레스 스페셜   디젤   72175  2018      무사고   검정색       인천
# 2       기아  카니발       그랜드 카니발 GLX   디젤  104368  2013      무사고   검정색       경기
# 3       기아  카니발         9인승 프레스티지   디젤   39004  2019      무사고   검정색       서울
# 4       기아  카니발         9인승 하이리무진   디젤  106003  2017      무사고   검정색       서울
# ...    ...  ...               ...  ...     ...   ...      ...   ...      ...
# 1298    기아  카니발        11인승 프레스티지   디젤   70370  2019       사고    흰색       인천
# 1299    기아  카니발         9인승 프레스티지   디젤   27745  2019      무사고    흰색       인천
# 1300    기아  카니발  가솔린 7인승 리무진프레지던트  가솔린   42527  2019      무사고   검정색       인천
# 1301    기아  카니발  그랜드 카니발 GLXR 스페셜   디젤  142838  2010      무사고    기타       인천
# 1302    기아  카니발           9인승 럭셔리   디젤   69881  2019      무사고    기타       인천
#
#       price   wd   upgrade
# ...

# %%
carnival[carnival['upgrade'] == 'NaN']
# Out:
# Empty DataFrame
# Columns: [brand, name, info, type, km, year, accident, color, location, price, wd, upgrade]
# Index: []

# %%
carnival[carnival['upgrade'] == 'NaN']['info'].unique()
# Out:
# array([], dtype=object)

# %%
carnival['info'] = carnival.apply(lambda x: x['info'].replace('세부등급 없음',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('럭셔리',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('디럭스',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('노블레스',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('스페셜',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('프레스티지',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('시그니처',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('프레지던트',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('VIP',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('LIMITED',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('리미티드',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('GX',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('GLX',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('President',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('어린이 보호차',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('이지무브',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('트립',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('랜드',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('파크',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('그 카니발',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('(특장업체)',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('아웃도어',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('프리미엄',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('그 팩',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('기본형',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('최고급형',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].replace('뉴 카니발',''), axis = 1)
carnival['info'] = carnival.apply(lambda x: x['info'].strip(), axis = 1)
carnival
# Out:
#      brand name         info type      km  year accident color location  \
# 0       기아  카니발  가솔린 7인승 리무진  가솔린   34516  2019      무사고   검정색       대구
# 1       기아  카니발          9인승   디젤   72175  2018      무사고   검정색       인천
# 2       기아  카니발                디젤  104368  2013      무사고   검정색       경기
# 3       기아  카니발          9인승   디젤   39004  2019      무사고   검정색       서울
# 4       기아  카니발    9인승 하이리무진   디젤  106003  2017      무사고   검정색       서울
# ...    ...  ...          ...  ...     ...   ...      ...   ...      ...
# 1298    기아  카니발         11인승   디젤   70370  2019       사고    흰색       인천
# 1299    기아  카니발          9인승   디젤   27745  2019      무사고    흰색       인천
# 1300    기아  카니발  가솔린 7인승 리무진  가솔린   42527  2019      무사고   검정색       인천
# 1301    기아  카니발            R   디젤  142838  2010      무사고    기타       인천
# 1302    기아  카니발          9인승   디젤   69881  2019      무사고    기타       인천
#
#       price   wd   upgrade
# 0      3430  2WD       디럭스
# 1      2620  2WD  노블레스 스페셜
# ...

# %%
carnival['info'].unique()
# Out:
# array(['가솔린 7인승 리무진', '9인승', '', '9인승 하이리무진', '가솔린 9인승 하이리무진',
#        '가솔린 7인승 하이리무진', '7인승 리무진', '11인승', '하이리무진 11인승', '가솔린 9인승',
#        '7인승 하이리무진', '9인승 디젤(CRDI)', '하이리무진', '11인승 하이리무진', '뉴카니발 리무진',
#        'LPI', '리무진 9인승', '9인승 디젤(VGT)', '7인승', '가솔린', '9인승 디젤(VGT) 리무진',
#        '8인승', '뉴카니발', '하이리무진 L290 7인승', '가솔린 7인승', '9인승 디젤',
#        '디젤 2.2 (7인승)', '고급형', 'R', '가솔린 3.5 (9인승)하이리무진'], dtype=object)

# %%
sorento1 = df[df['name'] == '쏘렌토']
sorento2 = df[df['name'] == '쏘렌토R']
sorento = pd.concat([sorento1,sorento2])

# %%
sorento.reset_index(inplace = True)
sorento.drop(['index'], axis = 1,inplace = True)
sorento
# Out:
#     brand  name                   info type      km  year accident color  \
# 0      기아   쏘렌토             디젤 2.0 4WD   디젤   93132  2016      무사고   검정색
# 1      기아   쏘렌토             디젤 2.0 2WD   디젤  181517  2014      무사고   검정색
# 2      기아   쏘렌토             디젤 2.2 2WD   디젤   61468  2016      무사고   검정색
# 3      기아   쏘렌토             디젤 2.0 4WD   디젤   95833  2017      무사고   검정색
# 4      기아   쏘렌토             디젤 2.0 2WD   디젤   85485  2018      무사고   검정색
# ..    ...   ...                    ...  ...     ...   ...      ...   ...
# 873    기아  쏘렌토R   디젤 2.0 2WD TLX 스페셜     디젤  126563  2013      무사고    흰색
# 874    기아  쏘렌토R   디젤 2.0 2WD TLX 스페셜     디젤  111209  2012      무사고    흰색
# 875    기아  쏘렌토R  디젤 2.0 2WD TLX 최고급형     디젤  110700  2009      무사고    흰색
# 876    기아  쏘렌토R  디젤 2.0 2WD TLX 최고급형     디젤  105161  2010      무사고    흰색
# 877    기아  쏘렌토R   디젤 2.0 2WD TLX 스페셜     디젤  126563  2013      무사고    흰색
#
#     location  price   wd
# 0         광주   2180  4WD
# 1         광주   1070  2WD
# ...

# %%
sorento['info'].unique()
# Out:
# array(['디젤 2.0 4WD', '디젤 2.0 2WD', '디젤 2.2 2WD', '디젤 2.2 4WD',
#        '가솔린 2.0 터보 2WD', '디젤 2.0 2WD TLX', '7인승 디젤(VGT) 4WD TLX',
#        '7인승 디젤(VGT) 2WD TLX', 'HEV 1.6 2WD', '디젤 2.0 2WD 리미티드',
#        '디젤 2.2 4WD TLX', '가솔린 2.0 터보 4WD', 'HEV 1.6 4WD',
#        '디젤(CRDI) 2WD TLX', '가솔린 2.5T 2WD', '디젤 2.2 2WD TLX',
#        '디젤(CRDI) 2WD LX', '가솔린 2.5T 4WD', '가솔린 3.3 4WD', '디젤 2.0 2WD LX',
#        '7인승 디젤(CRDI) 2WD LX', '7인승 디젤(VGT) 2WD LX', 'LPG 2.7 2WD TLX',
#        '디젤 2.2 4WD LX', '7인승 디젤(VGT) 4WD LX', '디젤 2.0 2WD프레스티지',
#        '가솔린 2.0 터보 2WD노블레스', '가솔린 터보 1.6 4WD시그니처', '디젤 2.0 4WD프레스티지',
#        '디젤 2.0 2WD노블레스 스페셜', '디젤 2.0 4WD노블레스 스페셜', '디젤 2.0 2WD노블레스',
#        '디젤 2.0 4WD노블레스', '디젤 2.2 2WD노블레스 스페셜', '디젤 2.2 2WD노블레스',
#        '디젤 2.0 2WD마스터', '디젤 2.0 2WD럭셔리', '디젤 2.2 2WD시그니처',
#        '디젤 2.0 2WD트렌디', '디젤 2.2 4WD노블레스', '디젤 2.0 2WD마스터 스페셜',
#        '가솔린 터보 1.6 2WD시그니처', '가솔린 2.0 터보 4WD노블레스',
#        '가솔린 2.0 터보 2WD마스터 스페셜', '디젤 2.2 4WD 리미티드프리미엄',
# ...

# %%
# info열의 프리미엄 스포츠 여부를 upgrade 열에 추가
sorento['upgrade'] = ""

for i in range(0, len(sorento)):
    
    if sorento['info'].str.contains('디럭스')[i]:
        sorento['upgrade'][i] = '디럭스'

    elif sorento['info'].str.contains('럭셔리')[i]:
        sorento['upgrade'][i] = '럭셔리'
        
    elif sorento['info'].str.contains('트렌디')[i]:
        sorento['upgrade'][i] = '트렌디'
    
    elif sorento['info'].str.contains('프레스티지')[i]:
        sorento['upgrade'][i] = '프레스티지'
        
    elif sorento['info'].str.contains('노블레스 스페셜')[i]:
        sorento['upgrade'][i] = '노블레스 스페셜' 
        
    elif sorento['info'].str.contains('노블레스')[i]:
        sorento['upgrade'][i] = '노블레스'
        
    elif sorento['info'].str.contains('시그니처')[i]:
        sorento['upgrade'][i] = '시그니처' 
        
    elif sorento['info'].str.contains('그래비티')[i]:
        sorento['upgrade'][i] = '그래비티' 
        
    elif sorento['info'].str.contains('마스터 스페셜')[i]:
        sorento['upgrade'][i] = '마스터 스페셜' 
        
    elif sorento['info'].str.contains('마스터')[i]:
        sorento['upgrade'][i] = '마스터' 
        
    elif sorento['info'].str.contains('LX')[i]:
        sorento['upgrade'][i] = 'LX' 
        
    elif sorento['info'].str.contains('TLX')[i]:
        sorento['upgrade'][i] = 'TLX' 
        
    elif sorento['info'].str.contains('TLX 스페셜')[i]:
        sorento['upgrade'][i] = 'TLX 스페셜' 
        
    elif sorento['info'].str.contains('리미티드')[i]:
        sorento['upgrade'][i] = '리미티드'
        
    elif sorento['info'].str.contains('프리미엄')[i]:
        sorento['upgrade'][i] = '프리미엄' 
        
    else :
        sorento['upgrade'][i] = '디럭스'
sorento
# Out:
#     brand  name                   info type      km  year accident color  \
# 0      기아   쏘렌토             디젤 2.0 4WD   디젤   93132  2016      무사고   검정색
# 1      기아   쏘렌토             디젤 2.0 2WD   디젤  181517  2014      무사고   검정색
# 2      기아   쏘렌토             디젤 2.2 2WD   디젤   61468  2016      무사고   검정색
# 3      기아   쏘렌토             디젤 2.0 4WD   디젤   95833  2017      무사고   검정색
# 4      기아   쏘렌토             디젤 2.0 2WD   디젤   85485  2018      무사고   검정색
# ..    ...   ...                    ...  ...     ...   ...      ...   ...
# 873    기아  쏘렌토R   디젤 2.0 2WD TLX 스페셜     디젤  126563  2013      무사고    흰색
# 874    기아  쏘렌토R   디젤 2.0 2WD TLX 스페셜     디젤  111209  2012      무사고    흰색
# 875    기아  쏘렌토R  디젤 2.0 2WD TLX 최고급형     디젤  110700  2009      무사고    흰색
# 876    기아  쏘렌토R  디젤 2.0 2WD TLX 최고급형     디젤  105161  2010      무사고    흰색
# 877    기아  쏘렌토R   디젤 2.0 2WD TLX 스페셜     디젤  126563  2013      무사고    흰색
#
#     location  price   wd upgrade
# 0         광주   2180  4WD     디럭스
# ...

# %%
sorento[sorento['upgrade'] == 'NaN']
# Out:
# Empty DataFrame
# Columns: [brand, name, info, type, km, year, accident, color, location, price, wd, upgrade]
# Index: []

# %%
sorento['info'] = sorento.apply(lambda x: x['info'].replace('4WD',''), axis = 1)
sorento['info'] = sorento.apply(lambda x: x['info'].replace('2WD',''), axis = 1)
sorento['info'] = sorento.apply(lambda x: x['info'].replace('디젤',''), axis = 1)
sorento['info'] = sorento.apply(lambda x: x['info'].replace('가솔린',''), axis = 1)
sorento['info'] = sorento.apply(lambda x: x['info'].replace('리미티드',''), axis = 1)
sorento['info'] = sorento.apply(lambda x: x['info'].replace('프레스티지',''), axis = 1)
sorento['info'] = sorento.apply(lambda x: x['info'].replace('노블레스',''), axis = 1)
sorento['info'] = sorento.apply(lambda x: x['info'].replace('럭셔리',''), axis = 1)
sorento['info'] = sorento.apply(lambda x: x['info'].replace('TLX',''), axis = 1)
sorento['info'] = sorento.apply(lambda x: x['info'].replace('프리미엄',''), axis = 1)
sorento['info'] = sorento.apply(lambda x: x['info'].replace('스페셜',''), axis = 1)
sorento['info'] = sorento.apply(lambda x: x['info'].replace('최고급형',''), axis = 1)
sorento['info'] = sorento.apply(lambda x: x['info'].replace('고급형',''), axis = 1)
sorento['info'] = sorento.apply(lambda x: x['info'].replace('LX',''), axis = 1)
sorento['info'] = sorento.apply(lambda x: x['info'].replace('마스터',''), axis = 1)
sorento['info'] = sorento.apply(lambda x: x['info'].replace('시그니처',''), axis = 1)
sorento['info'] = sorento.apply(lambda x: x['info'].replace('트렌디',''), axis = 1)
sorento['info'] = sorento.apply(lambda x: x['info'].strip(), axis = 1)
sorento
# Out:
#     brand  name info type      km  year accident color location  price   wd  \
# 0      기아   쏘렌토  2.0   디젤   93132  2016      무사고   검정색       광주   2180  4WD
# 1      기아   쏘렌토  2.0   디젤  181517  2014      무사고   검정색       광주   1070  2WD
# 2      기아   쏘렌토  2.2   디젤   61468  2016      무사고   검정색       대구   2430  2WD
# 3      기아   쏘렌토  2.0   디젤   95833  2017      무사고   검정색       경기   1820  4WD
# 4      기아   쏘렌토  2.0   디젤   85485  2018      무사고   검정색       울산   2090  2WD
# ..    ...   ...  ...  ...     ...   ...      ...   ...      ...    ...  ...
# 873    기아  쏘렌토R  2.0   디젤  126563  2013      무사고    흰색       대전   1430  2WD
# 874    기아  쏘렌토R  2.0   디젤  111209  2012      무사고    흰색       광주   1399  2WD
# 875    기아  쏘렌토R  2.0   디젤  110700  2009      무사고    흰색       광주    930  2WD
# 876    기아  쏘렌토R  2.0   디젤  105161  2010      무사고    흰색       전북    880  2WD
# 877    기아  쏘렌토R  2.0   디젤  126563  2013      무사고    흰색       대전   1430  2WD
#
#     upgrade
# 0       디럭스
# 1       디럭스
# 2       디럭스
# ...

# %%
sorento['info'].unique()
# Out:
# array(['2.0', '2.2', '2.0 터보', '7인승 (VGT)', 'HEV 1.6', '(CRDI)', '2.5T',
#        '3.3', '7인승 (CRDI)', 'LPG 2.7', '터보 1.6', '2.5 VGT',
#        '2.5 커먼레일 WGT', '', '2.0  LIMITED', '2.2  LIMITED'], dtype=object)

# %%
ray = df[df['name'] == '레이']
ray
# Out:
#       brand name               info type     km  year accident color location  \
# 11       기아   레이              프레스티지  가솔린  39097  2018      무사고   검정색       경기
# 59       기아   레이               시그니처  가솔린   4256  2021      무사고   검정색       경기
# 108      기아   레이              프레스티지  가솔린  16857  2019      무사고   검정색       충남
# 155      기아   레이              프레스티지  가솔린  21849  2019      무사고   검정색       경기
# 185      기아   레이                디럭스  가솔린  57297  2016      무사고   검정색       서울
# ...     ...  ...                ...  ...    ...   ...      ...   ...      ...
# 10658    기아   레이  1.0 가솔린 프레스티지      가솔린   2947  2017      무사고    흰색       경기
# 10659    기아   레이    1.0 가솔린 럭셔리      가솔린  66305  2015      무사고    흰색       전북
# 10660    기아   레이  1.0 가솔린 프레스티지      가솔린  95000  2016      무사고    흰색       경기
# 10661    기아   레이    1.0 가솔린 럭셔리      가솔린  68724  2015      무사고    흰색       경기
# 10662    기아   레이  1.0 가솔린 프레스티지      가솔린  81508  2012      무사고    흰색       경기
#
#        price   wd
# ...

# %%
ray.reset_index(inplace = True)
ray.drop(['index'], axis = 1,inplace = True)
ray
# Out:
#     brand name               info type     km  year accident color location  \
# 0      기아   레이              프레스티지  가솔린  39097  2018      무사고   검정색       경기
# 1      기아   레이               시그니처  가솔린   4256  2021      무사고   검정색       경기
# 2      기아   레이              프레스티지  가솔린  16857  2019      무사고   검정색       충남
# 3      기아   레이              프레스티지  가솔린  21849  2019      무사고   검정색       경기
# 4      기아   레이                디럭스  가솔린  57297  2016      무사고   검정색       서울
# ..    ...  ...                ...  ...    ...   ...      ...   ...      ...
# 962    기아   레이  1.0 가솔린 프레스티지      가솔린   2947  2017      무사고    흰색       경기
# 963    기아   레이    1.0 가솔린 럭셔리      가솔린  66305  2015      무사고    흰색       전북
# 964    기아   레이  1.0 가솔린 프레스티지      가솔린  95000  2016      무사고    흰색       경기
# 965    기아   레이    1.0 가솔린 럭셔리      가솔린  68724  2015      무사고    흰색       경기
# 966    기아   레이  1.0 가솔린 프레스티지      가솔린  81508  2012      무사고    흰색       경기
#
#      price   wd
# 0     1350  2WD
# 1     1470  2WD
# ...

# %%
ray['info'].unique()
# Out:
# array(['프레스티지', '시그니처', '디럭스', '럭셔리', '터보 프레스티지', '밴', '터보', '프레스티지 바이퓨얼',
#        'LPI 프레스티지', '밴 고급형', '터보 럭셔리', '트렌디', '럭셔리 바이퓨얼', '디럭스 스페셜',
#        '스탠다드', '밴고급형', '밴프레스티지 스폐셜', '밴럭셔리', 'LPi 프레스티지', '캠핑카', 'EV',
#        '1.0 가솔린 Turbo 럭셔리   ', '1.0 가솔린 디럭스    ', '1.0 가솔린 럭셔리    ',
#        '1.0 가솔린 디럭스 스페셜   ', '1.0 가솔린 프레스티지    ',
#        '1.0 가솔린 Turbo 프레스티지   ', '1.0 가솔린 에코플러스 럭셔리   ',
#        '1.0 가솔린 Turbo 기본   '], dtype=object)

# %%
# info열의 프리미엄 스포츠 여부를 upgrade 열에 추가
ray['upgrade'] = ""

for i in range(0, len(ray)):
    
    if ray['info'].str.contains('디럭스')[i]:
        ray['upgrade'][i] = '디럭스'

    elif ray['info'].str.contains('럭셔리')[i]:
        ray['upgrade'][i] = '럭셔리'
        
    elif ray['info'].str.contains('트렌디')[i]:
        ray['upgrade'][i] = '트렌디'
    
    elif ray['info'].str.contains('프레스티지 스페셜')[i]:
        ray['upgrade'][i] = '프레스티지 스페셜'
        
    elif ray['info'].str.contains('프레스티지')[i]:
        ray['upgrade'][i] = '프레스티지' 
        
    elif ray['info'].str.contains('스탠다드')[i]:
        ray['upgrade'][i] = '스탠다드' 
        
    elif ray['info'].str.contains('시그니처')[i]:
        ray['upgrade'][i] = '시그니처' 
        
    elif ray['info'].str.contains('캠핑카')[i]:
        ray['upgrade'][i] = '캠핑카' 
        
    elif ray['info'].str.contains('고급형')[i]:
        ray['upgrade'][i] = '고급형' 
        
    else :
        ray['upgrade'][i] = '스탠다드'
ray
# Out:
#     brand name               info type     km  year accident color location  \
# 0      기아   레이              프레스티지  가솔린  39097  2018      무사고   검정색       경기
# 1      기아   레이               시그니처  가솔린   4256  2021      무사고   검정색       경기
# 2      기아   레이              프레스티지  가솔린  16857  2019      무사고   검정색       충남
# 3      기아   레이              프레스티지  가솔린  21849  2019      무사고   검정색       경기
# 4      기아   레이                디럭스  가솔린  57297  2016      무사고   검정색       서울
# ..    ...  ...                ...  ...    ...   ...      ...   ...      ...
# 962    기아   레이  1.0 가솔린 프레스티지      가솔린   2947  2017      무사고    흰색       경기
# 963    기아   레이    1.0 가솔린 럭셔리      가솔린  66305  2015      무사고    흰색       전북
# 964    기아   레이  1.0 가솔린 프레스티지      가솔린  95000  2016      무사고    흰색       경기
# 965    기아   레이    1.0 가솔린 럭셔리      가솔린  68724  2015      무사고    흰색       경기
# 966    기아   레이  1.0 가솔린 프레스티지      가솔린  81508  2012      무사고    흰색       경기
#
#      price   wd upgrade
# 0     1350  2WD   프레스티지
# ...

# %%
ray[ray['upgrade'] == 'NaN']
# Out:
# Empty DataFrame
# Columns: [brand, name, info, type, km, year, accident, color, location, price, wd, upgrade]
# Index: []

# %%
K9 = df[df['name'] == 'K9']
K9
# Out:
#      brand name                   info type      km  year accident color  \
# 15      기아   K9          3.3 GDI 프레스티지  가솔린  134112  2017      무사고   검정색
# 21      기아   K9            3.8 GDI AWD  가솔린   13457  2021      무사고   검정색
# 26      기아   K9            3.8 GDI AWD  가솔린   33640  2019      무사고   검정색
# 27      기아   K9            3.8 GDI VIP  가솔린   70639  2017      무사고   검정색
# 63      기아   K9            3.8 GDI AWD  가솔린   99246  2019      무사고   검정색
# ...    ...  ...                    ...  ...     ...   ...      ...   ...
# 9796    기아   K9  3.3 T-GDI AWD그랜드 마스터즈  가솔린   11260  2021      무사고    흰색
# 9808    기아   K9        3.3 T-GDI마스터즈 Ⅱ  가솔린   35269  2019     단순교환    회색
# 9871    기아   K9       3.8 GDI AWD플래티넘Ⅱ  가솔린   59281  2019      무사고   검정색
# 9876    기아   K9    3.8 GDI AWD베스트 셀렉션Ⅰ  가솔린   20634  2021      무사고   검정색
# 9886    기아   K9  3.3 T-GDI AWD그랜드 마스터즈  가솔린   54359  2020      무사고   검정색
#
#      location  price   wd
# 15         대구   1899  2WD
# 21         경기   4830  AWD
# ...

# %%
K9.reset_index(inplace = True)
K9.drop(['index'], axis = 1,inplace = True)
K9
# Out:
#     brand name                   info type      km  year accident color  \
# 0      기아   K9          3.3 GDI 프레스티지  가솔린  134112  2017      무사고   검정색
# 1      기아   K9            3.8 GDI AWD  가솔린   13457  2021      무사고   검정색
# 2      기아   K9            3.8 GDI AWD  가솔린   33640  2019      무사고   검정색
# 3      기아   K9            3.8 GDI VIP  가솔린   70639  2017      무사고   검정색
# 4      기아   K9            3.8 GDI AWD  가솔린   99246  2019      무사고   검정색
# ..    ...  ...                    ...  ...     ...   ...      ...   ...
# 483    기아   K9  3.3 T-GDI AWD그랜드 마스터즈  가솔린   11260  2021      무사고    흰색
# 484    기아   K9        3.3 T-GDI마스터즈 Ⅱ  가솔린   35269  2019     단순교환    회색
# 485    기아   K9       3.8 GDI AWD플래티넘Ⅱ  가솔린   59281  2019      무사고   검정색
# 486    기아   K9    3.8 GDI AWD베스트 셀렉션Ⅰ  가솔린   20634  2021      무사고   검정색
# 487    기아   K9  3.3 T-GDI AWD그랜드 마스터즈  가솔린   54359  2020      무사고   검정색
#
#     location  price   wd
# 0         대구   1899  2WD
# 1         경기   4830  AWD
# ...

# %%
K9['info'].unique()
# Out:
# array(['3.3 GDI 프레스티지', '3.8 GDI AWD', '3.8 GDI VIP', '3.8 GDI',
#        '3.3 GDI', '3.3 T-GDI AWD', '3.8 GDI 노블레스', '5.0 GDI 퀀텀',
#        '3.3 GDI 노블레스', '3.8 GDI 이그제큐티브', '3.3 T-GDI', '3.3 GDI 이그제큐티브',
#        '3.8 GDI RVIP', '3.8 GDI 프레스티지', '5.0 GDI AWD', '3.3 GDI RVIP',
#        '3.3 GDI AWD', '3.8 GDI 프레지던트', '3.8 GDI AWD플래티넘Ⅲ',
#        '3.3 GDI 노블레스스페셜', '3.3 T-GDI마스터즈 Ⅱ', '3.3 T-GDI AWD마스터즈 Ⅱ',
#        '3.3 T-GDI AWD그랜드 마스터즈', '3.8 GDI AWD그랜드 플래티넘',
#        '3.8 GDI AWD베스트 셀렉션Ⅰ', '3.8 GDI플래티넘Ⅰ', '3.3 T-GDI AWD마스터즈 Ⅲ',
#        '3.8 GDI AWD플래티넘Ⅱ', '3.3 GDI 프레스티지기본형', '3.3 GDI 노블레스기본형',
#        '3.8 GDI AWD플래티넘Ⅰ', '3.3 GDI AWD법인전용 고급형', '3.3 T-GDI AWD베스트 셀렉션Ⅱ'],
#       dtype=object)

# %%
# info열의 프리미엄 스포츠 여부를 upgrade 열에 추가
K9['upgrade'] = ""

for i in range(0, len(K9)):
    
    if K9['info'].str.contains('5.0 GDI')[i]:
        K9['upgrade'][i] = '퀸텀'

    elif K9['info'].str.contains('플래티넘 Ⅰ')[i]:
        K9['upgrade'][i] = '플래티넘'
        
    elif K9['info'].str.contains('플래티넘 Ⅱ')[i]:
        K9['upgrade'][i] = '플래티넘'
        
    elif K9['info'].str.contains('플래티넘 Ⅲ')[i]:
        K9['upgrade'][i] = '플래티넘'
        
    elif K9['info'].str.contains('3.8 GDI')[i] and 'AWD' not in  K9['info'][i]: 
        K9['upgrade'][i] = '플래티넘'
        
    elif K9['info'].str.contains('그랜드 플래티넘')[i]:
        K9['upgrade'][i] = '그랜드 플래티넘'
        
    elif K9['info'].str.contains('플래티넘')[i]:
        K9['upgrade'][i] = '플래티넘'
        
    elif K9['info'].str.contains('베스트 셀렉션Ⅰ')[i]:
        K9['upgrade'][i] = '베스트 셀렉션 1'
        
    elif K9['info'].str.contains('베스트 셀렉션Ⅱ')[i]:
        K9['upgrade'][i] = '베스트 셀렉션 2'
        
    elif K9['info'].str.contains('마스터즈 Ⅰ')[i]:
        K9['upgrade'][i] = '마스터즈'
        
    elif K9['info'].str.contains('마스터즈 Ⅱ')[i]:
        K9['upgrade'][i] = '마스터즈'
        
    elif K9['info'].str.contains('마스터즈 Ⅲ')[i]:
        K9['upgrade'][i] = '마스터즈'
    
    elif K9['info'].str.contains('그랜드 마스터즈')[i]:
        K9['upgrade'][i] = '그랜드 마스터즈'
        
    elif K9['info'].str.contains('프레스티지 스페셜')[i]:
        K9['upgrade'][i] = '프레스티지 스페셜' 
        
    elif K9['info'].str.contains('프레스티지')[i]:
        K9['upgrade'][i] = '프레스티지'
        
    elif K9['info'].str.contains('이그제큐티브')[i]:
        K9['upgrade'][i] = '이그제큐티브' 
        
    elif K9['info'].str.contains('노블레스 스페셜')[i]:
        K9['upgrade'][i] = '노블레스 스페셜' 
        
    elif K9['info'].str.contains('노블레스')[i]:
        K9['upgrade'][i] = '노블레스' 
        
    elif K9['info'].str.contains('RVIP')[i]:
        K9['upgrade'][i] = 'RVIP' 
        
    elif K9['info'].str.contains('VIP')[i]:
        K9['upgrade'][i] = 'VIP'
        
    else :
        K9['upgrade'][i] = '프레스티지'
K9
# Out:
#     brand name                   info type      km  year accident color  \
# 0      기아   K9          3.3 GDI 프레스티지  가솔린  134112  2017      무사고   검정색
# 1      기아   K9            3.8 GDI AWD  가솔린   13457  2021      무사고   검정색
# 2      기아   K9            3.8 GDI AWD  가솔린   33640  2019      무사고   검정색
# 3      기아   K9            3.8 GDI VIP  가솔린   70639  2017      무사고   검정색
# 4      기아   K9            3.8 GDI AWD  가솔린   99246  2019      무사고   검정색
# ..    ...  ...                    ...  ...     ...   ...      ...   ...
# 483    기아   K9  3.3 T-GDI AWD그랜드 마스터즈  가솔린   11260  2021      무사고    흰색
# 484    기아   K9        3.3 T-GDI마스터즈 Ⅱ  가솔린   35269  2019     단순교환    회색
# 485    기아   K9       3.8 GDI AWD플래티넘Ⅱ  가솔린   59281  2019      무사고   검정색
# 486    기아   K9    3.8 GDI AWD베스트 셀렉션Ⅰ  가솔린   20634  2021      무사고   검정색
# 487    기아   K9  3.3 T-GDI AWD그랜드 마스터즈  가솔린   54359  2020      무사고   검정색
#
#     location  price   wd    upgrade
# 0         대구   1899  2WD      프레스티지
# ...

# %%
K9[K9['upgrade'] == 'NaN']
# Out:
# Empty DataFrame
# Columns: [brand, name, info, type, km, year, accident, color, location, price, wd, upgrade]
# Index: []

# %%
K9[K9['info']=='3.3 T-GDI']
# Out:
#     brand name       info type      km  year accident color location  price  \
# 26     기아   K9  3.3 T-GDI  가솔린   55164  2019      무사고   검정색       서울   4250
# 58     기아   K9  3.3 T-GDI  가솔린  104102  2019      무사고   검정색       대구   3799
# 100    기아   K9  3.3 T-GDI  가솔린   39932  2019      무사고   검정색       광주   4299
# 203    기아   K9  3.3 T-GDI  가솔린   27707  2019      무사고   검정색       서울   4299
# 211    기아   K9  3.3 T-GDI  가솔린   60966  2019      무사고   검정색       경기   3890
# 282    기아   K9  3.3 T-GDI  가솔린   21992  2020      무사고   검정색       대구   5190
#
#       wd upgrade
# 26   2WD   프레스티지
# 58   2WD   프레스티지
# 100  2WD   프레스티지
# 203  2WD   프레스티지
# 211  2WD   프레스티지
# 282  2WD   프레스티지

# %%
forte = df[df['name'] == '포르테']
forte
# Out:
#       brand name                       info    type      km  year  accident  \
# 20       기아  포르테           1.6 CVVT 프리미엄 Si     가솔린   35638  2010       무사고
# 171      기아  포르테              1.6 고급 레드프리미엄     가솔린  112774  2010       무사고
# 776      기아  포르테              1.6 GDI 프레스티지     가솔린  136871  2011       무사고
# 1113     기아  포르테              1.6 GDI 프레스티지     가솔린   67041  2013       무사고
# 1716     기아  포르테              1.6 GDI 프레스티지     가솔린   95442  2013       무사고
# 2376     기아  포르테          1.6 하이브리드 LPI HEV  LPG+전기  155328  2010       무사고
# 2637     기아  포르테              1.6 GDI 프레스티지     가솔린   84326  2011       무사고
# 3048     기아  포르테              1.6 GDI 프레스티지     가솔린  162647  2011       무사고
# 3088     기아  포르테                     1.6 고급     가솔린  130974  2010       무사고
# 3312     기아  포르테                     2.0 고급     가솔린  103506  2010       무사고
# 3319     기아  포르테                     2.0 고급     가솔린  109281  2010       무사고
# ...

# %%
forte.reset_index(inplace = True)
forte.drop(['index'], axis = 1,inplace = True)
forte
# Out:
#    brand name                       info    type      km  year  accident  \
# 0     기아  포르테           1.6 CVVT 프리미엄 Si     가솔린   35638  2010       무사고
# 1     기아  포르테              1.6 고급 레드프리미엄     가솔린  112774  2010       무사고
# 2     기아  포르테              1.6 GDI 프레스티지     가솔린  136871  2011       무사고
# 3     기아  포르테              1.6 GDI 프레스티지     가솔린   67041  2013       무사고
# 4     기아  포르테              1.6 GDI 프레스티지     가솔린   95442  2013       무사고
# 5     기아  포르테          1.6 하이브리드 LPI HEV  LPG+전기  155328  2010       무사고
# 6     기아  포르테              1.6 GDI 프레스티지     가솔린   84326  2011       무사고
# 7     기아  포르테              1.6 GDI 프레스티지     가솔린  162647  2011       무사고
# 8     기아  포르테                     1.6 고급     가솔린  130974  2010       무사고
# 9     기아  포르테                     2.0 고급     가솔린  103506  2010       무사고
# 10    기아  포르테                     2.0 고급     가솔린  109281  2010       무사고
# 11    기아  포르테                1.6 GDI 럭셔리     가솔린  132404  2012       무사고
# ...

# %%
forte['info'].unique()
# Out:
# array(['1.6 CVVT 프리미엄 Si', '1.6 고급 레드프리미엄', '1.6 GDI 프레스티지',
#        '1.6 하이브리드 LPI HEV', '1.6 고급', '2.0 고급', '1.6 GDI 럭셔리',
#        '1.6 GDI 디럭스', '1.6 CVVT Si', '디젤 1.6 VGT Si', '1.6 GDI 럭셔리기본형',
#        '1.6 GDI 디럭스기본형', '1.6 CVVT S 기본형   ', '1.6 VGT Si 프리미엄   ',
#        '1.6 하이브리드LPI HEV 기본형   ', '1.6 CVVT Si    ',
#        '2.0 CVVT 프리미엄 SLi 블랙스페셜  '], dtype=object)

# %%
# info열의 프리미엄 스포츠 여부를 upgrade 열에 추가
forte['upgrade'] = ""

for i in range(0, len(forte)):
    
    if forte['info'].str.contains('프레스티지')[i]:
        forte['upgrade'][i] = '프레스티지'

    elif forte['info'].str.contains('블랙스페셜')[i]:
        forte['upgrade'][i] = '블랙스페셜'
        
    elif forte['info'].str.contains('럭셔리')[i]:
        forte['upgrade'][i] = '럭셔리'
        
    elif forte['info'].str.contains('디럭스')[i]:
        forte['upgrade'][i] = '디럭스'
        
    elif forte['info'].str.contains('기본형')[i]:
        forte['upgrade'][i] = '기본형'
        
    elif forte['info'].str.contains('레드프리미엄')[i]:
        forte['upgrade'][i] = '레드프리미엄'
        
    elif forte['info'].str.contains('Si')[i]:
        forte['upgrade'][i] = '기본형'
                
    elif forte['info'].str.contains('Si 프리미엄')[i]:
        forte['upgrade'][i] = '블랙'
    
    elif forte['info'].str.contains('고급')[i]:
        forte['upgrade'][i] = '고급형'
        
    else :
        forte['upgrade'][i] = '스탠다드'
forte
# Out:
#    brand name                       info    type      km  year  accident  \
# 0     기아  포르테           1.6 CVVT 프리미엄 Si     가솔린   35638  2010       무사고
# 1     기아  포르테              1.6 고급 레드프리미엄     가솔린  112774  2010       무사고
# 2     기아  포르테              1.6 GDI 프레스티지     가솔린  136871  2011       무사고
# 3     기아  포르테              1.6 GDI 프레스티지     가솔린   67041  2013       무사고
# 4     기아  포르테              1.6 GDI 프레스티지     가솔린   95442  2013       무사고
# 5     기아  포르테          1.6 하이브리드 LPI HEV  LPG+전기  155328  2010       무사고
# 6     기아  포르테              1.6 GDI 프레스티지     가솔린   84326  2011       무사고
# 7     기아  포르테              1.6 GDI 프레스티지     가솔린  162647  2011       무사고
# 8     기아  포르테                     1.6 고급     가솔린  130974  2010       무사고
# 9     기아  포르테                     2.0 고급     가솔린  103506  2010       무사고
# 10    기아  포르테                     2.0 고급     가솔린  109281  2010       무사고
# 11    기아  포르테                1.6 GDI 럭셔리     가솔린  132404  2012       무사고
# ...

# %%
forte[forte['upgrade'] == 'NaN']
# Out:
# Empty DataFrame
# Columns: [brand, name, info, type, km, year, accident, color, location, price, wd, upgrade]
# Index: []

# %%
df['name'].unique()
# Out:
# array(['K5', '모하비', 'K7', '스포티지', '카니발', '쏘렌토', '레이', 'K9', '포르테', '모닝',
#        'K8', '카렌스', '스팅어', 'K3', '마스터', '오피러스', '프라이드', '로체', '스토닉', '쏘울',
#        '셀토스', '니로', '쎄라토', '옵티마', '봉고III 트럭 CRDi 카고',
#        '더 뉴 봉고III 트럭 CRDi 카고', '봉고3', '쏘렌토R'], dtype=object)

# %%
morning = df[df['name']=='모닝']
morning
# Out:
#       brand name                 info         type     km  year accident  \
# 28       기아   모닝              스포츠 RUN          가솔린  38539  2016      무사고
# 56       기아   모닝              LPi 디럭스  LPG(일반인 구입)  77738  2017      무사고
# 84       기아   모닝                프레스티지          가솔린  13046  2021      무사고
# 197      기아   모닝                    밴          가솔린  18625  2017      무사고
# 207      기아   모닝                프레스티지          가솔린  22064  2021      무사고
# ...     ...  ...                  ...          ...    ...   ...      ...
# 10740    기아   모닝  어반 1.0 가솔린 프레스티지             가솔린  10000  2021      무사고
# 10741    기아   모닝  어반 1.0 가솔린 프레스티지             가솔린  16171  2020      무사고
# 10742    기아   모닝  어반 1.0 가솔린 프레스티지             가솔린  15483  2020      무사고
# 10743    기아   모닝  어반 1.0 가솔린 프레스티지             가솔린  15483  2020      무사고
# 10744    기아   모닝   어반 1.0 가솔린 스탠다드             가솔린  30595  2020      무사고
#
#       color location  price   wd
# 28      검정색       대구    830  2WD
# ...

# %%
morning.reset_index(inplace = True)
morning.drop(['index'], axis = 1,inplace = True)
morning
# Out:
#      brand name                 info         type     km  year accident color  \
# 0       기아   모닝              스포츠 RUN          가솔린  38539  2016      무사고   검정색
# 1       기아   모닝              LPi 디럭스  LPG(일반인 구입)  77738  2017      무사고   검정색
# 2       기아   모닝                프레스티지          가솔린  13046  2021      무사고   검정색
# 3       기아   모닝                    밴          가솔린  18625  2017      무사고   검정색
# 4       기아   모닝                프레스티지          가솔린  22064  2021      무사고   검정색
# ...    ...  ...                  ...          ...    ...   ...      ...   ...
# 998     기아   모닝  어반 1.0 가솔린 프레스티지             가솔린  10000  2021      무사고    흰색
# 999     기아   모닝  어반 1.0 가솔린 프레스티지             가솔린  16171  2020      무사고    흰색
# 1000    기아   모닝  어반 1.0 가솔린 프레스티지             가솔린  15483  2020      무사고    흰색
# 1001    기아   모닝  어반 1.0 가솔린 프레스티지             가솔린  15483  2020      무사고    흰색
# 1002    기아   모닝   어반 1.0 가솔린 스탠다드             가솔린  30595  2020      무사고    흰색
#
#      location  price   wd
# ...

# %%
morning['info'].unique()
# Out:
# array(['스포츠 RUN', 'LPi 디럭스', '프레스티지', '밴', '럭셔리', '럭셔리 스포츠', '디럭스',
#        'SLX 스페셜', 'SLX', '터보 프레스티지', '시그니처', '스마트', '디럭스 스페셜', '바이퓨얼 스마트',
#        'LX', 'LPi 럭셔리', '디럭스 트렌디', '트렌디', '바이퓨얼 럭셔리', '터보 럭셔리', '레이디',
#        '스탠다드', 'SLX 뷰티', '스포츠 RUN HIGH', '베이직 플러스', 'LPI LX', 'LPI SLX',
#        'LX 스페셜', '바이퓨얼 디럭스 스페셜', '바이퓨얼 스마트 트렌디', '에코플러스 럭셔리', '스마트 스페셜',
#        '가솔린 1.0밴', 'SLX고급형 블랙프리미엄', 'LX기본형 블랙프리미엄', '가솔린 1.0프레스티지',
#        'LX고급형 블랙프리미엄', '밴고급형', '가솔린 1.0스탠다드', '가솔린 1.0밴 스페셜', 'SLX고급형',
#        '밴기본형', '에코 다이나믹스 스마트', 'LX기본형', '어반 1.0 가솔린 시그니처   ',
#        '어반 밴 1.0 가솔린 밴 기본형 ', '어반 1.0 가솔린 프레스티지   ',
#        '어반 밴 1.0 가솔린 밴 스페셜 ', '어반 1.0 가솔린 스탠다드   '], dtype=object)

# %%
# info열의 프리미엄 스포츠 여부를 upgrade 열에 추가
morning['upgrade'] = ""

for i in range(0, len(morning)):
    
    if morning['info'].str.contains('스탠다드')[i]:
        morning['upgrade'][i] = '스탠다드'

    elif morning['info'].str.contains('스탠다드 마이너스')[i]:
        morning['upgrade'][i] = '스탠다드'
        
    elif morning['info'].str.contains('베이직 플러스')[i]:
        morning['upgrade'][i] = '스탠다드'
        
    elif morning['info'].str.contains('기본형')[i]:
        morning['upgrade'][i] = '스탠다드'
        
    elif morning['info'].str.contains('프레스티지')[i]:
        morning['upgrade'][i] = '프레스티지'
        
    elif morning['info'].str.contains('시그니처')[i]:
        morning['upgrade'][i] = '시그니처'
        
    elif morning['info'].str.contains('시그니처 엣지-업')[i]:
        morning['upgrade'][i] = '프레스티지'
        
    elif morning['info'].str.contains('스마트 스페셜')[i]:
        morning['upgrade'][i] = '스페셜'
        
    elif morning['info'].str.contains('디럭스 스페셜')[i]:
        morning['upgrade'][i] = '스페셜'
        
    elif morning['info'].str.contains('스페셜')[i]:
        morning['upgrade'][i] = '스페셜'
        
    elif morning['info'].str.contains('럭셔리 스포츠')[i]:
        morning['upgrade'][i] = '스포츠'
        
    elif morning['info'].str.contains('디럭스')[i]:
        morning['upgrade'][i] = '디럭스'    
        
    elif morning['info'].str.contains('럭셔리')[i]:
        morning['upgrade'][i] = '럭셔리'    
        
    elif morning['info'].str.contains('트렌디')[i]:
        morning['upgrade'][i] = '트렌디'  
        
    elif morning['info'].str.contains('스마트')[i]:
        morning['upgrade'][i] = '스마트'  
        
    elif morning['info'].str.contains('RUN')[i]:
        morning['upgrade'][i] = '스포츠' 
        
    elif morning['info'].str.contains('블랙프리미엄')[i]:
        morning['upgrade'][i] = '블랙프리미엄' 
        
    elif morning['info'].str.contains('고급형')[i]:
        morning['upgrade'][i] = '고급형' 
        
    elif morning['info'].str.contains('기본형')[i]:
        morning['upgrade'][i] = '기본형' 

    elif morning['info'].str.contains('레이디')[i]:
        morning['upgrade'][i] = '레이디' 

    else :
        morning['upgrade'][i] = '스탠다드'
morning
# Out:
#      brand name                 info         type     km  year accident color  \
# 0       기아   모닝              스포츠 RUN          가솔린  38539  2016      무사고   검정색
# 1       기아   모닝              LPi 디럭스  LPG(일반인 구입)  77738  2017      무사고   검정색
# 2       기아   모닝                프레스티지          가솔린  13046  2021      무사고   검정색
# 3       기아   모닝                    밴          가솔린  18625  2017      무사고   검정색
# 4       기아   모닝                프레스티지          가솔린  22064  2021      무사고   검정색
# ...    ...  ...                  ...          ...    ...   ...      ...   ...
# 998     기아   모닝  어반 1.0 가솔린 프레스티지             가솔린  10000  2021      무사고    흰색
# 999     기아   모닝  어반 1.0 가솔린 프레스티지             가솔린  16171  2020      무사고    흰색
# 1000    기아   모닝  어반 1.0 가솔린 프레스티지             가솔린  15483  2020      무사고    흰색
# 1001    기아   모닝  어반 1.0 가솔린 프레스티지             가솔린  15483  2020      무사고    흰색
# 1002    기아   모닝   어반 1.0 가솔린 스탠다드             가솔린  30595  2020      무사고    흰색
#
# ...

# %%
morning[morning['upgrade'] == 'NaN']['info'].unique()
# Out:
# array([], dtype=object)

# %%
K8 = df[df['name'] == 'K8']
K8
# Out:
#       brand name              info         type     km  year accident color  \
# 75       기아   K8       2.5 가솔린 2WD          가솔린  12225  2022      무사고   검정색
# 123      기아   K8       3.5 가솔린 2WD          가솔린   1525  2022      무사고   검정색
# 243      기아   K8       3.5 가솔린 2WD          가솔린   3370  2022      무사고   검정색
# 335      기아   K8       2.5 가솔린 2WD          가솔린   2659  2022      무사고   검정색
# 447      기아   K8       2.5 가솔린 2WD          가솔린   2169  2022      무사고   검정색
# ...     ...  ...               ...          ...    ...   ...      ...   ...
# 10433    기아   K8  3.5 가솔린 노블레스              가솔린    100  2021      무사고    흰색
# 10434    기아   K8  3.5 LPG 노블레스      LPG(일반인 구입)   1731  2021      무사고    흰색
# 10435    기아   K8  2.5 가솔린 시그니처              가솔린   7147  2021      무사고    흰색
# 10436    기아   K8  2.5 가솔린 시그니처              가솔린   3093  2021      무사고    흰색
# 10437    기아   K8  3.5 LPG 노블레스      LPG(일반인 구입)   1731  2021      무사고    흰색
#
#       location  price   wd
# 75          울산   4350  2WD
# ...

# %%
K8.reset_index(inplace = True)
K8.drop(['index'], axis = 1,inplace = True)
K8
# Out:
#     brand name              info         type     km  year accident color  \
# 0      기아   K8       2.5 가솔린 2WD          가솔린  12225  2022      무사고   검정색
# 1      기아   K8       3.5 가솔린 2WD          가솔린   1525  2022      무사고   검정색
# 2      기아   K8       3.5 가솔린 2WD          가솔린   3370  2022      무사고   검정색
# 3      기아   K8       2.5 가솔린 2WD          가솔린   2659  2022      무사고   검정색
# 4      기아   K8       2.5 가솔린 2WD          가솔린   2169  2022      무사고   검정색
# ..    ...  ...               ...          ...    ...   ...      ...   ...
# 222    기아   K8  3.5 가솔린 노블레스              가솔린    100  2021      무사고    흰색
# 223    기아   K8  3.5 LPG 노블레스      LPG(일반인 구입)   1731  2021      무사고    흰색
# 224    기아   K8  2.5 가솔린 시그니처              가솔린   7147  2021      무사고    흰색
# 225    기아   K8  2.5 가솔린 시그니처              가솔린   3093  2021      무사고    흰색
# 226    기아   K8  3.5 LPG 노블레스      LPG(일반인 구입)   1731  2021      무사고    흰색
#
#     location  price   wd
# 0         울산   4350  2WD
# 1         서울   4799  2WD
# ...

# %%
# info열의 프리미엄 스포츠 여부를 upgrade 열에 추가
K8['upgrade'] = ""

for i in range(0, len(K8)):
    
    if K8['info'].str.contains('시그니처')[i]:
        K8['upgrade'][i] = '시그니처'

    elif K8['info'].str.contains('2.5 가솔린')[i]:
        K8['upgrade'][i] = '노블레스'
        
    elif K8['info'].str.contains('노블레스')[i]:
        K8['upgrade'][i] = '노블레스'
        
    elif K8['info'].str.contains('노블레스 라이트')[i]:
        K8['upgrade'][i] = '노블레스'
        
    elif K8['info'].str.contains('플래티넘')[i]:
        K8['upgrade'][i] = '플래티넘'
        
    elif K8['info'].str.contains('트렌디')[i]:
        K8['upgrade'][i] = '트렌디'
        
    elif K8['info'].str.contains('프레스티지')[i]:
        K8['upgrade'][i] = '프레스티지'
        
    elif K8['info'].str.contains('3.5 가솔린')[i]:
        K8['upgrade'][i] = '노블레스'
        
    elif K8['info'].str.contains('3.5 LPG')[i]:
        K8['upgrade'][i] = '스탠다드'

    else :
        K8['upgrade'][i] = '스탠다드'
K8
# Out:
#     brand name              info         type     km  year accident color  \
# 0      기아   K8       2.5 가솔린 2WD          가솔린  12225  2022      무사고   검정색
# 1      기아   K8       3.5 가솔린 2WD          가솔린   1525  2022      무사고   검정색
# 2      기아   K8       3.5 가솔린 2WD          가솔린   3370  2022      무사고   검정색
# 3      기아   K8       2.5 가솔린 2WD          가솔린   2659  2022      무사고   검정색
# 4      기아   K8       2.5 가솔린 2WD          가솔린   2169  2022      무사고   검정색
# ..    ...  ...               ...          ...    ...   ...      ...   ...
# 222    기아   K8  3.5 가솔린 노블레스              가솔린    100  2021      무사고    흰색
# 223    기아   K8  3.5 LPG 노블레스      LPG(일반인 구입)   1731  2021      무사고    흰색
# 224    기아   K8  2.5 가솔린 시그니처              가솔린   7147  2021      무사고    흰색
# 225    기아   K8  2.5 가솔린 시그니처              가솔린   3093  2021      무사고    흰색
# 226    기아   K8  3.5 LPG 노블레스      LPG(일반인 구입)   1731  2021      무사고    흰색
#
#     location  price   wd upgrade
# 0         울산   4350  2WD    노블레스
# ...

# %%
K8[K8['upgrade'] == 'NaN']
# Out:
# Empty DataFrame
# Columns: [brand, name, info, type, km, year, accident, color, location, price, wd, upgrade]
# Index: []

# %%
for i in range(0,len(K8)):
    if K8['info'].str.contains('3.5 가솔린')[i]:
        print(K8['info'][i])
# Out:
# 3.5 가솔린 2WD
# 3.5 가솔린 2WD
# 3.5 가솔린 2WD
# 3.5 가솔린 4WD
# 3.5 가솔린 4WD
# 3.5 가솔린 2WD
# 3.5 가솔린 2WD
# 3.5 가솔린 2WD
# 3.5 가솔린 2WD
# 3.5 가솔린 2WD
# 3.5 가솔린 4WD
# 3.5 가솔린 2WD
# 3.5 가솔린 2WD
# 3.5 가솔린 2WD
# 3.5 가솔린 2WD
# 3.5 가솔린 2WD
# 3.5 가솔린 2WD
# 3.5 가솔린 2WD
# 3.5 가솔린 2WD
# 3.5 가솔린 2WD
# 3.5 가솔린 2WD
# 3.5 가솔린 플래티넘
# 3.5 가솔린 시그니처
# 3.5 가솔린 시그니처
# 3.5 가솔린 시그니처
# 3.5 가솔린 시그니처
# 3.5 가솔린 시그니처
# 3.5 가솔린 시그니처
# 3.5 가솔린 시그니처
# 3.5 가솔린 시그니처
# 3.5 가솔린 시그니처
# 3.5 가솔린 시그니처
# 3.5 가솔린 시그니처
# 3.5 가솔린 노블레스
# 3.5 가솔린 시그니처
# 3.5 가솔린 시그니처
# 3.5 가솔린 시그니처
# 3.5 가솔린 시그니처
# 3.5 가솔린 시그니처
# 3.5 가솔린 시그니처
# 3.5 가솔린 시그니처
# 3.5 가솔린 노블레스
# 3.5 가솔린 시그니처
# 3.5 가솔린 노블레스
# 3.5 가솔린 플래티넘
# 3.5 가솔린 노블레스
# 3.5 가솔린 노블레스

# %%
carens = df[df['name']=='카렌스']
carens
# Out:
#       brand name               info         type      km  year  accident  \
# 92       기아  카렌스         LPI 2.0 GX  LPG(일반인 구입)  138746  2008       무사고
# 276      기아  카렌스        LPI 2.0 GLX  LPG(일반인 구입)  114923  2009       무사고
# 646      기아  카렌스       1.7 VGT 노블레스           디젤   77587  2015       무사고
# 716      기아  카렌스        2.0 LPI 럭셔리  LPG(일반인 구입)  110185  2017       무사고
# 1561     기아  카렌스      2.0 LPi 프레스티지  LPG(일반인 구입)  144232  2014       무사고
# ...     ...  ...                ...          ...     ...   ...       ...
# 8374     기아  카렌스        2.0 LPi 럭셔리          LPG  110003  2014  단순사고(접촉)
# 8870     기아  카렌스      1.7 VGT 프레스티지           디젤   62309  2014       무사고
# 9668     기아  카렌스      1.7 VGT 프레스티지           디젤   96735  2014       무사고
# 11273    기아  카렌스  2.0 VGT GX 고급형              디젤  139780  2007       무사고
# 11274    기아  카렌스  2.0 LPG GX 고급형     LPG(일반인 구입)  120000  2006       무사고
#
#       color location  price   wd
# 92      검정색       광주    550  2WD
# ...

# %%
carens.reset_index(inplace = True)
carens.drop(['index'], axis = 1,inplace = True)
carens
# Out:
#    brand name               info         type      km  year  accident color  \
# 0     기아  카렌스         LPI 2.0 GX  LPG(일반인 구입)  138746  2008       무사고   검정색
# 1     기아  카렌스        LPI 2.0 GLX  LPG(일반인 구입)  114923  2009       무사고   검정색
# 2     기아  카렌스       1.7 VGT 노블레스           디젤   77587  2015       무사고   검정색
# 3     기아  카렌스        2.0 LPI 럭셔리  LPG(일반인 구입)  110185  2017       무사고   검정색
# 4     기아  카렌스      2.0 LPi 프레스티지  LPG(일반인 구입)  144232  2014       무사고   검정색
# ..   ...  ...                ...          ...     ...   ...       ...   ...
# 69    기아  카렌스        2.0 LPi 럭셔리          LPG  110003  2014  단순사고(접촉)    회색
# 70    기아  카렌스      1.7 VGT 프레스티지           디젤   62309  2014       무사고    회색
# 71    기아  카렌스      1.7 VGT 프레스티지           디젤   96735  2014       무사고    흰색
# 72    기아  카렌스  2.0 VGT GX 고급형              디젤  139780  2007       무사고    회색
# 73    기아  카렌스  2.0 LPG GX 고급형     LPG(일반인 구입)  120000  2006       무사고    회색
#
#    location  price   wd
# 0        광주    550  2WD
# ...

# %%
# info열의 프리미엄 스포츠 여부를 upgrade 열에 추가
carens['upgrade'] = ""

for i in range(0, len(carens)):
    
    if carens['info'].str.contains('디럭스')[i]:
        carens['upgrade'][i] = '디럭스'

    elif carens['info'].str.contains('럭셔리')[i]:
        carens['upgrade'][i] = '럭셔리'
        
    elif carens['info'].str.contains('트렌디')[i]:
        carens['upgrade'][i] = '트렌디'
        
    elif carens['info'].str.contains('프레스티지')[i]:
        carens['upgrade'][i] = '프레스티지'
        
    elif carens['info'].str.contains('노블레스')[i]:
        carens['upgrade'][i] = '노블레스'
        
    elif carens['info'].str.contains('에코')[i]:
        carens['upgrade'][i] = '에코 다이나믹스'
        
    elif carens['info'].str.contains('TLX')[i]:
        carens['upgrade'][i] = 'TLX'
        
    elif carens['info'].str.contains('GLX')[i]:
        carens['upgrade'][i] = 'GLX'
        
    elif carens['info'].str.contains('LX')[i]:
        carens['upgrade'][i] = 'LX'
        
    elif carens['info'].str.contains('EX')[i]:
        carens['upgrade'][i] = 'EX'
        
    elif carens['info'].str.contains('GX')[i]:
        carens['upgrade'][i] = 'GX'
        
    elif carens['info'].str.contains('프리미')[i]:
        carens['upgrade'][i] = '프리미엄'
        
    elif carens['info'].str.contains('리미티드')[i]:
        carens['upgrade'][i] = '리미티드'
        
    elif carens['info'].str.contains('골드')[i]:
        carens['upgrade'][i] = '비즈니스'
        
    elif carens['info'].str.contains('비즈니스')[i]:
        carens['upgrade'][i] = '비즈니스'
        
    elif carens['info'].str.contains('베타')[i]:
        carens['upgrade'][i] = '비즈니스'
        
    else :
        carens['upgrade'][i] = '스탠다드'
carens
# Out:
#    brand name               info         type      km  year  accident color  \
# 0     기아  카렌스         LPI 2.0 GX  LPG(일반인 구입)  138746  2008       무사고   검정색
# 1     기아  카렌스        LPI 2.0 GLX  LPG(일반인 구입)  114923  2009       무사고   검정색
# 2     기아  카렌스       1.7 VGT 노블레스           디젤   77587  2015       무사고   검정색
# 3     기아  카렌스        2.0 LPI 럭셔리  LPG(일반인 구입)  110185  2017       무사고   검정색
# 4     기아  카렌스      2.0 LPi 프레스티지  LPG(일반인 구입)  144232  2014       무사고   검정색
# ..   ...  ...                ...          ...     ...   ...       ...   ...
# 69    기아  카렌스        2.0 LPi 럭셔리          LPG  110003  2014  단순사고(접촉)    회색
# 70    기아  카렌스      1.7 VGT 프레스티지           디젤   62309  2014       무사고    회색
# 71    기아  카렌스      1.7 VGT 프레스티지           디젤   96735  2014       무사고    흰색
# 72    기아  카렌스  2.0 VGT GX 고급형              디젤  139780  2007       무사고    회색
# 73    기아  카렌스  2.0 LPG GX 고급형     LPG(일반인 구입)  120000  2006       무사고    회색
#
#    location  price   wd upgrade
# ...

# %%
carens[carens['upgrade'] == 'NaN']
# Out:
# Empty DataFrame
# Columns: [brand, name, info, type, km, year, accident, color, location, price, wd, upgrade]
# Index: []

# %%
stingr = df[df['name'] == '스팅어']
stingr
# Out:
#       brand name                       info type     km  year accident color  \
# 103      기아  스팅어                 2.0 터보 2WD  가솔린  14973  2020      무사고   검정색
# 112      기아  스팅어                 2.0 터보 2WD  가솔린  70179  2018      무사고   검정색
# 201      기아  스팅어                 2.0 터보 2WD  가솔린  37689  2020      무사고   검정색
# 240      기아  스팅어                 2.0 터보 2WD  가솔린  27005  2018      무사고   검정색
# 349      기아  스팅어                 2.0 터보 2WD  가솔린   9810  2020      무사고   검정색
# ...     ...  ...                        ...  ...    ...   ...      ...   ...
# 11066    기아  스팅어  마이스터 3.3 가솔린 터보 4WD 마스터즈   가솔린   7245  2020      무사고    흰색
# 11067    기아  스팅어          2.2 디젤 2WD 프라임      디젤  51857  2018      무사고    흰색
# 11068    기아  스팅어          2.2 디젤 2WD 프라임      디젤  51857  2018      무사고    흰색
# 11069    기아  스팅어  마이스터 3.3 가솔린 터보 2WD 마스터즈   가솔린     50  2021      무사고    흰색
# 11070    기아  스팅어          2.2 디젤 2WD 프라임      디젤  51857  2018      무사고    흰색
#
#       location  price   wd
# ...

# %%
stingr.reset_index(inplace = True)
stingr.drop(['index'], axis = 1,inplace = True)
stingr
# Out:
#     brand name                       info type     km  year accident color  \
# 0      기아  스팅어                 2.0 터보 2WD  가솔린  14973  2020      무사고   검정색
# 1      기아  스팅어                 2.0 터보 2WD  가솔린  70179  2018      무사고   검정색
# 2      기아  스팅어                 2.0 터보 2WD  가솔린  37689  2020      무사고   검정색
# 3      기아  스팅어                 2.0 터보 2WD  가솔린  27005  2018      무사고   검정색
# 4      기아  스팅어                 2.0 터보 2WD  가솔린   9810  2020      무사고   검정색
# ..    ...  ...                        ...  ...    ...   ...      ...   ...
# 291    기아  스팅어  마이스터 3.3 가솔린 터보 4WD 마스터즈   가솔린   7245  2020      무사고    흰색
# 292    기아  스팅어          2.2 디젤 2WD 프라임      디젤  51857  2018      무사고    흰색
# 293    기아  스팅어          2.2 디젤 2WD 프라임      디젤  51857  2018      무사고    흰색
# 294    기아  스팅어  마이스터 3.3 가솔린 터보 2WD 마스터즈   가솔린     50  2021      무사고    흰색
# 295    기아  스팅어          2.2 디젤 2WD 프라임      디젤  51857  2018      무사고    흰색
#
#     location  price   wd
# 0         서울   3320  2WD
# ...

# %%
# info열의 프리미엄 스포츠 여부를 upgrade 열에 추가
stingr['upgrade'] = ""

for i in range(0, len(stingr)):
    
    if stingr['info'].str.contains('프라임')[i]:
        stingr['upgrade'][i] = '프라임'

    elif stingr['info'].str.contains('플래티넘')[i]:
        stingr['upgrade'][i] = '플래티넘'
        
    elif stingr['info'].str.contains('마스터즈')[i]:
        stingr['upgrade'][i] = '마스터즈'
        
    elif stingr['info'].str.contains('익스트림')[i]:
        stingr['upgrade'][i] = '익스트림 팩'
        
    elif stingr['info'].str.contains('드림')[i]:
        stingr['upgrade'][i] = '드림 에디션'
        
    elif stingr['info'].str.contains('알칸타라')[i]:
        stingr['upgrade'][i] = '알칸타라 에디션'
        
    elif stingr['info'].str.contains('GT')[i]:
        stingr['upgrade'][i] = 'GT'
        
    elif stingr['info'].str.contains('2.0 터보')[i]:
        stingr['upgrade'][i] = '프라임'
        
    elif stingr['info'].str.contains('2.2 디젤')[i]:
        stingr['upgrade'][i] = '프라임'
        
    elif stingr['info'].str.contains('3.3 터보')[i]:
        stingr['upgrade'][i] = '마스터즈'
        
    else :
        stingr['upgrade'][i] = '플래티넘'
stingr
# Out:
#     brand name                       info type     km  year accident color  \
# 0      기아  스팅어                 2.0 터보 2WD  가솔린  14973  2020      무사고   검정색
# 1      기아  스팅어                 2.0 터보 2WD  가솔린  70179  2018      무사고   검정색
# 2      기아  스팅어                 2.0 터보 2WD  가솔린  37689  2020      무사고   검정색
# 3      기아  스팅어                 2.0 터보 2WD  가솔린  27005  2018      무사고   검정색
# 4      기아  스팅어                 2.0 터보 2WD  가솔린   9810  2020      무사고   검정색
# ..    ...  ...                        ...  ...    ...   ...      ...   ...
# 291    기아  스팅어  마이스터 3.3 가솔린 터보 4WD 마스터즈   가솔린   7245  2020      무사고    흰색
# 292    기아  스팅어          2.2 디젤 2WD 프라임      디젤  51857  2018      무사고    흰색
# 293    기아  스팅어          2.2 디젤 2WD 프라임      디젤  51857  2018      무사고    흰색
# 294    기아  스팅어  마이스터 3.3 가솔린 터보 2WD 마스터즈   가솔린     50  2021      무사고    흰색
# 295    기아  스팅어          2.2 디젤 2WD 프라임      디젤  51857  2018      무사고    흰색
#
#     location  price   wd upgrade
# 0         서울   3320  2WD     프라임
# ...

# %%
stingr[stingr['upgrade'] == 'NaN']
# Out:
# Empty DataFrame
# Columns: [brand, name, info, type, km, year, accident, color, location, price, wd, upgrade]
# Index: []

# %%
K3 = df[df['name'] == 'K3']
K3
# Out:
#      brand name           info type     km  year accident color location  \
# 154     기아   K3            럭셔리  가솔린  36592  2020      무사고   검정색       대구
# 160     기아   K3    5도어 GT 시그니처  가솔린  16628  2021      무사고   검정색       경기
# 161     기아   K3           노블레스  가솔린  31023  2014      무사고   검정색       서울
# 208     기아   K3     5도어 GT 베이직  가솔린  69158  2019      무사고   검정색       경기
# 260     기아   K3           노블레스  가솔린  90646  2013      무사고   검정색       충남
# ...    ...  ...            ...  ...    ...   ...      ...   ...      ...
# 9899    기아   K3          프레스티지  가솔린  17725  2021      무사고    기타       인천
# 9903    기아   K3    디젤 럭셔리        디젤  90367  2014      무사고    흰색       서울
# 9904    기아   K3    디젤 럭셔리        디젤  90367  2014      무사고    흰색       서울
# 9905    기아   K3   디젤 노블레스        디젤  98952  2014      무사고    흰색       경기
# 9906    기아   K3  디젤 프레스티지        디젤  91514  2015      무사고    흰색       서울
#
#       price   wd
# 154    1599  2WD
# 160    2280  2WD
# 161    1170  2WD
# 208    1789  2WD
# ...

# %%
K3.reset_index(inplace = True)
K3.drop(['index'], axis = 1,inplace = True)
K3
# Out:
#     brand name           info type     km  year accident color location  \
# 0      기아   K3            럭셔리  가솔린  36592  2020      무사고   검정색       대구
# 1      기아   K3    5도어 GT 시그니처  가솔린  16628  2021      무사고   검정색       경기
# 2      기아   K3           노블레스  가솔린  31023  2014      무사고   검정색       서울
# 3      기아   K3     5도어 GT 베이직  가솔린  69158  2019      무사고   검정색       경기
# 4      기아   K3           노블레스  가솔린  90646  2013      무사고   검정색       충남
# ..    ...  ...            ...  ...    ...   ...      ...   ...      ...
# 576    기아   K3          프레스티지  가솔린  17725  2021      무사고    기타       인천
# 577    기아   K3    디젤 럭셔리        디젤  90367  2014      무사고    흰색       서울
# 578    기아   K3    디젤 럭셔리        디젤  90367  2014      무사고    흰색       서울
# 579    기아   K3   디젤 노블레스        디젤  98952  2014      무사고    흰색       경기
# 580    기아   K3  디젤 프레스티지        디젤  91514  2015      무사고    흰색       서울
#
#      price   wd
# 0     1599  2WD
# 1     2280  2WD
# 2     1170  2WD
# 3     1789  2WD
# ...

# %%
# info열의 프리미엄 스포츠 여부를 upgrade 열에 추가
K3['upgrade'] = ""

for i in range(0, len(K3)):
    
    if K3['info'].str.contains('디럭스')[i]:
        K3['upgrade'][i] = '디럭스'

    elif K3['info'].str.contains('트렌디')[i]:
        K3['upgrade'][i] = '트렌디'
        
    elif K3['info'].str.contains('스탠다드')[i]:
        K3['upgrade'][i] = '스탠다드'
        
    elif K3['info'].str.contains('베이직')[i]:
        K3['upgrade'][i] = '트렌디'
        
    elif K3['info'].str.contains('플러스')[i]:
        K3['upgrade'][i] = '럭셔리'
        
    elif K3['info'].str.contains('럭셔리')[i]:
        K3['upgrade'][i] = '럭셔리'
        
    elif K3['info'].str.contains('프레스티지')[i]:
        K3['upgrade'][i] = '프레스티지'
        
    elif K3['info'].str.contains('노블레스')[i]:
        K3['upgrade'][i] = '노블레스'
        
    elif K3['info'].str.contains('시그니처')[i]:
        K3['upgrade'][i] = '시그니처'
        
    elif K3['info'].str.contains('W 스페셜')[i]:
        K3['upgrade'][i] = 'W 스페셜'
        
    elif K3['info'].str.contains('1.6 터보 GT')[i]:
        K3['upgrade'][i] = '트렌디'
        
    elif K3['info'].str.contains('1.6')[i]:
        K3['upgrade'][i] = '럭셔리'
        
    else :
        K3['upgrade'][i] = '스탠다드'
K3
# Out:
#     brand name           info type     km  year accident color location  \
# 0      기아   K3            럭셔리  가솔린  36592  2020      무사고   검정색       대구
# 1      기아   K3    5도어 GT 시그니처  가솔린  16628  2021      무사고   검정색       경기
# 2      기아   K3           노블레스  가솔린  31023  2014      무사고   검정색       서울
# 3      기아   K3     5도어 GT 베이직  가솔린  69158  2019      무사고   검정색       경기
# 4      기아   K3           노블레스  가솔린  90646  2013      무사고   검정색       충남
# ..    ...  ...            ...  ...    ...   ...      ...   ...      ...
# 576    기아   K3          프레스티지  가솔린  17725  2021      무사고    기타       인천
# 577    기아   K3    디젤 럭셔리        디젤  90367  2014      무사고    흰색       서울
# 578    기아   K3    디젤 럭셔리        디젤  90367  2014      무사고    흰색       서울
# 579    기아   K3   디젤 노블레스        디젤  98952  2014      무사고    흰색       경기
# 580    기아   K3  디젤 프레스티지        디젤  91514  2015      무사고    흰색       서울
#
#      price   wd upgrade
# 0     1599  2WD     럭셔리
# 1     2280  2WD    시그니처
# 2     1170  2WD    노블레스
# ...

# %%
K3[K3['upgrade'] == 'NaN']
# Out:
# Empty DataFrame
# Columns: [brand, name, info, type, km, year, accident, color, location, price, wd, upgrade]
# Index: []

# %%
master = df[df['name'] == '마스터']
master
# Out:
#      brand name                info type     km  year accident color location  \
# 162     기아  마스터      디젤 3.0 4WD 6인승   디젤   6521  2021      무사고   검정색       경기
# 180     기아  마스터      디젤 3.0 4WD 6인승   디젤  14837  2021      무사고   검정색       경기
# 259     기아  마스터      디젤 3.0 4WD 7인승   디젤  13953  2020      무사고   검정색       경기
# 286     기아  마스터      디젤 3.0 4WD 6인승   디젤  42537  2020      무사고   검정색       대구
# 357     기아  마스터      디젤 3.0 4WD 6인승   디젤  12653  2021      무사고   검정색       서울
# ...    ...  ...                 ...  ...    ...   ...      ...   ...      ...
# 9234    기아  마스터  디젤 3.0 4WD마스터즈 6인승   디젤  28801  2020      무사고   검정색       인천
# 9248    기아  마스터  디젤 3.0 4WD마스터즈 7인승   디젤  30429  2020      무사고    흰색       인천
# 9394    기아  마스터  디젤 3.0 4WD마스터즈 7인승   디젤  20287  2020      무사고   검정색       인천
# 9774    기아  마스터  디젤 3.0 4WD마스터즈 7인승   디젤  20202  2021      무사고   검정색       경남
# 9822    기아  마스터  디젤 3.0 4WD마스터즈 6인승   디젤  19416  2020      무사고   검정색       인천
#
#       price   wd
# ...

# %%
master.reset_index(inplace = True)
master.drop(['index'], axis = 1,inplace = True)
master
# Out:
#    brand name                info type     km  year accident color location  \
# 0     기아  마스터      디젤 3.0 4WD 6인승   디젤   6521  2021      무사고   검정색       경기
# 1     기아  마스터      디젤 3.0 4WD 6인승   디젤  14837  2021      무사고   검정색       경기
# 2     기아  마스터      디젤 3.0 4WD 7인승   디젤  13953  2020      무사고   검정색       경기
# 3     기아  마스터      디젤 3.0 4WD 6인승   디젤  42537  2020      무사고   검정색       대구
# 4     기아  마스터      디젤 3.0 4WD 6인승   디젤  12653  2021      무사고   검정색       서울
# ..   ...  ...                 ...  ...    ...   ...      ...   ...      ...
# 63    기아  마스터  디젤 3.0 4WD마스터즈 6인승   디젤  28801  2020      무사고   검정색       인천
# 64    기아  마스터  디젤 3.0 4WD마스터즈 7인승   디젤  30429  2020      무사고    흰색       인천
# 65    기아  마스터  디젤 3.0 4WD마스터즈 7인승   디젤  20287  2020      무사고   검정색       인천
# 66    기아  마스터  디젤 3.0 4WD마스터즈 7인승   디젤  20202  2021      무사고   검정색       경남
# 67    기아  마스터  디젤 3.0 4WD마스터즈 6인승   디젤  19416  2020      무사고   검정색       인천
#
#     price   wd
# 0    5490  4WD
# 1    5370  4WD
# ...

# %%
master['info'].unique()
# Out:
# array(['디젤 3.0 4WD 6인승', '디젤 3.0 4WD 7인승', '디젤 3.0 4WD 5인승',
#        '디젤 3.0 4WD마스터즈 5인승', '디젤 3.0 4WD플래티넘 5인승',
#        '디젤 3.0 4WD마스터즈 그래비티 6인승', '디젤 3.0 4WD마스터즈 7인승',
#        '디젤 3.0 4WD마스터즈 6인승'], dtype=object)

# %%
# info열의 프리미엄 스포츠 여부를 upgrade 열에 추가
master['upgrade'] = ""

for i in range(0, len(master)):
    
    if master['info'].str.contains('마스터즈')[i]:
        master['upgrade'][i] = '마스터즈'

    elif master['info'].str.contains('플래티넘')[i]:
        master['upgrade'][i] = '플래티넘'
        
    else :
        master['upgrade'][i] = '마스터즈'
master
# Out:
#    brand name                info type     km  year accident color location  \
# 0     기아  마스터      디젤 3.0 4WD 6인승   디젤   6521  2021      무사고   검정색       경기
# 1     기아  마스터      디젤 3.0 4WD 6인승   디젤  14837  2021      무사고   검정색       경기
# 2     기아  마스터      디젤 3.0 4WD 7인승   디젤  13953  2020      무사고   검정색       경기
# 3     기아  마스터      디젤 3.0 4WD 6인승   디젤  42537  2020      무사고   검정색       대구
# 4     기아  마스터      디젤 3.0 4WD 6인승   디젤  12653  2021      무사고   검정색       서울
# ..   ...  ...                 ...  ...    ...   ...      ...   ...      ...
# 63    기아  마스터  디젤 3.0 4WD마스터즈 6인승   디젤  28801  2020      무사고   검정색       인천
# 64    기아  마스터  디젤 3.0 4WD마스터즈 7인승   디젤  30429  2020      무사고    흰색       인천
# 65    기아  마스터  디젤 3.0 4WD마스터즈 7인승   디젤  20287  2020      무사고   검정색       인천
# 66    기아  마스터  디젤 3.0 4WD마스터즈 7인승   디젤  20202  2021      무사고   검정색       경남
# 67    기아  마스터  디젤 3.0 4WD마스터즈 6인승   디젤  19416  2020      무사고   검정색       인천
#
#     price   wd upgrade
# 0    5490  4WD    마스터즈
# ...

# %%
opirus = df[df['name'] == '오피러스']
opirus
# Out:
#      brand  name           info         type      km  year accident color  \
# 173     기아  오피러스     GH330 노블레스          가솔린  161289  2011      무사고   검정색
# 215     기아  오피러스      GH270 디럭스          가솔린  143031  2011      무사고   검정색
# 225     기아  오피러스      GH330 고급형          가솔린   50480  2007      무사고   검정색
# 235     기아  오피러스      GH270 고급형          가솔린  188539  2007      무사고   검정색
# 360     기아  오피러스      GH270 스페셜          가솔린  136881  2008      무사고   검정색
# ...    ...   ...            ...          ...     ...   ...      ...   ...
# 7395    기아  오피러스      GH270 스페셜          가솔린  103703  2009      무사고    회색
# 7411    기아  오피러스      GH270 디럭스          가솔린  139025  2011      무사고    회색
# 7526    기아  오피러스      GH270 고급형          가솔린  196378  2007      무사고    회색
# 7534    기아  오피러스  LPI GH270 고급형  LPG(일반인 구입)  271290  2009      무사고    회색
# 7594    기아  오피러스  LPI GH270 고급형  LPG(일반인 구입)  173992  2009      무사고    회색
#
#      location  price   wd
# 173        광주    600  2WD
# ...

# %%
opirus.reset_index(inplace = True)
opirus.drop(['index'], axis = 1,inplace = True)
opirus
# Out:
#    brand  name           info         type      km  year accident color  \
# 0     기아  오피러스     GH330 노블레스          가솔린  161289  2011      무사고   검정색
# 1     기아  오피러스      GH270 디럭스          가솔린  143031  2011      무사고   검정색
# 2     기아  오피러스      GH330 고급형          가솔린   50480  2007      무사고   검정색
# 3     기아  오피러스      GH270 고급형          가솔린  188539  2007      무사고   검정색
# 4     기아  오피러스      GH270 스페셜          가솔린  136881  2008      무사고   검정색
# ..   ...   ...            ...          ...     ...   ...      ...   ...
# 68    기아  오피러스      GH270 스페셜          가솔린  103703  2009      무사고    회색
# 69    기아  오피러스      GH270 디럭스          가솔린  139025  2011      무사고    회색
# 70    기아  오피러스      GH270 고급형          가솔린  196378  2007      무사고    회색
# 71    기아  오피러스  LPI GH270 고급형  LPG(일반인 구입)  271290  2009      무사고    회색
# 72    기아  오피러스  LPI GH270 고급형  LPG(일반인 구입)  173992  2009      무사고    회색
#
#    location  price   wd
# 0        광주    600  2WD
# 1        충남    600  2WD
# 2        대구    450  2WD
# ...

# %%
# info열의 프리미엄 스포츠 여부를 upgrade 열에 추가
opirus['upgrade'] = ""

for i in range(0, len(opirus)):
    
    if opirus['info'].str.contains('디럭스')[i]:
        opirus['upgrade'][i] = '디럭스'

    elif opirus['info'].str.contains('럭셔리')[i]:
        opirus['upgrade'][i] = '럭셔리'
        
    elif opirus['info'].str.contains('고급형')[i]:
        opirus['upgrade'][i] = '럭셔리'
        
    elif opirus['info'].str.contains('프리미엄')[i]:
        opirus['upgrade'][i] = '프리미엄'
        
    elif opirus['info'].str.contains('프레스티지')[i]:
        opirus['upgrade'][i] = '프레스티지'
        
    elif opirus['info'].str.contains('노블레스')[i]:
        opirus['upgrade'][i] = '노블레스'
        
    else :
        opirus['upgrade'][i] = '디럭스'
opirus
# Out:
#    brand  name           info         type      km  year accident color  \
# 0     기아  오피러스     GH330 노블레스          가솔린  161289  2011      무사고   검정색
# 1     기아  오피러스      GH270 디럭스          가솔린  143031  2011      무사고   검정색
# 2     기아  오피러스      GH330 고급형          가솔린   50480  2007      무사고   검정색
# 3     기아  오피러스      GH270 고급형          가솔린  188539  2007      무사고   검정색
# 4     기아  오피러스      GH270 스페셜          가솔린  136881  2008      무사고   검정색
# ..   ...   ...            ...          ...     ...   ...      ...   ...
# 68    기아  오피러스      GH270 스페셜          가솔린  103703  2009      무사고    회색
# 69    기아  오피러스      GH270 디럭스          가솔린  139025  2011      무사고    회색
# 70    기아  오피러스      GH270 고급형          가솔린  196378  2007      무사고    회색
# 71    기아  오피러스  LPI GH270 고급형  LPG(일반인 구입)  271290  2009      무사고    회색
# 72    기아  오피러스  LPI GH270 고급형  LPG(일반인 구입)  173992  2009      무사고    회색
#
#    location  price   wd upgrade
# 0        광주    600  2WD    노블레스
# 1        충남    600  2WD     디럭스
# ...

# %%
pride = df[df['name'] == '프라이드']
pride
# Out:
#       brand  name                 info type      km  year accident color  \
# 238      기아  프라이드           1.6 GDI 세단  가솔린  161066  2014      무사고   검정색
# 1133     기아  프라이드           1.6 GDI 세단  가솔린   79699  2012      무사고   검정색
# 1935     기아  프라이드   디젤 4DR 1.5 VGT SLX   디젤   44960  2011      무사고   검정색
# 2289     기아  프라이드           1.6 GDI 세단  가솔린  127438  2014      무사고   검정색
# 2424     기아  프라이드           1.6 GDI 세단  가솔린  102807  2014      무사고    흰색
# ...     ...   ...                  ...  ...     ...   ...      ...   ...
# 11282    기아  프라이드  4DR 1.6 CVVT SLX     가솔린   70000  2009      무사고    기타
# 11283    기아  프라이드  4DR 1.6 CVVT SLX     가솔린   21768  2007      무사고    회색
# 11284    기아  프라이드  4DR 1.6 CVVT SLX     가솔린   21768  2007      무사고    회색
# 11285    기아  프라이드    4DR 1.5 VGT LX      디젤  133837  2009      무사고    회색
# 11286    기아  프라이드   4DR 1.5 VGT SLX      디젤  230000  2009      무사고    흰색
#
#       location  price   wd
# 238         충남    460  2WD
# 1133        인천    580  2WD
# ...

# %%
pride.reset_index(inplace = True)
pride.drop(['index'], axis = 1,inplace = True)
pride
# Out:
#     brand  name                 info type      km  year accident color  \
# 0      기아  프라이드           1.6 GDI 세단  가솔린  161066  2014      무사고   검정색
# 1      기아  프라이드           1.6 GDI 세단  가솔린   79699  2012      무사고   검정색
# 2      기아  프라이드   디젤 4DR 1.5 VGT SLX   디젤   44960  2011      무사고   검정색
# 3      기아  프라이드           1.6 GDI 세단  가솔린  127438  2014      무사고   검정색
# 4      기아  프라이드           1.6 GDI 세단  가솔린  102807  2014      무사고    흰색
# ..    ...   ...                  ...  ...     ...   ...      ...   ...
# 102    기아  프라이드  4DR 1.6 CVVT SLX     가솔린   70000  2009      무사고    기타
# 103    기아  프라이드  4DR 1.6 CVVT SLX     가솔린   21768  2007      무사고    회색
# 104    기아  프라이드  4DR 1.6 CVVT SLX     가솔린   21768  2007      무사고    회색
# 105    기아  프라이드    4DR 1.5 VGT LX      디젤  133837  2009      무사고    회색
# 106    기아  프라이드   4DR 1.5 VGT SLX      디젤  230000  2009      무사고    흰색
#
#     location  price   wd
# 0         충남    460  2WD
# 1         인천    580  2WD
# 2         서울    530  2WD
# ...

# %%
# info열의 프리미엄 스포츠 여부를 upgrade 열에 추가
pride['upgrade'] = ""

for i in range(0, len(pride)):
    
    if pride['info'].str.contains('디럭스')[i]:
        pride['upgrade'][i] = '디럭스'

    elif pride['info'].str.contains('트렌디')[i]:
        pride['upgrade'][i] = '트렌디'
        
    elif pride['info'].str.contains('럭셔리')[i]:
        pride['upgrade'][i] = '럭셔리'
        
    elif pride['info'].str.contains('프레스티지')[i]:
        pride['upgrade'][i] = '프레스티지'
        
    elif pride['info'].str.contains('프리미엄')[i]:
        pride['upgrade'][i] = '프리미엄'
        
    elif pride['info'].str.contains('SLX')[i]:
        pride['upgrade'][i] = '프레스티지'
        
    elif pride['info'].str.contains('LX')[i]:
        pride['upgrade'][i] = '럭셔리'
        
    elif pride['info'].str.contains('L')[i]:
        pride['upgrade'][i] = '트렌디'
        
    else :
        pride['upgrade'][i] = '디럭스'
pride
# Out:
#     brand  name                 info type      km  year accident color  \
# 0      기아  프라이드           1.6 GDI 세단  가솔린  161066  2014      무사고   검정색
# 1      기아  프라이드           1.6 GDI 세단  가솔린   79699  2012      무사고   검정색
# 2      기아  프라이드   디젤 4DR 1.5 VGT SLX   디젤   44960  2011      무사고   검정색
# 3      기아  프라이드           1.6 GDI 세단  가솔린  127438  2014      무사고   검정색
# 4      기아  프라이드           1.6 GDI 세단  가솔린  102807  2014      무사고    흰색
# ..    ...   ...                  ...  ...     ...   ...      ...   ...
# 102    기아  프라이드  4DR 1.6 CVVT SLX     가솔린   70000  2009      무사고    기타
# 103    기아  프라이드  4DR 1.6 CVVT SLX     가솔린   21768  2007      무사고    회색
# 104    기아  프라이드  4DR 1.6 CVVT SLX     가솔린   21768  2007      무사고    회색
# 105    기아  프라이드    4DR 1.5 VGT LX      디젤  133837  2009      무사고    회색
# 106    기아  프라이드   4DR 1.5 VGT SLX      디젤  230000  2009      무사고    흰색
#
#     location  price   wd upgrade
# 0         충남    460  2WD     디럭스
# 1         인천    580  2WD     디럭스
# ...

# %%
l = df[df['name'] == '로체']
s = df[df['name'] == '스토닉']
sel = df[df['name'] == '셀토스']

# %%
lss = pd.concat([l,s,sel])

# %%
lss
# Out:
#       brand name                   info         type      km  year accident  \
# 254      기아   로체               LPI LX20  LPG(일반인 구입)  243900  2009      무사고
# 680      기아   로체                  LEX20          가솔린  170473  2009      무사고
# 1336     기아   로체                  LEX20          가솔린  137682  2009      무사고
# 1455     기아   로체                LPI DLX  LPG(일반인 구입)   94863  2008      무사고
# 1483     기아   로체                  LEX20          가솔린  132195  2009      무사고
# ...     ...  ...                    ...          ...     ...   ...      ...
# 10922    기아  셀토스     1.6 디젤 2WD 노블레스              디젤   23657  2019      무사고
# 10923    기아  셀토스  1.6 가솔린 터보 2WD 시그니처            가솔린   17931  2020      무사고
# 10924    기아  셀토스  1.6 가솔린 터보 2WD 노블레스            가솔린   11505  2020      무사고
# 10925    기아  셀토스     1.6 디젤 2WD 노블레스              디젤   23657  2019      무사고
# 10926    기아  셀토스  1.6 가솔린 터보 2WD 노블레스            가솔린   18224  2020      무사고
#
#       color location  price   wd
# ...

# %%
lss.reset_index(inplace = True)
lss.drop(['index'], axis = 1,inplace = True)
lss
# Out:
#     brand name                   info         type      km  year accident  \
# 0      기아   로체               LPI LX20  LPG(일반인 구입)  243900  2009      무사고
# 1      기아   로체                  LEX20          가솔린  170473  2009      무사고
# 2      기아   로체                  LEX20          가솔린  137682  2009      무사고
# 3      기아   로체                LPI DLX  LPG(일반인 구입)   94863  2008      무사고
# 4      기아   로체                  LEX20          가솔린  132195  2009      무사고
# ..    ...  ...                    ...          ...     ...   ...      ...
# 523    기아  셀토스     1.6 디젤 2WD 노블레스              디젤   23657  2019      무사고
# 524    기아  셀토스  1.6 가솔린 터보 2WD 시그니처            가솔린   17931  2020      무사고
# 525    기아  셀토스  1.6 가솔린 터보 2WD 노블레스            가솔린   11505  2020      무사고
# 526    기아  셀토스     1.6 디젤 2WD 노블레스              디젤   23657  2019      무사고
# 527    기아  셀토스  1.6 가솔린 터보 2WD 노블레스            가솔린   18224  2020      무사고
#
#     color location  price   wd
# 0     검정색       광주    255  2WD
# ...

# %%
# info열의 프리미엄 스포츠 여부를 upgrade 열에 추가
lss['upgrade'] = ""

for i in range(0, len(lss)):
    
    if lss['info'].str.contains('디럭스')[i]:
        lss['upgrade'][i] = '디럭스'
        
    elif lss['info'].str.contains('기본형')[i]:
        lss['upgrade'][i] = '디럭스'

    elif lss['info'].str.contains('트렌디')[i]:
        lss['upgrade'][i] = '트렌디'
        
    elif lss['info'].str.contains('고급형')[i]:
        lss['upgrade'][i] = '트렌디'
        
    elif lss['info'].str.contains('럭셔리')[i]:
        lss['upgrade'][i] = '럭셔리'
        
    elif lss['info'].str.contains('최고급형')[i]:
        lss['upgrade'][i] = '럭셔리'
        
    elif lss['info'].str.contains('프레스티지')[i]:
        lss['upgrade'][i] = '프레스티지'
        
    elif lss['info'].str.contains('비즈니스')[i]:
        lss['upgrade'][i] = '프레스티지'
        
    elif lss['info'].str.contains('노블레스')[i]:
        lss['upgrade'][i] = '노블레스'
        
    elif lss['info'].str.contains('프리미엄')[i]:
        lss['upgrade'][i] = '프리미엄'
        
    elif lss['info'].str.contains('시그니처')[i]:
        lss['upgrade'][i] = '시그니처'
        
    elif lss['info'].str.contains('그래비티')[i]:
        lss['upgrade'][i] = '그래비티'
        
    else :
        lss['upgrade'][i] = '디럭스'
lss
# Out:
#     brand name                   info         type      km  year accident  \
# 0      기아   로체               LPI LX20  LPG(일반인 구입)  243900  2009      무사고
# 1      기아   로체                  LEX20          가솔린  170473  2009      무사고
# 2      기아   로체                  LEX20          가솔린  137682  2009      무사고
# 3      기아   로체                LPI DLX  LPG(일반인 구입)   94863  2008      무사고
# 4      기아   로체                  LEX20          가솔린  132195  2009      무사고
# ..    ...  ...                    ...          ...     ...   ...      ...
# 523    기아  셀토스     1.6 디젤 2WD 노블레스              디젤   23657  2019      무사고
# 524    기아  셀토스  1.6 가솔린 터보 2WD 시그니처            가솔린   17931  2020      무사고
# 525    기아  셀토스  1.6 가솔린 터보 2WD 노블레스            가솔린   11505  2020      무사고
# 526    기아  셀토스     1.6 디젤 2WD 노블레스              디젤   23657  2019      무사고
# 527    기아  셀토스  1.6 가솔린 터보 2WD 노블레스            가솔린   18224  2020      무사고
#
#     color location  price   wd upgrade
# 0     검정색       광주    255  2WD     디럭스
# ...

# %%
soul = df[df['name'] == '쏘울']

# %%
soul.reset_index(inplace = True)
soul.drop(['index'], axis = 1,inplace = True)
soul
# Out:
#     brand name                info type     km  year accident color location  \
# 0      기아   쏘울      1.6 T-GDI 노블레스  가솔린  32525  2019      무사고   검정색       경기
# 1      기아   쏘울      1.6 T-GDI 노블레스  가솔린  52948  2019      무사고   검정색       경기
# 2      기아   쏘울      1.6 T-GDI 노블레스  가솔린  31025  2019      무사고   검정색       경기
# 3      기아   쏘울      1.6 T-GDI 노블레스  가솔린  33072  2021      무사고   검정색       서울
# 4      기아   쏘울      1.6 T-GDI 노블레스  가솔린   8345  2019      무사고   검정색       광주
# ..    ...  ...                 ...  ...    ...   ...      ...   ...      ...
# 103    기아   쏘울      1.6 T-GDI 노블레스  가솔린  21173  2019      무사고    기타       경북
# 104    기아   쏘울      1.6 T-GDI 노블레스  가솔린  33636  2019      무사고    흰색       서울
# 105    기아   쏘울  1.6 T-GDI 노블레스 스폐셜  가솔린  50025  2019      무사고    기타       경북
# 106    기아   쏘울     1.6 T-GDI 프레스티지  가솔린  13259  2021      무사고    회색       경북
# 107    기아   쏘울             1.6 2U쿨  가솔린  55756  2010      무사고    기타       인천
#
#      price   wd
# 0     2050  2WD
# ...

# %%
# info열의 프리미엄 스포츠 여부를 upgrade 열에 추가
soul['upgrade'] = ""

for i in range(0, len(soul)):
    
    if soul['info'].str.contains('디럭스')[i]:
        soul['upgrade'][i] = '디럭스'
        
    elif soul['info'].str.contains('기본형')[i]:
        soul['upgrade'][i] = '디럭스'

    elif soul['info'].str.contains('트렌디')[i]:
        soul['upgrade'][i] = '트렌디'
        
    elif soul['info'].str.contains('고급형')[i]:
        soul['upgrade'][i] = '트렌디'
        
    elif soul['info'].str.contains('럭셔리')[i]:
        soul['upgrade'][i] = '럭셔리'
        
    elif soul['info'].str.contains('최고급형')[i]:
        soul['upgrade'][i] = '럭셔리'
        
    elif soul['info'].str.contains('프레스티지')[i]:
        soul['upgrade'][i] = '프레스티지'
        
    elif soul['info'].str.contains('그린존')[i]:
        soul['upgrade'][i] = '프레스티지'
        
    elif soul['info'].str.contains('레드존')[i]:
        soul['upgrade'][i] = '프레스티지'
        
    elif soul['info'].str.contains('노블레스')[i]:
        soul['upgrade'][i] = '노블레스'
        
    elif soul['info'].str.contains('브라운존')[i]:
        soul['upgrade'][i] = '노블레스'
        
    elif soul['info'].str.contains('프리미엄')[i]:
        soul['upgrade'][i] = '프리미엄'
        
    else :
        soul['upgrade'][i] = '디럭스'
soul
# Out:
#     brand name                info type     km  year accident color location  \
# 0      기아   쏘울      1.6 T-GDI 노블레스  가솔린  32525  2019      무사고   검정색       경기
# 1      기아   쏘울      1.6 T-GDI 노블레스  가솔린  52948  2019      무사고   검정색       경기
# 2      기아   쏘울      1.6 T-GDI 노블레스  가솔린  31025  2019      무사고   검정색       경기
# 3      기아   쏘울      1.6 T-GDI 노블레스  가솔린  33072  2021      무사고   검정색       서울
# 4      기아   쏘울      1.6 T-GDI 노블레스  가솔린   8345  2019      무사고   검정색       광주
# ..    ...  ...                 ...  ...    ...   ...      ...   ...      ...
# 103    기아   쏘울      1.6 T-GDI 노블레스  가솔린  21173  2019      무사고    기타       경북
# 104    기아   쏘울      1.6 T-GDI 노블레스  가솔린  33636  2019      무사고    흰색       서울
# 105    기아   쏘울  1.6 T-GDI 노블레스 스폐셜  가솔린  50025  2019      무사고    기타       경북
# 106    기아   쏘울     1.6 T-GDI 프레스티지  가솔린  13259  2021      무사고    회색       경북
# 107    기아   쏘울             1.6 2U쿨  가솔린  55756  2010      무사고    기타       인천
#
#      price   wd upgrade
# ...

# %%
ss = df[df['name'] == '쎄라토']
n = df[df['name'] == '니로']
op = df[df['name'] == '옵티마']
sno = pd.concat([ss,n,op])

# %%
sno.reset_index(inplace = True)
sno.drop(['index'], axis = 1,inplace = True)
sno
# Out:
#     brand name            info    type      km  year accident color location  \
# 0      기아  쎄라토         1.6 SLX     가솔린  104682  2006      무사고    흰색       대전
# 1      기아  쎄라토        1.6 GOLD     가솔린  189405  2006      무사고    흰색       광주
# 2      기아  쎄라토  1.6 디젤 SLX          디젤  114148  2008      무사고    회색       전북
# 3      기아   니로           프레스티지  가솔린+전기   62213  2017      무사고   검정색       서울
# 4      기아   니로           프레스티지  가솔린+전기   55338  2018      무사고   검정색       경기
# ..    ...  ...             ...     ...     ...   ...      ...   ...      ...
# 197    기아   니로        노블레스 스폐셜  가솔린+전기   16297  2020      무사고    흰색       인천
# 198    기아   니로           프레스티지  가솔린+전기   72092  2018      무사고    흰색       경남
# 199    기아   니로        노블레스 스폐셜  가솔린+전기   21466  2020      무사고    기타       인천
# 200    기아   니로        노블레스 스폐셜  가솔린+전기   43245  2020      무사고    흰색       인천
# 201    기아  옵티마       2.0 LS SS     가솔린   68610  2000      무사고    회색       경기
#
#      price   wd
# 0      200  2WD
# ...

# %%
# info열의 프리미엄 스포츠 여부를 upgrade 열에 추가
sno['upgrade'] = ""

for i in range(0, len(sno)):
    
    if sno['info'].str.contains('디럭스')[i]:
        sno['upgrade'][i] = '디럭스'
        
    elif sno['info'].str.contains('기본형')[i]:
        sno['upgrade'][i] = '디럭스'

    elif sno['info'].str.contains('트렌디')[i]:
        sno['upgrade'][i] = '트렌디'
        
    elif sno['info'].str.contains('고급형')[i]:
        sno['upgrade'][i] = '트렌디'
        
    elif sno['info'].str.contains('럭셔리')[i]:
        sno['upgrade'][i] = '럭셔리'
        
    elif sno['info'].str.contains('최고급형')[i]:
        sno['upgrade'][i] = '럭셔리'
        
    elif sno['info'].str.contains('프레스티지')[i]:
        sno['upgrade'][i] = '프레스티지'
        
    elif sno['info'].str.contains('프리미엄')[i]:
        sno['upgrade'][i] = '프리미엄'
        
    elif sno['info'].str.contains('프라임')[i]:
        sno['upgrade'][i] = '프리미엄'
        
    elif sno['info'].str.contains('노블레스')[i]:
        sno['upgrade'][i] = '노블레스'
        
    elif sno['info'].str.contains('스포츠')[i]:
        sno['upgrade'][i] = '스포츠'
        
    elif sno['info'].str.contains('스페셜')[i]:
        sno['upgrade'][i] = '스페셜'
        
    else :
        sno['upgrade'][i] = '디럭스'
sno
# Out:
#     brand name            info    type      km  year accident color location  \
# 0      기아  쎄라토         1.6 SLX     가솔린  104682  2006      무사고    흰색       대전
# 1      기아  쎄라토        1.6 GOLD     가솔린  189405  2006      무사고    흰색       광주
# 2      기아  쎄라토  1.6 디젤 SLX          디젤  114148  2008      무사고    회색       전북
# 3      기아   니로           프레스티지  가솔린+전기   62213  2017      무사고   검정색       서울
# 4      기아   니로           프레스티지  가솔린+전기   55338  2018      무사고   검정색       경기
# ..    ...  ...             ...     ...     ...   ...      ...   ...      ...
# 197    기아   니로        노블레스 스폐셜  가솔린+전기   16297  2020      무사고    흰색       인천
# 198    기아   니로           프레스티지  가솔린+전기   72092  2018      무사고    흰색       경남
# 199    기아   니로        노블레스 스폐셜  가솔린+전기   21466  2020      무사고    기타       인천
# 200    기아   니로        노블레스 스폐셜  가솔린+전기   43245  2020      무사고    흰색       인천
# 201    기아  옵티마       2.0 LS SS     가솔린   68610  2000      무사고    회색       경기
#
#      price   wd upgrade
# ...

# %%
bo = df[df['name'] == '봉고III 트럭 CRDi 카고']
no = df[df['name'] == '더 뉴 봉고III 트럭 CRDi 카고']
go = df[df['name'] == '봉고3']
bongo = pd.concat([bo,no,go])

# %%
bongo.reset_index(inplace = True)
bongo.drop(['index'], axis = 1,inplace = True)
bongo
# Out:
#   brand                  name                     info type      km  year  \
# 0    기아      봉고III 트럭 CRDi 카고      4WD 1톤 장축 더블캡GX 스폐셜   디젤   75088  2012
# 1    기아      봉고III 트럭 CRDi 카고         4WD 1톤 장축 더블캡럭셔리   디젤   53278  2016
# 2    기아      봉고III 트럭 CRDi 카고           1톤 초장축 킹캡프레스티지   디젤   55222  2019
# 3    기아      봉고III 트럭 CRDi 카고         1.2톤 초장축 킹캡프레스티지   디젤   24524  2016
# 4    기아      봉고III 트럭 CRDi 카고            1톤 초장축 더블캡럭셔리   디젤   31085  2018
# 5    기아  더 뉴 봉고III 트럭 CRDi 카고         1톤 2WD 초장축 더블캡GL   디젤   24737  2020
# 6    기아                   봉고3              1톤 LPi       LPG    4024  2019
# 7    기아                   봉고3  1.4톤 킹캡 장축 4륜 CRDI LTD    디젤  110000  2018
#
#   accident color location  price   wd
# 0     단순교환    기타       인천   1090  4WD
# 1      무사고    기타       충남   1450  4WD
# 2     단순교환    흰색       전북   1420  2WD
# 3      무사고    흰색       인천   1580  2WD
# 4      무사고    흰색       인천   1690  2WD
# 5      무사고    흰색       충남   1890  2WD
# ...

# %%
for i in range(0, len(bongo)):
    bongo['name'][i] = '봉고3'
bongo
# Out:
#   brand name                     info type      km  year accident color  \
# 0    기아  봉고3      4WD 1톤 장축 더블캡GX 스폐셜   디젤   75088  2012     단순교환    기타
# 1    기아  봉고3         4WD 1톤 장축 더블캡럭셔리   디젤   53278  2016      무사고    기타
# 2    기아  봉고3           1톤 초장축 킹캡프레스티지   디젤   55222  2019     단순교환    흰색
# 3    기아  봉고3         1.2톤 초장축 킹캡프레스티지   디젤   24524  2016      무사고    흰색
# 4    기아  봉고3            1톤 초장축 더블캡럭셔리   디젤   31085  2018      무사고    흰색
# 5    기아  봉고3         1톤 2WD 초장축 더블캡GL   디젤   24737  2020      무사고    흰색
# 6    기아  봉고3              1톤 LPi       LPG    4024  2019      무사고    기타
# 7    기아  봉고3  1.4톤 킹캡 장축 4륜 CRDI LTD    디젤  110000  2018      무사고    흰색
#
#   location  price   wd
# 0       인천   1090  4WD
# 1       충남   1450  4WD
# 2       전북   1420  2WD
# 3       인천   1580  2WD
# 4       인천   1690  2WD
# 5       충남   1890  2WD
# 6       경기   1690  2WD
# 7       광주   1490  2WD

# %%
# info열의 프리미엄 스포츠 여부를 upgrade 열에 추가
bongo['upgrade'] = ""

for i in range(0, len(bongo)):
    
    if bongo['info'].str.contains('GLS')[i]:
        bongo['upgrade'][i] = 'GLS'
        
    elif bongo['info'].str.contains('GL')[i]:
        bongo['upgrade'][i] = 'GL'

    elif bongo['info'].str.contains('L')[i]:
        bongo['upgrade'][i] = 'L'
        
    else :
        bongo['upgrade'][i] = 'L'
bongo
# Out:
#   brand name                     info type      km  year accident color  \
# 0    기아  봉고3      4WD 1톤 장축 더블캡GX 스폐셜   디젤   75088  2012     단순교환    기타
# 1    기아  봉고3         4WD 1톤 장축 더블캡럭셔리   디젤   53278  2016      무사고    기타
# 2    기아  봉고3           1톤 초장축 킹캡프레스티지   디젤   55222  2019     단순교환    흰색
# 3    기아  봉고3         1.2톤 초장축 킹캡프레스티지   디젤   24524  2016      무사고    흰색
# 4    기아  봉고3            1톤 초장축 더블캡럭셔리   디젤   31085  2018      무사고    흰색
# 5    기아  봉고3         1톤 2WD 초장축 더블캡GL   디젤   24737  2020      무사고    흰색
# 6    기아  봉고3              1톤 LPi       LPG    4024  2019      무사고    기타
# 7    기아  봉고3  1.4톤 킹캡 장축 4륜 CRDI LTD    디젤  110000  2018      무사고    흰색
#
#   location  price   wd upgrade
# 0       인천   1090  4WD       L
# 1       충남   1450  4WD       L
# 2       전북   1420  2WD       L
# 3       인천   1580  2WD       L
# 4       인천   1690  2WD       L
# 5       충남   1890  2WD      GL
# 6       경기   1690  2WD       L
# 7       광주   1490  2WD       L

# %%
kia = pd.concat([K5,K7,mohave,sport,carnival,sorento,ray,K9,forte,morning,K8,carens,stingr,K3,master,opirus,pride,lss,soul,sno,bongo])
kia
# Out:
#    brand name                     info type      km  year accident color  \
# 0     기아   K5                      2.0  가솔린  110575  2011      무사고   검정색
# 1     기아   K5                           가솔린  106819  2014      무사고   검정색
# 2     기아   K5                      2.0  가솔린   29151  2019      무사고   검정색
# 3     기아   K5                   1.6 터보  가솔린    8766  2021      무사고   검정색
# 4     기아   K5                      2.0  가솔린  101196  2012      무사고   검정색
# ..   ...  ...                      ...  ...     ...   ...      ...   ...
# 3     기아  봉고3         1.2톤 초장축 킹캡프레스티지   디젤   24524  2016      무사고    흰색
# 4     기아  봉고3            1톤 초장축 더블캡럭셔리   디젤   31085  2018      무사고    흰색
# 5     기아  봉고3         1톤 2WD 초장축 더블캡GL   디젤   24737  2020      무사고    흰색
# 6     기아  봉고3              1톤 LPi       LPG    4024  2019      무사고    기타
# 7     기아  봉고3  1.4톤 킹캡 장축 4륜 CRDI LTD    디젤  110000  2018      무사고    흰색
#
#    location  price   wd upgrade
# 0        인천    650  2WD     럭셔리
# ...

# %%
kia.drop(['info'], axis = 1, inplace = True)
kia
# Out:
#    brand name type      km  year accident color location  price   wd upgrade
# 0     기아   K5  가솔린  110575  2011      무사고   검정색       인천    650  2WD     럭셔리
# 1     기아   K5  가솔린  106819  2014      무사고   검정색       인천    940  2WD     럭셔리
# 2     기아   K5  가솔린   29151  2019      무사고   검정색       충북   1890  2WD    스탠다드
# 3     기아   K5  가솔린    8766  2021      무사고   검정색       경기   3190  2WD    스탠다드
# 4     기아   K5  가솔린  101196  2012      무사고   검정색       대구    820  2WD   프레스티지
# ..   ...  ...  ...     ...   ...      ...   ...      ...    ...  ...     ...
# 3     기아  봉고3   디젤   24524  2016      무사고    흰색       인천   1580  2WD       L
# 4     기아  봉고3   디젤   31085  2018      무사고    흰색       인천   1690  2WD       L
# 5     기아  봉고3   디젤   24737  2020      무사고    흰색       충남   1890  2WD      GL
# 6     기아  봉고3  LPG    4024  2019      무사고    기타       경기   1690  2WD       L
# 7     기아  봉고3   디젤  110000  2018      무사고    흰색       광주   1490  2WD       L
#
# [11287 rows x 11 columns]

# %%
kia.reset_index(inplace = True)
kia.drop(['index'], axis = 1,inplace = True)

# %%
kia['type'].unique()
# Out:
# array(['가솔린', '하이브리드', 'LPG', '디젤', 'LPG(일반인 구입)', '가솔린+전기', '가솔린+LPG',
#        '전기', 'LPG+전기'], dtype=object)

# %%
kia['type'] = kia.apply(lambda x: x['type'].replace('(일반인 구입)',''), axis = 1)
kia['type'] = kia.apply(lambda x: x['type'].replace('가솔린+전기','하이브리드'), axis = 1)
kia['type'] = kia.apply(lambda x: x['type'].replace('LPG+전기','하이브리드'), axis = 1)
kia['type'] = kia.apply(lambda x: x['type'].replace('가솔린+LPG','바이퓨얼'), axis = 1)
kia['type'] = kia.apply(lambda x: x['type'].strip(), axis = 1)
kia['type'].unique()
# Out:
# array(['가솔린', '하이브리드', 'LPG', '디젤', '바이퓨얼', '전기'], dtype=object)

# %%
kia['upgrade'].unique()
# Out:
# array(['럭셔리', '스탠다드', '프레스티지', '노블레스', '디럭스', '시그니쳐', '스마트', 'W 스페셜',
#        '트렌디', '노블레스 스페셜', '스타일 에디션', '럭셔리 트렌디', 'GT LINE', '스페셜 에디션',
#        '스마트 스페셜', '리미티드', 'X 에디션', '프레스티지 스페셜', '월드컵 에디션', '프레스티디 스페셜',
#        '기본형', '프레지던트', 'VIP', '마스터즈', '플래티넘', '시그니처', 'GLX', 'GX', '파크',
#        'LX', '마스터', '마스터 스페셜', '프리미엄', '고급형', '캠핑카', '퀸텀', '이그제큐티브',
#        'RVIP', '그랜드 마스터즈', '그랜드 플래티넘', '베스트 셀렉션 1', '베스트 셀렉션 2', '레드프리미엄',
#        '블랙스페셜', '스포츠', '스페셜', '레이디', '블랙프리미엄', '프라임', 'GT', '드림 에디션', 'L',
#        'GL'], dtype=object)

# %%
import time
from tqdm import tqdm

# %%
kia['trim'] = ""

for i in tqdm(range(0, len(kia))):
    
    if kia['upgrade'].str.contains('럭셔리')[i]:
        kia['trim'][i] = 1
        
    elif kia['upgrade'].str.contains('스탠다드')[i]:
        kia['trim'][i] = 1
        
    elif kia['upgrade'].str.contains('월드컵')[i]:
        kia['trim'][i] = 4
        
    elif kia['upgrade'].str.contains('레이디')[i]:
        kia['trim'][i] = 1
        
    elif kia['upgrade'].str.contains('트립')[i]:
        kia['trim'][i] = 1
        
    elif kia['upgrade'].str.contains('트렌디')[i]:
        kia['trim'][i] = 1
        
    elif kia['upgrade'].str.contains('디럭스')[i]:
        kia['trim'][i] = 1
        
    elif kia['upgrade'].str.contains('스마트')[i]:
        kia['trim'][i] = 1

    elif kia['upgrade'].str.contains('프레스티')[i]:
        kia['trim'][i] = 2
        
    elif kia['upgrade'].str.contains('에디션')[i]:
        kia['trim'][i] = 2
        
    elif kia['upgrade'].str.contains('리미티드')[i]:
        kia['trim'][i] = 2
        
    elif kia['upgrade'].str.contains('W')[i]:
        kia['trim'][i] = 2
        
    elif kia['upgrade'].str.contains('GX')[i]:
        kia['trim'][i] = 2
        
    elif kia['upgrade'].str.contains('랜드')[i]:
        kia['trim'][i] = 2
        
    elif kia['upgrade'].str.contains('플래티넘')[i]:
        kia['trim'][i] = 2
        
    elif kia['upgrade'].str.contains('이그제큐티브')[i]:
        kia['trim'][i] = 2
        
    elif kia['upgrade'].str.contains('노블레스')[i]:
        kia['trim'][i] = 3
        
    elif kia['upgrade'].str.contains('스포츠')[i]:
        kia['trim'][i] = 3
        
    elif kia['upgrade'].str.contains('베스트 셀렉션')[i]:
        kia['trim'][i] = 3
        
    elif kia['upgrade'].str.contains('파크')[i]:
        kia['trim'][i] = 3
        
    elif kia['upgrade'].str.contains('마스터')[i]:
        kia['trim'][i] = 4
        
    elif kia['upgrade'].str.contains('RVIP')[i]:
        kia['trim'][i] = 4
        
    elif kia['upgrade'].str.contains('VIP')[i]:
        kia['trim'][i] = 3
        
    elif kia['upgrade'].str.contains('마스터즈')[i]:
        kia['trim'][i] = 3
        
    elif kia['upgrade'].str.contains('퀸텀')[i]:
        kia['trim'][i] = 4
        
    elif kia['upgrade'].str.contains('시그니처')[i]:
        kia['trim'][i] = 4
        
    elif kia['upgrade'].str.contains('시그니쳐')[i]:
        kia['trim'][i] = 4
        
    elif kia['upgrade'].str.contains('프리미엄')[i]:
        kia['trim'][i] = 4
        
    elif kia['upgrade'].str.contains('프라임')[i]:
        kia['trim'][i] = 4
        
    elif kia['upgrade'].str.contains('GLX')[i]:
        kia['trim'][i] = 3
        
    elif kia['upgrade'].str.contains('GT')[i]:
        kia['trim'][i] = 4
        
    elif kia['upgrade'].str.contains('LX')[i]:
        kia['trim'][i] = 1
        
    elif kia['upgrade'].str.contains('GL')[i]:
        kia['trim'][i] = 2
        
    elif kia['upgrade'].str.contains('L')[i]:
        kia['trim'][i] = 1
        
    elif kia['upgrade'].str.contains('고급형')[i]:
        kia['trim'][i] = 2
        
    elif kia['upgrade'].str.contains('캠핑카')[i]:
        kia['trim'][i] = 1
        
    elif kia['upgrade'].str.contains('기본형')[i]:
        kia['trim'][i] = 1
        
    elif kia['upgrade'].str.contains('프레지던트')[i]:
        kia['trim'][i] = 3
        
    elif kia['upgrade'].str.contains('스페셜')[i]:
        kia['trim'][i] = 3
        
    else :
        pass
kia
# Out:
# 100%|██████████| 11287/11287 [12:58<00:00, 14.49it/s]
#       brand name type      km  year accident color location  price   wd  \
# 0        기아   K5  가솔린  110575  2011      무사고   검정색       인천    650  2WD
# 1        기아   K5  가솔린  106819  2014      무사고   검정색       인천    940  2WD
# 2        기아   K5  가솔린   29151  2019      무사고   검정색       충북   1890  2WD
# 3        기아   K5  가솔린    8766  2021      무사고   검정색       경기   3190  2WD
# 4        기아   K5  가솔린  101196  2012      무사고   검정색       대구    820  2WD
# ...     ...  ...  ...     ...   ...      ...   ...      ...    ...  ...
# 11282    기아  봉고3   디젤   24524  2016      무사고    흰색       인천   1580  2WD
# 11283    기아  봉고3   디젤   31085  2018      무사고    흰색       인천   1690  2WD
# 11284    기아  봉고3   디젤   24737  2020      무사고    흰색       충남   1890  2WD
# 11285    기아  봉고3  LPG    4024  2019      무사고    기타       경기   1690  2WD
# 11286    기아  봉고3   디젤  110000  2018      무사고    흰색       광주   1490  2WD
#
#       upgrade trim
# 0         럭셔리    1
# ...

# %%
kia.drop(['upgrade'], axis = 1, inplace = True)
kia
# Out:
#       brand name type      km  year accident color location  price   wd trim
# 0        기아   K5  가솔린  110575  2011      무사고   검정색       인천    650  2WD    1
# 1        기아   K5  가솔린  106819  2014      무사고   검정색       인천    940  2WD    1
# 2        기아   K5  가솔린   29151  2019      무사고   검정색       충북   1890  2WD    1
# 3        기아   K5  가솔린    8766  2021      무사고   검정색       경기   3190  2WD    1
# 4        기아   K5  가솔린  101196  2012      무사고   검정색       대구    820  2WD    2
# ...     ...  ...  ...     ...   ...      ...   ...      ...    ...  ...  ...
# 11282    기아  봉고3   디젤   24524  2016      무사고    흰색       인천   1580  2WD    1
# 11283    기아  봉고3   디젤   31085  2018      무사고    흰색       인천   1690  2WD    1
# 11284    기아  봉고3   디젤   24737  2020      무사고    흰색       충남   1890  2WD    2
# 11285    기아  봉고3  LPG    4024  2019      무사고    기타       경기   1690  2WD    1
# 11286    기아  봉고3   디젤  110000  2018      무사고    흰색       광주   1490  2WD    1
#
# [11287 rows x 11 columns]

# %%
kia.to_csv('data/KIA_df.csv')

# %%
kia['trim'].value_counts()
# Out:
# 1    4772
# 2    3145
# 3    2041
# 4    1329
# Name: trim, dtype: int64

# %%
df = pd.read_csv('data/KIA_df.csv')

# %%
df
# Out:
#        Unnamed: 0 brand name type      km  year accident color location  \
# 0               0    기아   K5  가솔린  110575  2011      무사고   검정색       인천
# 1               1    기아   K5  가솔린  106819  2014      무사고   검정색       인천
# 2               2    기아   K5  가솔린   29151  2019      무사고   검정색       충북
# 3               3    기아   K5  가솔린    8766  2021      무사고   검정색       경기
# 4               4    기아   K5  가솔린  101196  2012      무사고   검정색       대구
# ...           ...   ...  ...  ...     ...   ...      ...   ...      ...
# 11282       11282    기아  봉고3   디젤   24524  2016      무사고    흰색       인천
# 11283       11283    기아  봉고3   디젤   31085  2018      무사고    흰색       인천
# 11284       11284    기아  봉고3   디젤   24737  2020      무사고    흰색       충남
# 11285       11285    기아  봉고3  LPG    4024  2019      무사고    기타       경기
# 11286       11286    기아  봉고3   디젤  110000  2018      무사고    흰색       광주
#
#        price   wd  trim
# 0        650  2WD     1
# 1        940  2WD     1
# 2       1890  2WD     1
# ...
