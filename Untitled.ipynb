# %%
import joblib

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns',None)
df = pd.read_csv("./data/test_data.csv")
df
# Out:
#        km  year  accident  wd  trim  brand_BMW  brand_기아  brand_랜드로버  \
# 0  100000     3         2   0     1          0         0           0
#
#    brand_르노삼성  brand_미니  brand_벤츠  brand_쉐보레  brand_쌍용  brand_아우디  brand_제네시스  \
# 0           1         0         0          0         0          0           0
#
#    brand_포드  brand_폭스바겐  brand_현대  name_118  name_200  name_320  name_330  \
# 0         0           0         0         0         0         0         0
#
#    name_420   쿠페  name_420  그란쿠페  name_428   컨버터블  name_428   쿠페  name_520  \
# 0              0               0                0              0         0
#
#    name_528  name_530  name_640    그란쿠페  name_730  name_730Ld  name_740  \
# 0         0         0                 0         0           0         0
#
#    name_740Li  name_750Ld  name_750Li  name_A200  name_A220  name_A3  name_A4  \
# 0           0           0           0          0          0        0        0
#
#    name_A45  name_A5  name_A6  name_A7  name_A8  name_B200  name_C200  \
# 0         0        0        0        0        0          0          0
#
#    name_C220  name_C220 블루텍  name_C63  name_CC  name_CC 블루모션  name_CLA220  \
# 0          0              0         0        0             0            0
#
#    name_CLA250  name_CLA45  name_CLS250  name_CLS350  name_CLS4.0  \
# 0            0           0            0            0            0
#
#    name_CLS450  name_CLS63  name_E200  name_E220  name_E220 블루텍  name_E250  \
# 0            0           0          0          0              0          0
#
#    name_E250 블루텍  name_E300  name_E350  name_E400  name_EQ900  name_F150  \
# 0              0          0          0          0           0          0
#
#    name_G63  name_G70  name_G80  name_G90  name_GLA220  name_GLA45  \
# 0         0         0         0         0            0           0
#
#    name_GLC220  name_GLC250  name_GLC300  name_GLC350e  name_GLC43  \
# 0            0            0            0             0           0
#
#    name_GLE350  name_GLK220  name_GT  name_GV70  name_GV80  name_K3  name_K5  \
# 0            0            0        0          0          0        0        0
#
#    name_K7  name_K8  name_K9  name_ML350 블루텍  name_Q3  name_Q5  name_Q7  \
# 0        0        0        0               0        0        0        0
#
#    name_Q8  name_QM5  name_QM6  name_R8  name_S3  name_S350  name_S350 블루텍  \
# 0        0         0         0        0        0          0              0
#
#    name_S350L  name_S350L 블루텍  name_S4  name_S4.0  name_S5  name_S500  \
# 0           0               0        0          0        0          0
#
#    name_S500L  name_S550  name_S560  name_S6  name_S600  name_S63  name_S7  \
# 0           0          0          0        0          0         0        0
#
#    name_S8  name_SM3  name_SM5  name_SM6  name_SM7  name_TT  name_X1  20  \
# 0        0         0         0         1         0        0            0
#
#    name_X4 20  name_X5  30  name_X6 30  name_X6 40  name_e-트론  name_i3  \
# 0           0            0           0           0          0        0
#
#    name_i30  name_i40  name_골프  name_골프 블루모션  name_그랜드스타렉스  name_그랜저  \
# 0         0         0        0             0             0         0
#
#    name_뉴 CC  name_뉴 CC 블루모션  name_니로  name_다마스  name_디스커버리 SE  name_라세티  \
# 0          0               0        0         0              0         0
#
#    name_레이  name_레인지로버  name_레인지로버 AB  name_레인지로버 SE  name_레인지로버 Vogue  \
# 0        0           0              0              0                 0
#
#    name_렉스턴  name_렉스턴 RX4  name_렉스턴 RX6  name_렉스턴 RX7  name_로드스터  name_로디우스  \
# 0         0             0             0             0          0          0
#
#    name_로체  name_마티즈  name_말리부  name_맥스크루즈  name_머스탱 컨버터블  name_머스탱 쿠페  \
# 0        0         0         0           0              0            0
#
#    name_모닝  name_모하비  name_몬데오 2.0 트렌드  name_몬데오 2.0 티타늄  name_베뉴  name_벨로스터  \
# 0        0         0                 0                 0        0          0
#
#    name_볼트  name_봉고3  name_비틀  name_셀토스  name_스타렉스  name_스타리아  name_스토닉  \
# 0        0         0        0         0          0          0         0
#
#    name_스팅어  name_스파크  name_스포티지  name_시로코  name_싼타페  name_쎄라토  name_쏘나타  \
# 0         0         0          0         0         0         0         0
#
#    name_쏘렌토  name_쏘울  name_쏠라티  name_아반떼  name_아베오  name_아슬란  name_아테온  \
# 0         0        0         0         0         0         0         0
#
#    name_알페온  name_액티언  name_에쿠스  name_엑센트  name_엑센트(신형)  name_오피러스  name_올란도  \
# 0         0         0         0         0             0          0         0
#
#    name_옵티마  name_윈스톰  name_익스프레스밴  name_익스플로러  name_임팔라  name_제네시스  name_제타  \
# 0         0         0            0           0         0          0        0
#
#    name_제타 블루모션  name_조에  name_체어맨  name_카니발  name_카렌스  name_카마로  name_카이런  \
# 0             0        0         0         0         0         0         0
#
#    name_캡처  name_캡티바  name_코나  name_코란도  name_코란도 어드벤처 60th 에디션  \
# 0        0         0        0         0                       0
#
#    name_코란도 익스트림  name_콜로라도  name_쿠퍼  name_쿠퍼 5도어  name_쿠퍼 JCW  name_쿠퍼 SE  \
# 0              0          0        0            0            0           0
#
#    name_쿠퍼 컨트리맨  name_쿠퍼 컨트리맨 파크래인  name_크루즈  name_클리오  name_토러스  \
# 0             0                  0         0         0         0
#
#    name_토러스 2.0 에코부스트  name_투싼  name_투아렉  name_투아렉 블루모션  name_트래버스  name_트랙스  \
# 0                   0        0         0              0          0         0
#
#    name_트레일블레이저  name_트위지  name_티구안  name_티록  name_티볼리  name_파사트  name_팰리세이드  \
# 0             0         0         0        0         0         0           0
#
#    name_페이톤  name_펠리세이드  name_포르테  name_포터2  name_폴로  name_프라이드  name_프리랜더 SE  \
# 0         0           0         0         0        0          0             0
#
#    type_LPG  type_가솔린  type_디젤  type_바이퓨얼  type_전기  type_하이브리드  color_검정색  \
# 0         0         1        0          0        0           0          0
#
#    color_기타  color_회색  color_흰색
# 0         0         0         1

# %%
model = joblib.load('XGBoost 최종모델2.pkl')
price = model.predict(df)

# %%
price
# Out:
# array([7.1304007], dtype=float32)
