# %%
import numpy as np
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df = pd.read_csv("./data/닛산.csv")
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.head(30)
# Out:
#    brand   name type      km  year accident color location  price   wd  \
# 0     닛산    알티마  가솔린   43270  2018      무사고   검정색       광주   1620  2WD
# 1     닛산     로그  가솔린  164150  2009      무사고   검정색       경기    490  4WD
# 2     닛산     큐브  가솔린  177725  2006      무사고   검정색       경기    399  2WD
# 4     닛산  패스파인더  가솔린  115749  2014      무사고   검정색       부산   1380  4WD
# 5     닛산    알티마  가솔린   90547  2017      무사고   검정색       경기    970  2WD
# 6     닛산    알티마  가솔린   78365  2018      무사고   검정색       대구   1330  2WD
# 7     닛산    맥시마  가솔린   45994  2017      무사고   검정색       경기   2090  2WD
# 8     닛산   370Z  가솔린   81539  2010      무사고   검정색       경기   2050  2WD
# 9     닛산    무라노  가솔린  155924  2010      무사고   검정색       경기    690  2WD
# 10    닛산   370Z  가솔린  127256  2012      무사고   검정색       경기   1990  2WD
# 11    닛산  패스파인더  가솔린   27402  2018      무사고   검정색       서울   2670  4WD
# 12    닛산     큐브  가솔린  105741  2011      무사고    흰색       서울    690  2WD
# 13    닛산    맥시마  가솔린   33388  2017      무사고    흰색       서울   2090  2WD
# 14    닛산    알티마  가솔린   76250  2017      무사고    흰색       경기   1180  2WD
# 15    닛산  패스파인더  가솔린   56037  2016      무사고    흰색       경기   2050  4WD
# 16    닛산    알티마  가솔린  105007  2010      무사고    흰색       부산    490  2WD
# 17    닛산     쥬크  가솔린   22465  2014      무사고    흰색       경기   1250  2WD
# 18    닛산     큐브  가솔린   59741  2011      무사고    흰색       경기    850  2WD
# 19    닛산    맥시마  가솔린   27284  2017      무사고    흰색       경기   2120  2WD
# 20    닛산   캐시카이   디젤   57600  2015      무사고    흰색       경기   9999  2WD
# 21    닛산     리프   전기  126538  2015      무사고    흰색       부산   1030  2WD
# 22    닛산     큐브  가솔린  107592  2011      무사고    흰색       경기    630  2WD
# 23    닛산   캐시카이   디젤  114272  2015      무사고    흰색       서울   1200  2WD
# 24    닛산     큐브  가솔린  199765  2004      무사고    흰색       경기    370  2WD
# 25    닛산  패스파인더  가솔린   14562  2019      무사고    흰색       서울   2970  4WD
# 26    닛산    알티마  가솔린  116734  2013      무사고    흰색       광주    770  2WD
# 27    닛산     쥬크  가솔린   36686  2016      무사고    흰색       경기   1440  2WD
# 28    닛산     쥬크  가솔린   81220  2015      무사고    흰색       울산   1080  2WD
# 29    닛산    알티마  가솔린   23478  2018      무사고    흰색       경기   1790  2WD
# 30    닛산    맥시마  가솔린   63432  2018      무사고    흰색       부산   2050  2WD
#
#         trim
# 0        2.5
# 1     Deluxe
# 2        1.4
# 4        3.5
# 5    2.5 스마트
# 6        2.5
# 7   3.5 플래티넘
# 8     3.7 쿠페
# 9        3.5
# 10    3.7 쿠페
# 11       3.5
# 12     1.8 S
# 13  3.5 플래티넘
# 14   2.5 스마트
# 15       3.5
# 16       3.5
# 17    1.6 SV
# 18     1.8 S
# 19  3.5 플래티넘
# 20     1.6 S
# 21     EV SL
# 22    1.8 SL
# 23    1.6 SL
# 24       1.4
# 25       3.5
# 26       2.5
# 27    1.6 SV
# 28    1.6 SV
# 29    2.5 테크
# 30  3.5 플래티넘

# %%
# 데이터 확인 용도로 사용
#df['info'].value_counts().to_csv("닛산요약.csv")
# Out:
# 3.5               20
# 2.5               16
# 3.5 플래티넘          10
# 1.8 S              9
# 1.6 SV             7
# 1.8 SL             7
# 3.7 쿠페             5
# 1.4                5
# 2.5 스마트            5
# EV SL              5
# 1.6 S              4
# 2.5 테크             4
# 1.6 SL             4
# 2.5 하이브리드 플래티넘     3
# 2.5 스페셜 에디션        2
# 2.5 SL 테크L33       2
#                    2
# 1.6 SVF15          2
# EV                 2
# Deluxe             2
# 2.5 SL 테크          2
# 2.5 SL 스마트L33      2
# 2.5 SLL33          2
# Name: trim, dtype: int64

# %%
df['info'].value_counts()
# Out:
# 3.5               20
# 2.5               16
# 3.5 플래티넘          10
# 1.8 S              9
# 1.6 SV             7
# 1.8 SL             7
# EV SL              5
# 3.7 쿠페             5
# 1.4                5
# 2.5 스마트            5
# 1.6 SL             4
# 1.6 S              4
# 2.5 테크             4
# 2.5 하이브리드 플래티넘     3
# 2.5 SL 스마트L33      2
# Deluxe             2
#                    2
# 1.6 SVF15          2
# 2.5 스페셜 에디션        2
# 2.5 SLL33          2
# 2.5 SL 테크          2
# 2.5 SL 테크L33       2
# EV                 2
# 3.8                1
# Premium            1
# 1.3                1
# 3.7 쿠페Z34          1
# 1.8 SLZ12          1
# 2.0                1
# 4.0                1
# 1.6 플래티넘           1
# 1.4Z11             1
# Name: info, dtype: int64

# %%
df['trim']= pd.Series()
# Out:
# <ipython-input-11-9517e9924d0c>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df['trim']= pd.Series()

# %%
df['info']=df['info'].str.replace(pat='AWD', repl='')
df['info']=df['info'].str.replace(pat='2WD', repl='')
df['info']=df['info'].str.replace(pat='4WD', repl='')
df['info']=df['info'].str.strip()

# %%
df=df.groupby('info').filter(lambda x : len(x)>1)

# %%
df['trim']= df['info']
df.drop(['info'], axis=1,inplace=True)

# %%
df['type'] = df.apply(lambda x: x['type'].replace('(일반인 구입)',''), axis = 1)
df['type'] = df.apply(lambda x: x['type'].replace('가솔린+전기','하이브리드'), axis = 1)
df['type'] = df.apply(lambda x: x['type'].strip(), axis = 1)

# %%
df.to_csv("닛산_문혁.csv")
