# %%
import numpy as np
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df = pd.read_csv("./data/도요타.csv")
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.head(30)
# Out:
#    brand  name   type      km  year accident color location  price   wd  \
# 0    도요타    캠리  하이브리드   67128  2018      무사고   검정색       경기   2790  2WD
# 1    도요타   시에나    가솔린   79652  2015      무사고   검정색       경기   2299  2WD
# 2    도요타   시에나    가솔린   39796  2015      무사고   검정색       경기   2770  AWD
# 3    도요타    86    가솔린   70333  2013      무사고   검정색       경기   2090  2WD
# 4    도요타  프리우스  하이브리드    4089  2021      무사고   검정색       경기   2790  2WD
# 5    도요타   알파드    가솔린   90716  2017      무사고   검정색       경기   6600  2WD
# 6    도요타    캠리  하이브리드   83894  2017      무사고   검정색       경기   1930  2WD
# 7    도요타   아발론    가솔린  114458  2013      무사고   검정색       서울   1380  2WD
# 8    도요타   시에나    가솔린  109817  2014      무사고   검정색       서울   1980  AWD
# 9    도요타    캠리    가솔린   71386  2014      무사고   검정색       서울   1120  2WD
# 10   도요타    캠리    가솔린   48156  2017      무사고   검정색       경기   1999  2WD
# 12   도요타   아발론  하이브리드   27040  2019      무사고   검정색       부산   3060  2WD
# 13   도요타   시에나    가솔린   76399  2017      무사고   검정색       경기   2750  AWD
# 16   도요타  프리우스  하이브리드  114726  2017      무사고    흰색       부산   1590  2WD
# 17   도요타  프리우스  하이브리드  135935  2012      무사고    흰색       경기    950  2WD
# 18   도요타  프리우스  하이브리드   67029  2018      무사고    흰색       경기   1550  2WD
# 19   도요타   시에나    가솔린   76074  2016      무사고    흰색       경기   2500  AWD
# 20   도요타   시에나    가솔린   44630  2015      무사고    흰색       경기   2550  AWD
# 21   도요타  프리우스  하이브리드   45324  2015      무사고    흰색       서울   1490  2WD
# 22   도요타  RAV4    가솔린   46699  2018      무사고    흰색       경기   5000  2WD
# 23   도요타   시에나    가솔린   28310  2017      무사고    흰색       경기   3420  AWD
# 24   도요타    86    가솔린   62785  2016      무사고    흰색       대구   2490  2WD
# 25   도요타  RAV4  하이브리드   85643  2017      무사고    흰색       경기   2570  4WD
# 26   도요타   시에나    가솔린   67935  2014      무사고    흰색       경기   2420  AWD
# 27   도요타  프리우스  하이브리드    7418  2020      무사고    흰색       경기   2590  2WD
# 28   도요타   시에나    가솔린   59892  2016      무사고    흰색       광주   2550  AWD
# 29   도요타   툰드라    가솔린   48639  2012      무사고    흰색       경기   3590  2WD
# 30   도요타    캠리    가솔린   95226  2013      무사고    흰색       서울    990  2WD
# 31   도요타   시에나    가솔린   74008  2014      무사고    흰색       경기   2090  2WD
# 32   도요타    캠리    가솔린   45367  2016      무사고    흰색       경기   1730  2WD
#
#        trim
# 0   2.5 XLE
# 1       3.5
# 2       3.5
# 3       2.0
# 4       1.8
# 5       3.5
# 6       XLE
# 7      리미티드
# 8       3.5
# 9   2.5 XLE
# 10  2.5 XLE
# 12      2.5
# 13      3.5
# 16    1.8 E
# 17    1.8 E
# 18      1.5
# 19      3.5
# 20      3.5
# 21    1.8 E
# 22      2.5
# 23      3.5
# 24      2.0
# 25      2.5
# 26      3.5
# 27      1.8
# 28      3.5
# 29      5.7
# 30      3.5
# 31      3.5
# 32  2.5 XLE

# %%
# 데이터 확인 용도로 사용
df['info'].value_counts().to_csv("도요타요약.csv")

# %%
df['info']=df['info'].str.replace(pat='AWD', repl='')
df['info']=df['info'].str.replace(pat='2WD', repl='')
df['info']=df['info'].str.replace(pat='4WD', repl='')
df['info']=df['info'].str.replace(pat='하이브리드', repl='')
df['info']=df['info'].str.replace(pat='   ', repl='')
df['info']=df['info'].str.replace(pat='  ', repl='')
df['info']=df['info'].str.strip()

# %%
df=df.groupby('info').filter(lambda x : len(x)>1)

# %%
df['trim']= df['info']
df.drop(['info'], axis=1,inplace=True)

# %%
df['type'] = df.apply(lambda x: x['type'].replace('(일반인 구입)',''), axis = 1)
df['type'] = df.apply(lambda x: x['type'].replace('가솔린+전기','하이브리드'), axis = 1)
df['type'] = df.apply(lambda x: x['type'].strip(), axis = 1)

# %%
df.to_csv("도요타_문혁.csv")
