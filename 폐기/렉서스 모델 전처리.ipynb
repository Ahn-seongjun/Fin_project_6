# %%
import numpy as np
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df = pd.read_csv("./data/렉서스.csv")
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.head(30)
# Out:
#    brand name   type      km  year accident color location  price   wd  \
# 0    렉서스   LS    가솔린   66803  2014      무사고   검정색       서울   3860  2WD
# 1    렉서스   LS    가솔린  170729  2015      무사고   검정색       경기   2730  2WD
# 2    렉서스  500  하이브리드   58322  2018      무사고   검정색       경기   8350  AWD
# 3    렉서스   X3  하이브리드   45606  2018      무사고   검정색       서울   3890  2WD
# 4    렉서스   X4  하이브리드   74133  2017      무사고   검정색       서울   4890  2WD
# 5    렉서스   X4  하이브리드   53160  2018      무사고   검정색       경기   5730  2WD
# 6    렉서스  500  하이브리드  114363  2018      무사고   검정색       부산   6360  AWD
# 7    렉서스   LS  하이브리드  191455  2012      무사고   검정색       경기   1990  2WD
# 8    렉서스   X4  하이브리드   30934  2016      무사고   검정색       경기   4980  2WD
# 9    렉서스   X3  하이브리드   52973  2019      무사고   검정색       광주   4350  2WD
# 10   렉서스  500  하이브리드   69664  2018      무사고   검정색       서울   7590  AWD
# 11   렉서스   S3  하이브리드   13359  2021      무사고   검정색       대구   5550  2WD
# ...

# %%
# 데이터 확인 용도로 사용
df['info'].value_counts().to_csv("렉서스요약.csv")

# %%
df['trim']= pd.Series()
# Out:
# <ipython-input-11-9517e9924d0c>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df['trim']= pd.Series()

# %%
df['info']=df['info'].str.replace(pat='AWD', repl='')
df['info']=df['info'].str.replace(pat='2WD', repl='')
df['info']=df['info'].str.replace(pat='4WD', repl='')
df['info']=df['info'].str.replace(pat='1.8', repl='')
df['info']=df['info'].str.replace(pat='2.5', repl='')
df['info']=df['info'].str.replace(pat='3.5', repl='')
df['info']=df['info'].str.strip()
df['info'].replace('', np.nan, inplace=True)
df.dropna(subset=['info'], inplace=True)
# Out:
# <ipython-input-13-451514a25465>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['info']=df['info'].str.replace(pat='1.8', repl='')
# <ipython-input-13-451514a25465>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['info']=df['info'].str.replace(pat='2.5', repl='')
# <ipython-input-13-451514a25465>:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['info']=df['info'].str.replace(pat='3.5', repl='')

# %%
df=df.groupby('info').filter(lambda x : len(x)>1)

# %%
df['trim']= df['info']
df.drop(['info'], axis=1,inplace=True)

# %%
df['type'] = df.apply(lambda x: x['type'].replace('(일반인 구입)',''), axis = 1)
df['type'] = df.apply(lambda x: x['type'].replace('가솔린+전기','하이브리드'), axis = 1)
df['type'] = df.apply(lambda x: x['type'].strip(), axis = 1)

# %%
df.to_csv("렉서스_문혁.csv")
